# %% [markdown]
# # online nets
#
# Deep learning is powerful but computationally expensive, frequently requiring massive compute budgets. In persuit of cost-effective-yet-powerful AI, this work explores and evaluates a heuristic which should lend to more-efficient use of data through online learning.
#
# Goal: evaluate a deep learning alternative capable of true online learning. Solution requirements:
#
# 1. catastrophic forgetting should be impossible;
# 2. all data is integrated into sufficient statistics of fixed dimension;
# 3. and our solution should have predictive power comparable to deep learning.
#
# ## modeling strategy
#
# We will not attempt to derive sufficient statistics for an entire deep net, but instead leverage well-known sufficient statistics for least squares models,
# so will have sufficient statistics per deep net layer. If this can be empirically shown effective, we'll build-out the theory afterwards.
#
# Recognizing a deep net as a series of compositions, as follows.
#
# $ Y + \varepsilon \approx \mathbb{E}Y = \sigma_3 \circ \beta_3^T \circ \sigma_2 \circ \beta_2^T \circ \sigma_1 \circ \beta_1^T X $
#
# So, we can isolate invidivdual $\beta_j$ matrices using (psuedo-)inverses $\beta_j^{-1}$ like so.
#
# $ \sigma_2^{-1} \circ \beta_3^{-1} \circ \sigma_3^{-1} (Y) \approx  \beta_2^T \circ \sigma_1 \circ \beta_1^T X $
#
# In this example, if we freeze all $\beta_j$'s except $\beta_2$, we are free to update $\hat \beta_2$ using $\tilde Y = \sigma_2^{-1} \circ \beta_3^{-1} \circ \sigma_3^{-1} (Y) $
# and $\tilde X = \sigma_1 \circ \beta_1^T X $.
#
# Using a least squares formulation for fitting to $\left( \tilde X, \tilde Y \right)$, we get sufficient statistics per layer.

# %% [markdown]
# # model code definitions

# %%
import torch

TORCH_TENSOR_TYPE = type(torch.tensor(1)) 

def iterated_diagonals(diag_value, n_rows, n_cols): 
    ## construct diagonal matrix 
    n_diag = min(n_rows, n_cols)
    diag = torch.diag(torch.tensor([diag_value]*n_diag))
    if n_rows > n_cols: 
        ## pad rows 
        pad = n_rows//n_cols + 1
        return torch.cat([diag]*pad, 0)[:n_rows, :n_cols] 
    if n_cols > n_rows: 
        ## pad cols 
        pad = n_cols//n_rows + 1 
        return torch.cat([diag]*pad, 1)[:n_rows, :n_cols] 
    ## no padding 
    return diag 

class OnlineDenseLayer: 
    ''' 
    A single dense net, formulated as a least squares model. 
    ''' 
    def __init__(self, p, q, activation=lambda x:x, activation_inverse=lambda x:x, lam=1., clip=10000., dlamdn=0.): 
        ''' 
        inputs: 
        - p: input dimension 
        - q: output dimension 
        - activation: non-linear function, from R^p to R^q. Default is identity. 
        - activation_inverse: inverse of the activation function. Default is identity. 
        - lam: regularization term 
        - clip: predicted value clipping limit 
        - dlamdn: rate of lambda growth relative to n for online regularization 
        ''' 
        lam = float(lam) 
        clip = float(clip) 
        if dlamdn is not None: 
            dlamdn = float(dlamdn)
        self.__validate_inputs(p=p, q=q, lam=lam, clip=clip, dlamdn=dlamdn) 
        self.p = p 
        self.q = q 
        self.n_fits = 0 
        self.clip = clip 
        self.trainable = True 
        self.activation = activation 
        self.activation_inverse = activation_inverse 
        self.batch_norm_forward_mean = None 
        self.batch_norm_forward_std = None 
        self.batch_norm_forward_n = 0 
        self.batch_norm_backward_mean = None 
        self.batch_norm_backward_std = None 
        self.batch_norm_backward_n = 0 
        self.lam = lam 
        self.dlamdn = dlamdn 
        self.xTy = iterated_diagonals(lam, p+1,q) # +1 for intercept 
        self.yTx = iterated_diagonals(lam, q+1,p) 
        self.xTx_inv = torch.diag(torch.tensor([1./lam]*(p+1))) 
        self.yTy_inv = torch.diag(torch.tensor([1./lam]*(q+1))) 
        self.betaT_forward = torch.matmul(self.xTx_inv, self.xTy) 
        self.betaT_forward = torch.transpose(self.betaT_forward, 0, 1) 
        self.betaT_backward = torch.matmul(self.yTy_inv, self.yTx) 
        self.betaT_backward = torch.transpose(self.betaT_backward, 0, 1) 
        self.x_forward = None 
        self.y_forward = None 
        self.x_backward = None 
        self.y_backward = None 
        pass 
    def copy(self): 
        copied_layer = OnlineDenseLayer(self.p, self.q)
        copied_layer.p = self.p 
        copied_layer.q = self.q 
        copied_layer.n_fits = self.n_fits 
        copied_layer.clip = self.clip 
        copied_layer.trainable = self.trainable 
        copied_layer.activation = self.activation 
        copied_layer.activation_inverse = self.activation_inverse 
        copied_layer.batch_norm_forward_mean = self.batch_norm_forward_mean 
        copied_layer.batch_norm_forward_std = self.batch_norm_forward_std 
        copied_layer.batch_norm_forward_n = self.batch_norm_forward_n 
        copied_layer.batch_norm_backward_mean = self.batch_norm_backward_mean 
        copied_layer.batch_norm_backward_std = self.batch_norm_backward_std 
        copied_layer.batch_norm_backward_n = self.batch_norm_backward_n 
        copied_layer.lam = self.lam 
        copied_layer.dlamdn = self.dlamdn 
        copied_layer.xTy = self.xTy.clone() 
        copied_layer.yTx = self.yTx.clone()
        copied_layer.betaT_forward = self.betaT_forward.clone()
        copied_layer.betaT_backward = self.betaT_backward.clone()
        self.x_forward = None 
        self.y_forward = None 
        self.x_backward = None 
        self.y_backward = None
        return copied_layer 
    def forward(self, x): 
        'creates and stores x_forward and y_forward, then returns activation(y_forward)' 
        self.__validate_inputs(x=x, p=self.p)  
        x = self.batch_norm(x, forward=True, fitting=True) 
        self.x_forward = x
        x = torch.cat((torch.tensor([[1.]]), x), dim=0) # intercept 
        self.y_forward = torch.matmul(self.betaT_forward, x) # predict 
        self.y_forward = torch.clip(self.y_forward, -self.clip, self.clip)
        return self.activation(self.y_forward) 
    def backward(self, y): 
        'creates and stores x_backward and y_backward, then returns y_backward' 
        y = self.activation_inverse(y) 
        self.__validate_inputs(y=y, q=self.q) 
        y = self.batch_norm(y, forward=False, fitting=True) 
        self.y_backward = y 
        y = torch.cat((torch.tensor([[1.]]), y), dim=0) 
        self.x_backward = torch.matmul(self.betaT_backward, y) 
        self.x_backward = torch.clip(self.x_backward, -self.clip, self.clip)
        return self.x_backward 
    def forward_fit(self): 
        'uses x_forward and y_backward to update forward model, then returns Sherman Morrison denominator' 
        if self.trainable: 
            self.__validate_inputs(x=self.x_forward, y=self.y_backward, p=self.p, q=self.q) 
            x = torch.cat((torch.tensor([[1.]]), self.x_forward), dim=0) 
            self.xTx_inv, sm_denom = self.sherman_morrison(self.xTx_inv, x, x) 
            ##self.xTx_inv = self.reregularizer(self.xTx_inv, self.dlamdn) ## real online regularization too slow 
            self.xTy += torch.matmul(x, torch.transpose(self.y_backward, 0, 1)) 
            self.betaT_forward = torch.matmul(self.xTx_inv, self.xTy) 
            self.betaT_forward = torch.transpose(self.betaT_forward, 0, 1) 
        return sm_denom 
    def backward_fit(self):
        'uses x_backward and y_forward to update backward model, then returns Sherman Morrison denominator' 
        if self.trainable: 
            self.__validate_inputs(x=self.x_forward, y=self.y_backward, p=self.p, q=self.q) 
            y = torch.cat((torch.tensor([[1.]]), self.y_backward), dim=0) 
            self.yTy_inv, sm_denom = self.sherman_morrison(self.yTy_inv, y, y) 
            ##self.yTy_inv = self.reregularizer(self.yTy_inv, self.dlamdn) 
            self.yTx += torch.matmul(y, torch.transpose(self.x_backward, 0, 1)) 
            self.betaT_backward = torch.matmul(self.yTy_inv, self.yTx) 
            self.betaT_backward = torch.transpose(self.betaT_backward, 0, 1) 
            self.n_fits += 1 ## TODO write general fitting function 
        return sm_denom 
    def forward_fit_temp(self): 
        'uses x_forward and y_backward to update forward model, then returns Sherman Morrison denominator' 
        if self.trainable: 
            self.__validate_inputs(x=self.x_forward, y=self.y_backward, p=self.p, q=self.q) 
            x = torch.cat((torch.tensor([[1.]]), self.x_forward), dim=0) 
            self.xTx_inv_temp, sm_denom = self.sherman_morrison(self.xTx_inv, x, x) 
            ##self.xTx_inv = self.reregularizer(self.xTx_inv, self.dlamdn) ## real online regularization too slow 
            self.xTy_temp = self.xTy + torch.matmul(x, torch.transpose(self.y_backward, 0, 1)) 
            self.betaT_forward_temp = torch.matmul(self.xTx_inv_temp, self.xTy_temp) 
            self.betaT_forward_temp = torch.transpose(self.betaT_forward_temp, 0, 1) 
        return sm_denom 
    def backward_fit_temp(self):
        'uses x_backward and y_forward to update backward model, then returns Sherman Morrison denominator' 
        if self.trainable: 
            self.__validate_inputs(x=self.x_forward, y=self.y_backward, p=self.p, q=self.q) 
            y = torch.cat((torch.tensor([[1.]]), self.y_backward), dim=0) 
            self.yTy_inv_temp, sm_denom = self.sherman_morrison(self.yTy_inv, y, y) 
            ##self.yTy_inv = self.reregularizer(self.yTy_inv, self.dlamdn) 
            self.yTx_temp = self.yTx + torch.matmul(y, torch.transpose(self.x_backward, 0, 1)) 
            self.betaT_backward_temp = torch.matmul(self.yTy_inv_temp, self.yTx_temp) 
            self.betaT_backward_temp = torch.transpose(self.betaT_backward_temp, 0, 1) 
            #self.n_fits += 1 ## TODO write general fitting function 
        return sm_denom 
    def forward_temp(self, x): 
        'creates and stores x_forward and y_forward, then returns activation(y_forward)' 
        self.__validate_inputs(x=x, p=self.p)  
        x = self.batch_norm(x, forward=True, fitting=False) 
        self.x_forward = x
        x = torch.cat((torch.tensor([[1.]]), x), dim=0) # intercept 
        self.y_forward = torch.matmul(self.betaT_forward_temp, x) # predict 
        self.y_forward = torch.clip(self.y_forward, -self.clip, self.clip)
        return self.activation(self.y_forward) 
    def backward_temp(self, y): 
        'creates and stores x_backward and y_backward, then returns y_backward' 
        y = self.activation_inverse(y) 
        self.__validate_inputs(y=y, q=self.q) 
        y = self.batch_norm(y, forward=False, fitting=False) 
        self.y_backward = y 
        y = torch.cat((torch.tensor([[1.]]), y), dim=0) 
        self.x_backward = torch.matmul(self.betaT_backward_temp, y) 
        self.x_backward = torch.clip(self.x_backward, -self.clip, self.clip)
        return self.x_backward 
    def set_n_fits(self, n):
        'resizes sufficient statistic matrices to sample size n'
        if n < 1 or self.n_fits < 1:
            return None 
        self.xTy *= n/self.n_fits 
        self.yTx *= n/self.n_fits 
        self.xTx_inv *= self.n_fits/n 
        self.yTy_inv *= self.n_fits/n 
        self.n_fits = n 
        pass
    def batch_norm(self, x, forward, fitting=True):
        '''
        batch normalize tensor
        inputs:
        - x: (tensor) to be normalized 
        - forward: (boolean) indicates prediction is forward, instead of backward 
        - fitting: (boolean) if in model fitting, update values 
        '''
        ## retrieve 
        if forward:
            m = self.batch_norm_forward_mean 
            s = self.batch_norm_forward_std
            n = self.batch_norm_forward_n 
        else: 
            m = self.batch_norm_backward_mean 
            s = self.batch_norm_backward_std
            n = self.batch_norm_backward_n 
        ## caculate 
        if n == 0: 
            n = 1 
            m = x.mean() 
            s = x.std() 
        else: 
            n += 1 
            m = x.mean()/n + m*(n-1)/n 
            s = x.std()/n + s*(n-1)/n 
        ## store 
        if fitting:
            if forward: 
                self.batch_norm_forward_mean = m 
                self.batch_norm_forward_std = s 
                self.batch_norm_forward_n = n 
            else: 
                self.batch_norm_backward_mean = m
                self.batch_norm_backward_std = s 
                self.batch_norm_backward_n = n 
        ## no dividing by zero 
        if s < 1e-3:
            s = 1e-3 
        return (x - m)/s 
    def reregularize(self, dlamdn=None): 
        if dlamdn is None:
            dlamdn = self.dlamdn 
        self.xTx_inv = self.online_regularizer(self.xTx_inv, dlamdn) 
        self.yTy_inv = self.online_regularizer(self.yTy_inv, dlamdn) 
        pass 
    @staticmethod
    def online_regularizer(m_inv, dlam):
        '''
        Used to expand the regularization sphere as samples grow.
        Applies modified Sherman Morrison formula for numerical efficiency. 
        inputs
        - m_inv: inverse matrix of m 
        - dlam: regularizer to be added on the diagonal 
        returns
         - (m + 1/dlam)^{-1} 
        '''
        if dlam == 0. or dlam is None:
            ## avoid degeneracy 
            return m_inv 
        if callable(dlam):
            dlam = dlam(self.n_fits) 
        dlam_inv = 1/dlam 
        for i in range(m_inv.shape[0]): 
            m_inv -= dlam_inv * torch.matmul(m_inv[:,i].reshape((-1,1)), m_inv[i,:].reshape((1,-1))) / (1. + dlam_inv * m_inv[i,i]) 
        return m_inv  
    @staticmethod 
    def sherman_morrison(inv_mat, vec1, vec2): 
        ''' 
        applies Sherman Morrison updates, (mat + vec1 vec2^T)^{-1} 
        inputs: 
        - inv_mat: an inverted matrix 
        - vec1: a column vector 
        - vec2: a column vector 
        returns: 
        - updated matrix 
        - the Sherman Morrison denominator, for tracking numerical stability 
        ''' 
        v2t = torch.transpose(vec2, 0, 1)
        denominator = 1. + torch.matmul(torch.matmul(v2t, inv_mat), vec1) 
        numerator = torch.matmul(torch.matmul(inv_mat, vec1), torch.matmul(v2t, inv_mat)) 
        updated_inv_mat = inv_mat - numerator / denominator 
        return updated_inv_mat, float(denominator) 
    def __validate_inputs(self, p=None, q=None, lam=None, x=None, y=None, clip=None, dlamdn=None): 
        'raises value exceptions if provided parameters are invalid'
        if q is not None:
            if not isinstance(q, int):
                raise ValueError('`q` must be int!')
            if q <= 0:
                raise ValueError('`q` must be greater than zero!')
        if p is not None:
            if not isinstance(p, int): 
                raise ValueError('`p` must be int!')
            if p <= 0: 
                raise ValueError('`p` must be greater than zero!')
        if lam is not None:
            if not (isinstance(lam, float) or isinstance(lam, int)):
                raise ValueError('`lam` must be float or int!')
            if lam < 0:
                raise ValueError('`lam` must be non-negative!')
        if x is not None and p is not None: 
            if type(x) != TORCH_TENSOR_TYPE:
                raise ValueError('`x` must be of type `torch.tensor`!') 
            if list(x.shape) != [p,1]: 
                raise ValueError('`x.shape` must be `[p,1]`!') 
            if torch.isnan(x).any():
                raise ValueError('`x` contains `nan`!')
            pass 
        if y is not None and q is not None: 
            if type(y) != TORCH_TENSOR_TYPE:
                raise ValueError('`y` must be of type `torch.tensor`!') 
            if list(y.shape) != [q,1]: 
                raise ValueError('`y.shape` must be `[q,1]`') 
            if torch.isnan(y).any():
                raise ValueError('`y` contains `nan`!')
            pass  
        if clip is not None: 
            if type(clip) != float:
                raise ValueError('`clip` my be of type `float`!') 
            if clip <= 0.: 
                raise ValueError('`clip` must be positive!')
            pass
        if dlamdn is not None: 
            if type(dlamdn) not in [float, callable]: 
                raise ValueError('`dlamdn` my be of type `float` or `callable`!') 
            if type(dlamdn) == float:
                if dlamdn < 0.: 
                    raise ValueError('`dlamdn` must be non-negative!') 
            pass
        pass
    pass

class OnlineNet: 
    'online, sequential dense net' 
    def __init__(self, layer_list, dlamdn=0., reregularization_frequency=1000): 
        '''
        initialize an online dense net
        inputs:
        - layer_list: list of OnlineDenseLayers 
        - dlamdn: (float >= 0) regularization rate per n. Disabled if zero 
        - reregularization_frequency: (int > 0) reregularize after fitting this number of samples, since reregularization is computationally expensive
        '''
        ## validate inputs 
        if type(layer_list) != list: 
            raise ValueError('`layer_list` must be of type list!') 
        for layer in layer_list: 
            if not issubclass(type(layer), OnlineDenseLayer):
                raise ValueError('each item in `layer_list` must be an instance of a subclass of `OnlineDenseLayer`!') 
        if type(dlamdn) != float: 
            raise ValueError('`dlamdn` must of type `float`!') 
        if dlamdn < 0.: 
            raise ValueError('`dlamdn` must be non-negative!') 
        if type(reregularization_frequency) != int: 
            raise ValueError('`reregularization_frequency` must be of type `int`!') 
        if reregularization_frequency <= 0: 
            raise ValueError('`reregularization_frequency` must be postive!') 
        ## assign 
        self.layer_list = layer_list 
        self.fit_count = 0 
        self.dlamdn = dlamdn 
        self.reregularization_frequency = reregularization_frequency 
        pass 
    def copy(self):
        copied_layers = [] 
        for layer in self.layer_list:
            copied_layers.append(layer.copy()) 
        copied_net = OnlineNet(copied_layers, 
                dlamdn=self.dlamdn, 
                reregularization_frequency=self.reregularization_frequency)
        return copied_net 
    def forward(self, x): 
        'predict forward'
        for layer in self.layer_list:
            x = layer.forward(x) 
        return x 
    def backward(self, y):
        'predict backward'
        for layer in reversed(self.layer_list): 
            y = layer.backward(y) 
        return y 
    def forward_temp(self, x): 
        'predicts forward with temporary statistics, returns errors' 
        err = 0. 
        n_layers = len(self.layer_list) 
        for idx, layer in enumerate(self.layer_list):
            x_old = layer.activation(layer.y_forward) 
            x = layer.forward_temp(x) 
            if idx + 1 < n_layers:
                ## ignore observed variables 
                err += (x_old - x).abs().sum() 
            print(f'DEBUG 4: forward cumulative err: {err}') 
        return err 
    def backward_temp(self, y):
        'predicts backward with temporary statistics, returns errors' 
        err = 0.
        n_layers = len(self.layer_list) 
        for idx, layer in enumerate(reversed(self.layer_list)):
            y_old = layer.x_backward 
            y = layer.backward_temp(y)
            if idx + 1 < n_layers: 
                ## ignore observed variables 
                err += (y_old - y).abs().sum() 
            print(f'DEBUG 3: backward cumulative err: {err}')
        return err 
    def set_n_fits(self, n):
        'resizes sufficient statistic matrices to sample size n'
        for layer in self.layer_list:
            layer.set_n_fits(n)
        pass 
    def fit(self, x, y, eps=.01):#1e-6): ## TODO get convergance guarantee, & remove cherry-picked eps
        'integrates observation pair. Returns Sherman Morrison denominators per layer in (forward, backward) pairs in a list'
        ## set intermediary predictions 
        self.set_ends(x,y)
        self.forward(x) 
        self.backward(y) 
        ## infer intermediary vectors before keeping them 
        ## this'll keep matrix sizes aligned with sample sizes 
        err = 1. + eps  
        idx = 0 
        while err > eps: 
            idx += 1 
            self.set_ends(x,y)
            for layer in self.layer_list: 
                layer.forward_fit_temp() 
                layer.backward_fit_temp() 
            self.set_ends(x,y) 
            err_forward = self.forward_temp(x)
            err_backward = self.backward_temp(y) 
            err = err_forward + err_backward 
            if idx % 1000 == 0:
                print(f'DEBUG 1: err: {err}') 
                print(f'DEBUG 2: err_forward: {err_forward}, err_backward: {err_backward}') 
        ## iterate once more, but keep sufficient statistics 
        sherman_morrison_denominator_list = [] 
        for layer in self.layer_list: 
            forward_smd = layer.forward_fit() 
            backward_smd = layer.backward_fit() 
            sherman_morrison_denominator_list.append((forward_smd, backward_smd)) 
        return sherman_morrison_denominator_list 
    def reregularize(self, dlamdn=None): 
        for layer in self.layer_list: 
            layer.reregularize(dlamdn) 
            pass 
        pass 
    def set_ends(self, x, y):
        'resets observations at network ends'
        self.layer_list[0].x_forward = x 
        self.layer_list[0].x_backward = x 
        self.layer_list[-1].y_forward = y 
        self.layer_list[-1].y_backward = y 
        pass 
    def __reduce_sherman_morrison_denominator_list(self, smd_pair_list):
        'returns the value closest to zero'
        if type(smd_pair_list) != list: 
            raise ValueError('`smd_pair_list` must be of type `list`!')
        if len(smd_pair_list) == 0:
            return None 
        smallest_smd = None 
        for smd_pair in smd_pair_list:
            if type(smd_pair) != tuple:
                raise ValueError('`smd_pair_list` must be list of tuples!')
            if smallest_smd is None: 
                smallest_smd = smd_pair[0] 
            if abs(smallest_smd) > abs(smd_pair[0]): 
                smallest_smd = smd_pair[0] 
            if abs(smallest_smd) > abs(smd_pair[1]):
                smallest_smd = smd_pair[1] 
        return float(smallest_smd) 
    def __call__(self, x, y=None): 
        '''
        If only x is given, a prediction is made and returned.
        If x and y are given, then the model is updated, and returns
        - the prediction
        - the sherman morrison denominator closest to zero, for tracking numerical stability
        '''
        y_hat = self.forward(x) 
        if y is None: 
            return y_hat 
        self.backward(y) 
        smd_pair_list = self.fit(x,y) 
        smallest_smd = self.__reduce_sherman_morrison_denominator_list(smd_pair_list) 
        self.fit_count += 1 
        if self.fit_count % self.reregularization_frequency == 0:
            if self.dlamdn is not None: 
                ## dividing by self.reregularization_frequency ensures mathematical equivalency to reregularizing with every step 
                self.reregularize(self.dlamdn/self.reregularization_frequency) 
            else:
                ## use per-layer dlamdn values 
                self.reregularize() 
        return y_hat, smallest_smd 

## tests 

## test 1: sherman morrison 
a = torch.tensor([[2., 1.], [1., 2.]]) 
b = torch.tensor([[.1],[.2]]) 
sm_inv, _ = OnlineDenseLayer.sherman_morrison(torch.inverse(a),b,b) 
num_inv = torch.inverse(a+torch.matmul(b, torch.transpose(b,0,1))) 
err = float(torch.abs(sm_inv - num_inv).sum()) 
assert(err < 1e-5) 

## test 2: online regularization sherman morrison 
a = torch.tensor([[2., 1.], [1., 2.]]) 
b = torch.tensor([[.1, 0.], [0., .1]])
or_inv = OnlineDenseLayer.online_regularizer(torch.inverse(a), 10.) 
num_inv = torch.inverse(a+b) 
err = float(torch.abs(or_inv - num_inv).sum()) 
assert(err < 1e-5)

# %% [markdown]
# # first experiment: mnist classification

# %%
from tqdm import tqdm
from torchvision import datasets, transforms

transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
    ])

dataset1 = datasets.MNIST('../../data', train=True, download=True, transform=transform)
dataset2 = datasets.MNIST('../../data', train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(dataset1)
test_loader = torch.utils.data.DataLoader(dataset2)

n_labels = 10 
lam = 100. 
dlamdn = 10. 
reregularization_frequency = 1000 
clip = 100. 

## activation functions 
## torch.sigmoid 
inv_sigmoid = lambda x: -torch.log((1/(x+1e-8))-1) 
leaky_relu_alpha = .1 
leaky_relu = lambda x: (x > 0)*x + (x <= 0)*x*leaky_relu_alpha 
inv_leaky_relu = lambda x: (x > 0)*x + (x <= 0)*x/leaky_relu_alpha 

model = OnlineNet( 
    layer_list = [ 
        OnlineDenseLayer(p=1*1*28*28, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=n_labels, activation=torch.sigmoid, activation_inverse=inv_sigmoid, lam=lam, clip=clip) 
    ], 
    reregularization_frequency = reregularization_frequency, 
    dlamdn = dlamdn 
) 

def build_data(image, label): 
    'format data from iterator for model' 
    y = torch.tensor([1. if int(label[0]) == idx else 0. for idx in range(n_labels)]) ## one-hot representation 
    x = image.reshape([-1]) ## flatten 
    ## shrink so sigmoid inverse is well-defined 
    y = y*.90 + .05 
    ## reshape to column vectors 
    x = x.reshape([-1,1]) 
    y = y.reshape([-1,1]) 
    return x, y 

def match(y, y_hat):
    y = y.reshape(-1)
    y_hat = y_hat.reshape(-1)
    if y.argmax() == y_hat.argmax():
        return 1.
    return 0. 

def run(data_iterable, fit=True, max_iters=None, model=model):
    '''
    fit or predict on dataset 
    inputs:
    - data_iterable: an iterable of (image, label) pairs
    - fit: (bool) are we integrating the (image, label) pair into the model or just predicting?
    - max_iters: (int or None) if int then cap fit/predict iters at this amount, otherwise run the whole iterable 
    - model: (OnlineDenseNet) the model to update in-place 
    output: 
    - errs: a list of model errors 
    - stab: a list of numerical stability statistics 
    - y_std: a list of y_hat standard deviations 
    - acc: a list of running average accuracies 
    side-effects: 
    - model is updated in-place 
    '''
    ## init stats 
    errs = [] 
    stab = [] 
    y_std = [] 
    acc = [0.] 
    ## get data 
    pbar = tqdm(data_iterable)
    n_iters = 0 
    for [image, label] in pbar: 
        n_iters += 1 
        ## get a datum 
        x, y = build_data(image, label) 
        ## fit or predict 
        if fit: 
            y_hat, stability = model(x, y) 
        else:
            y_hat = model(x) 
            stability = 1. 
        ## stats 
        err = float((y - y_hat).abs().sum()) 
        errs.append(err) 
        stab.append(stability) 
        std = float(y_hat.std()) 
        y_std.append(std) 
        acc_n = max(len(acc), 1000) 
        acc.append(match(y,y_hat)/acc_n + acc[-1]*(acc_n-1)/acc_n) 
        pbar.set_description(f'acc: {acc[-1]:.5f}, err: {err:.5f}, y_std: {std:.5f}, stab: {stability:.5f}') 
        if max_iters is not None: 
            if n_iters > max_iters:
                return errs, stab, y_std, acc
    return errs, stab, y_std, acc 

def test(data_iterable, model, max_iters=None): 
    'calculates accuracy correctly' 
    hits = 0 
    n = 0 
    n_iters = 0 
    for image, label in tqdm(data_iterable):
        x, y = build_data(image, label) 
        y_hat = model(x) 
        if match(y, y_hat) == 1:
            hits += 1 
        n += 1
    return hits/n  

errs, stab, y_std, acc = run(train_loader, fit=True, max_iters=10000)
# Out:
# acc: 0.00874, err: 3.86714, y_std: 0.25525, stab: 1.05000:   0%|          | 73/60000 [00:47<10:48:59,  1.54it/s]
# DEBUG 4: forward cumulative err: 87.66703796386719
# DEBUG 4: forward cumulative err: 139.34609985351562
# DEBUG 4: forward cumulative err: 189.9757080078125
# DEBUG 4: forward cumulative err: 189.9757080078125
# DEBUG 3: backward cumulative err: 1.6327847242355347
# DEBUG 3: backward cumulative err: 5.210565567016602
# DEBUG 3: backward cumulative err: 13.477991104125977
# DEBUG 3: backward cumulative err: 13.477991104125977
# DEBUG 4: forward cumulative err: 1.7382527589797974
# DEBUG 4: forward cumulative err: 17.64523696899414
# DEBUG 4: forward cumulative err: 39.929359436035156
# DEBUG 4: forward cumulative err: 39.929359436035156
# DEBUG 3: backward cumulative err: 0.05704900622367859
# DEBUG 3: backward cumulative err: 0.18061867356300354
# DEBUG 3: backward cumulative err: 0.4600914716720581
# DEBUG 3: backward cumulative err: 0.4600914716720581
# DEBUG 4: forward cumulative err: 0.05484948307275772
# DEBUG 4: forward cumulative err: 0.3031519651412964
# DEBUG 4: forward cumulative err: 3.572498321533203
# DEBUG 4: forward cumulative err: 3.572498321533203
# DEBUG 3: backward cumulative err: 0.0020011961460113525
# DEBUG 3: backward cumulative err: 0.006451517343521118
# DEBUG 3: backward cumulative err: 0.016267597675323486
# DEBUG 3: backward cumulative err: 0.016267597675323486
# DEBUG 4: forward cumulative err: 0.001998087391257286
# DEBUG 4: forward cumulative err: 0.009921183809638023
# DEBUG 4: forward cumulative err: 0.04896900802850723
# DEBUG 4: forward cumulative err: 0.04896900802850723
# DEBUG 3: backward cumulative err: 6.839632987976074e-05
# DEBUG 3: backward cumulative err: 0.0003250539302825928
# DEBUG 3: backward cumulative err: 0.0007786750793457031
# DEBUG 3: backward cumulative err: 0.0007786750793457031
# DEBUG 4: forward cumulative err: 0.00011684559285640717
# DEBUG 4: forward cumulative err: 0.00038257427513599396
# DEBUG 4: forward cumulative err: 0.0016570095904171467
# DEBUG 4: forward cumulative err: 0.0016570095904171467
# DEBUG 3: backward cumulative err: 5.364418029785156e-06
# DEBUG 3: backward cumulative err: 6.914138793945312e-05
# DEBUG 3: backward cumulative err: 0.00014582276344299316
# DEBUG 3: backward cumulative err: 0.00014582276344299316
# DEBUG 4: forward cumulative err: 133.3182830810547
# DEBUG 4: forward cumulative err: 187.15261840820312
# DEBUG 4: forward cumulative err: 230.81173706054688
# DEBUG 4: forward cumulative err: 230.81173706054688
# DEBUG 3: backward cumulative err: 1.6328309774398804
# DEBUG 3: backward cumulative err: 5.938437461853027
# DEBUG 3: backward cumulative err: 17.9538516998291
# DEBUG 3: backward cumulative err: 17.9538516998291
# DEBUG 4: forward cumulative err: 3.142758369445801
# DEBUG 4: forward cumulative err: 9.563398361206055
# DEBUG 4: forward cumulative err: 13.60413932800293
# DEBUG 4: forward cumulative err: 13.60413932800293
# DEBUG 3: backward cumulative err: 0.057065874338150024
# DEBUG 3: backward cumulative err: 0.20664730668067932
# DEBUG 3: backward cumulative err: 0.6175692081451416
# DEBUG 3: backward cumulative err: 0.6175692081451416
# DEBUG 4: forward cumulative err: 0.09251319617033005
# DEBUG 4: forward cumulative err: 0.4044956564903259
# DEBUG 4: forward cumulative err: 0.9550238251686096
# DEBUG 4: forward cumulative err: 0.9550238251686096
# DEBUG 3: backward cumulative err: 0.001986980438232422
# DEBUG 3: backward cumulative err: 0.007267773151397705
# DEBUG 3: backward cumulative err: 0.02165403962135315
# DEBUG 3: backward cumulative err: 0.02165403962135315
# DEBUG 4: forward cumulative err: 0.00318053737282753
# DEBUG 4: forward cumulative err: 0.012112820520997047
# DEBUG 4: forward cumulative err: 0.029822463169693947
# DEBUG 4: forward cumulative err: 0.029822463169693947
# DEBUG 3: backward cumulative err: 7.295608520507812e-05
# DEBUG 3: backward cumulative err: 0.0002931952476501465
# DEBUG 3: backward cumulative err: 0.0008449256420135498
# DEBUG 3: backward cumulative err: 0.0008449256420135498
# DEBUG 4: forward cumulative err: 0.00013877637684345245
# DEBUG 4: forward cumulative err: 0.00044126505963504314
# DEBUG 4: forward cumulative err: 0.0009570361580699682
# DEBUG 4: forward cumulative err: 0.0009570361580699682
# DEBUG 3: backward cumulative err: 3.4868717193603516e-06
# DEBUG 3: backward cumulative err: 5.367398262023926e-05
# DEBUG 3: backward cumulative err: 0.00012096762657165527
# DEBUG 3: backward cumulative err: 0.00012096762657165527
# DEBUG 4: forward cumulative err: 52.281005859375
# DEBUG 4: forward cumulative err: 77.891845703125
# DEBUG 4: forward cumulative err: 100.55480194091797
# DEBUG 4: forward cumulative err: 100.55480194091797
# DEBUG 3: backward cumulative err: 1.6328550577163696
# DEBUG 3: backward cumulative err: 6.252234935760498
# DEBUG 3: backward cumulative err: 20.114994049072266
# DEBUG 3: backward cumulative err: 20.114994049072266
# DEBUG 4: forward cumulative err: 3.800154685974121
# DEBUG 4: forward cumulative err: 13.746600151062012
# DEBUG 4: forward cumulative err: 25.430871963500977
# DEBUG 4: forward cumulative err: 25.430871963500977
# DEBUG 3: backward cumulative err: 0.05705997347831726
# DEBUG 3: backward cumulative err: 0.21769890189170837
# DEBUG 3: backward cumulative err: 0.6941510438919067
# DEBUG 3: backward cumulative err: 0.6941510438919067
# DEBUG 4: forward cumulative err: 0.12305480241775513
# DEBUG 4: forward cumulative err: 0.4748952388763428
# DEBUG 4: forward cumulative err: 1.6854326725006104
# DEBUG 4: forward cumulative err: 1.6854326725006104
# DEBUG 3: backward cumulative err: 0.0019904673099517822
# DEBUG 3: backward cumulative err: 0.007537394762039185
# DEBUG 3: backward cumulative err: 0.023984193801879883
# DEBUG 3: backward cumulative err: 0.023984193801879883
# DEBUG 4: forward cumulative err: 0.00434306263923645
# DEBUG 4: forward cumulative err: 0.015506008639931679
# DEBUG 4: forward cumulative err: 0.0526382252573967
# DEBUG 4: forward cumulative err: 0.0526382252573967
# DEBUG 3: backward cumulative err: 7.510185241699219e-05
# DEBUG 3: backward cumulative err: 0.0003198981285095215
# DEBUG 3: backward cumulative err: 0.000987231731414795
# DEBUG 3: backward cumulative err: 0.000987231731414795
# DEBUG 4: forward cumulative err: 9.719282388687134e-05
# DEBUG 4: forward cumulative err: 0.000482071191072464
# DEBUG 4: forward cumulative err: 0.0016377405263483524
# DEBUG 4: forward cumulative err: 0.0016377405263483524
# DEBUG 3: backward cumulative err: 1.0728836059570312e-06
# DEBUG 3: backward cumulative err: 3.129243850708008e-05
# DEBUG 3: backward cumulative err: 0.00012984871864318848
# DEBUG 3: backward cumulative err: 0.00012984871864318848
# DEBUG 4: forward cumulative err: 87.24929809570312
# DEBUG 4: forward cumulative err: 130.2467803955078
# DEBUG 4: forward cumulative err: 175.1728973388672
# DEBUG 4: forward cumulative err: 175.1728973388672
# DEBUG 3: backward cumulative err: 1.6328883171081543
# DEBUG 3: backward cumulative err: 6.427000999450684
# DEBUG 3: backward cumulative err: 21.381736755371094
# DEBUG 3: backward cumulative err: 21.381736755371094
# DEBUG 4: forward cumulative err: 9.864462852478027
# DEBUG 4: forward cumulative err: 17.5891170501709
# DEBUG 4: forward cumulative err: 36.195220947265625
# DEBUG 4: forward cumulative err: 36.195220947265625
# DEBUG 3: backward cumulative err: 0.057065606117248535
# DEBUG 3: backward cumulative err: 0.22399061918258667
# DEBUG 3: backward cumulative err: 0.7395766377449036
# DEBUG 3: backward cumulative err: 0.7395766377449036
# DEBUG 4: forward cumulative err: 0.2357548028230667
# DEBUG 4: forward cumulative err: 1.0956568717956543
# DEBUG 4: forward cumulative err: 2.5490353107452393
# DEBUG 4: forward cumulative err: 2.5490353107452393
# DEBUG 3: backward cumulative err: 0.001997709274291992
# DEBUG 3: backward cumulative err: 0.007858991622924805
# DEBUG 3: backward cumulative err: 0.025929927825927734
# DEBUG 3: backward cumulative err: 0.025929927825927734
# DEBUG 4: forward cumulative err: 0.008348669856786728
# DEBUG 4: forward cumulative err: 0.022019950672984123
# DEBUG 4: forward cumulative err: 0.26387888193130493
# DEBUG 4: forward cumulative err: 0.26387888193130493
# DEBUG 3: backward cumulative err: 6.625056266784668e-05
# DEBUG 3: backward cumulative err: 0.00030353665351867676
# DEBUG 3: backward cumulative err: 0.0009747147560119629
# DEBUG 3: backward cumulative err: 0.0009747147560119629
# DEBUG 4: forward cumulative err: 0.00032663089223206043
# DEBUG 4: forward cumulative err: 0.0008279264438897371
# DEBUG 4: forward cumulative err: 0.003884281264618039
# DEBUG 4: forward cumulative err: 0.003884281264618039
# DEBUG 3: backward cumulative err: 1.341104507446289e-06
# DEBUG 3: backward cumulative err: 5.7071447372436523e-05
# DEBUG 3: backward cumulative err: 0.0001939535140991211
# DEBUG 3: backward cumulative err: 0.0001939535140991211
# DEBUG 4: forward cumulative err: 104.31745147705078
# DEBUG 4: forward cumulative err: 159.9034881591797
# DEBUG 4: forward cumulative err: 213.35447692871094
# DEBUG 4: forward cumulative err: 213.35447692871094
# DEBUG 3: backward cumulative err: 1.632900357246399
# DEBUG 3: backward cumulative err: 6.538302898406982
# DEBUG 3: backward cumulative err: 22.212512969970703
# DEBUG 3: backward cumulative err: 22.212512969970703
# DEBUG 4: forward cumulative err: 9.598971366882324
# DEBUG 4: forward cumulative err: 20.523757934570312
# DEBUG 4: forward cumulative err: 35.45497131347656
# DEBUG 4: forward cumulative err: 35.45497131347656
# DEBUG 3: backward cumulative err: 0.05707016587257385
# DEBUG 3: backward cumulative err: 0.22803685069084167
# DEBUG 3: backward cumulative err: 0.7698994874954224
# DEBUG 3: backward cumulative err: 0.7698994874954224
# DEBUG 4: forward cumulative err: 0.1567288637161255
# DEBUG 4: forward cumulative err: 1.0927571058273315
# DEBUG 4: forward cumulative err: 2.9396629333496094
# DEBUG 4: forward cumulative err: 2.9396629333496094
# DEBUG 3: backward cumulative err: 0.0019936859607696533
# DEBUG 3: backward cumulative err: 0.007906466722488403
# DEBUG 3: backward cumulative err: 0.026677459478378296
# DEBUG 3: backward cumulative err: 0.026677459478378296
# DEBUG 4: forward cumulative err: 0.005451513454318047
# DEBUG 4: forward cumulative err: 0.019198818132281303
# DEBUG 4: forward cumulative err: 0.26170217990875244
# DEBUG 4: forward cumulative err: 0.26170217990875244
# DEBUG 3: backward cumulative err: 6.839632987976074e-05
# DEBUG 3: backward cumulative err: 0.0002891123294830322
# DEBUG 3: backward cumulative err: 0.0009832680225372314
# DEBUG 3: backward cumulative err: 0.0009832680225372314
# DEBUG 4: forward cumulative err: 0.0002239421010017395
# DEBUG 4: forward cumulative err: 0.000694669783115387
# DEBUG 4: forward cumulative err: 0.003527075983583927
# DEBUG 4: forward cumulative err: 0.003527075983583927
# DEBUG 3: backward cumulative err: 2.1457672119140625e-06
# DEBUG 3: backward cumulative err: 2.372264862060547e-05
# DEBUG 3: backward cumulative err: 7.462501525878906e-05
# DEBUG 3: backward cumulative err: 7.462501525878906e-05
# DEBUG 4: forward cumulative err: 131.98724365234375
# DEBUG 4: forward cumulative err: 196.2950439453125
# DEBUG 4: forward cumulative err: 258.2926940917969
# DEBUG 4: forward cumulative err: 258.2926940917969
# DEBUG 3: backward cumulative err: 1.632920265197754
# DEBUG 3: backward cumulative err: 6.615488052368164
# DEBUG 3: backward cumulative err: 22.799467086791992
# DEBUG 3: backward cumulative err: 22.799467086791992
# DEBUG 4: forward cumulative err: 8.328492164611816
# DEBUG 4: forward cumulative err: 16.570911407470703
# DEBUG 4: forward cumulative err: 26.980989456176758
# DEBUG 4: forward cumulative err: 26.980989456176758
# DEBUG 3: backward cumulative err: 0.057084113359451294
# DEBUG 3: backward cumulative err: 0.2308044135570526
# DEBUG 3: backward cumulative err: 0.7910724878311157
# DEBUG 3: backward cumulative err: 0.7910724878311157
# DEBUG 4: forward cumulative err: 0.1794106513261795
# DEBUG 4: forward cumulative err: 0.6990904211997986
# DEBUG 4: forward cumulative err: 1.762712001800537
# DEBUG 4: forward cumulative err: 1.762712001800537
# DEBUG 3: backward cumulative err: 0.0019928812980651855
# DEBUG 3: backward cumulative err: 0.008077263832092285
# DEBUG 3: backward cumulative err: 0.027707189321517944
# DEBUG 3: backward cumulative err: 0.027707189321517944
# DEBUG 4: forward cumulative err: 0.0062249391339719296
# DEBUG 4: forward cumulative err: 0.015852289274334908
# DEBUG 4: forward cumulative err: 0.10704086720943451
# DEBUG 4: forward cumulative err: 0.10704086720943451
# DEBUG 3: backward cumulative err: 6.756186485290527e-05
# DEBUG 3: backward cumulative err: 0.0003038942813873291
# DEBUG 3: backward cumulative err: 0.001077026128768921
# DEBUG 3: backward cumulative err: 0.001077026128768921
# DEBUG 4: forward cumulative err: 0.0002705678343772888
# DEBUG 4: forward cumulative err: 0.0006314705824479461
# DEBUG 4: forward cumulative err: 0.002029768191277981
# DEBUG 4: forward cumulative err: 0.002029768191277981
# DEBUG 3: backward cumulative err: 3.546476364135742e-06
# DEBUG 3: backward cumulative err: 2.7567148208618164e-05
# DEBUG 3: backward cumulative err: 9.453296661376953e-05
# DEBUG 3: backward cumulative err: 9.453296661376953e-05
# DEBUG 4: forward cumulative err: 68.30963897705078
# DEBUG 4: forward cumulative err: 101.15373229980469
# DEBUG 4: forward cumulative err: 131.7023162841797
# DEBUG 4: forward cumulative err: 131.7023162841797
# DEBUG 3: backward cumulative err: 1.4892995357513428
# DEBUG 3: backward cumulative err: 6.053671836853027
# DEBUG 3: backward cumulative err: 20.94654655456543
# DEBUG 3: backward cumulative err: 20.94654655456543
# DEBUG 4: forward cumulative err: 6.759692192077637
# DEBUG 4: forward cumulative err: 11.985101699829102
# DEBUG 4: forward cumulative err: 20.85882568359375
# DEBUG 4: forward cumulative err: 20.85882568359375
# DEBUG 3: backward cumulative err: 0.0473785400390625
# DEBUG 3: backward cumulative err: 0.19317245483398438
# DEBUG 3: backward cumulative err: 0.6691012382507324
# DEBUG 3: backward cumulative err: 0.6691012382507324
# DEBUG 4: forward cumulative err: 0.00046573043800890446
# DEBUG 4: forward cumulative err: 0.0015427421312779188
# DEBUG 4: forward cumulative err: 0.0015427421312779188
# DEBUG 3: backward cumulative err: 2.1457672119140625e-06
# DEBUG 3: backward cumulative err: 3.796815872192383e-05
# DEBUG 3: backward cumulative err: 0.0001207888126373291
# DEBUG 3: backward cumulative err: 0.0001207888126373291
# DEBUG 4: forward cumulative err: 33.0184326171875
# DEBUG 4: forward cumulative err: 50.31614303588867
# DEBUG 4: forward cumulative err: 71.76167297363281
# DEBUG 4: forward cumulative err: 71.76167297363281
# DEBUG 3: backward cumulative err: 1.3689169883728027
# DEBUG 3: backward cumulative err: 5.612749099731445
# DEBUG 3: backward cumulative err: 19.63026237487793
# DEBUG 3: backward cumulative err: 19.63026237487793
# DEBUG 4: forward cumulative err: 3.293869972229004
# DEBUG 4: forward cumulative err: 5.657855033874512
# DEBUG 4: forward cumulative err: 9.630468368530273
# DEBUG 4: forward cumulative err: 9.630468368530273
# DEBUG 3: backward cumulative err: 0.039949625730514526
# DEBUG 3: backward cumulative err: 0.16480639576911926
# DEBUG 3: backward cumulative err: 0.5791496634483337
# DEBUG 3: backward cumulative err: 0.5791496634483337
# DEBUG 4: forward cumulative err: 0.09055107086896896
# DEBUG 4: forward cumulative err: 0.23996049165725708
# DEBUG 4: forward cumulative err: 0.6078038215637207
# DEBUG 4: forward cumulative err: 0.6078038215637207
# DEBUG 3: backward cumulative err: 0.0011635422706604004
# DEBUG 3: backward cumulative err: 0.004833221435546875
# DEBUG 3: backward cumulative err: 0.01700606942176819
# DEBUG 3: backward cumulative err: 0.01700606942176819
# DEBUG 4: forward cumulative err: 0.0026760734617710114
# DEBUG 4: forward cumulative err: 0.006548434495925903
# DEBUG 4: forward cumulative err: 0.024037281051278114
# DEBUG 4: forward cumulative err: 0.024037281051278114
# DEBUG 3: backward cumulative err: 3.781914710998535e-05
# DEBUG 3: backward cumulative err: 0.0001608431339263916
# DEBUG 3: backward cumulative err: 0.0005369484424591064
# DEBUG 3: backward cumulative err: 0.0005369484424591064
# DEBUG 4: forward cumulative err: 0.00010265037417411804
# DEBUG 4: forward cumulative err: 0.00021960586309432983
# DEBUG 4: forward cumulative err: 0.0006236124318093061
# DEBUG 4: forward cumulative err: 0.0006236124318093061
# DEBUG 3: backward cumulative err: 1.0728836059570312e-06
# DEBUG 3: backward cumulative err: 2.6166439056396484e-05
# DEBUG 3: backward cumulative err: 0.00010219216346740723
# DEBUG 3: backward cumulative err: 0.00010219216346740723
# DEBUG 4: forward cumulative err: 84.6326904296875
# DEBUG 4: forward cumulative err: 130.9500732421875
# DEBUG 4: forward cumulative err: 182.83718872070312
# DEBUG 4: forward cumulative err: 182.83718872070312
# DEBUG 3: backward cumulative err: 1.4893791675567627
# DEBUG 3: backward cumulative err: 6.160823822021484
# DEBUG 3: backward cumulative err: 21.787975311279297
# DEBUG 3: backward cumulative err: 21.787975311279297
# DEBUG 4: forward cumulative err: 8.636998176574707
# DEBUG 4: forward cumulative err: 14.2478666305542
# DEBUG 4: forward cumulative err: 20.775121688842773
# DEBUG 3: backward cumulative err: 0.029810041189193726
# DEBUG 4: forward cumulative err: 0.0064862878061831
# DEBUG 4: forward cumulative err: 0.01439269632101059
# DEBUG 4: forward cumulative err: 0.10787465423345566
# DEBUG 4: forward cumulative err: 0.10787465423345566
# DEBUG 3: backward cumulative err: 7.241964340209961e-05
# DEBUG 3: backward cumulative err: 0.00031489133834838867
# DEBUG 3: backward cumulative err: 0.001141875982284546
# DEBUG 3: backward cumulative err: 0.001141875982284546
# DEBUG 4: forward cumulative err: 0.00023927586153149605
# DEBUG 4: forward cumulative err: 0.0005409494042396545
# DEBUG 4: forward cumulative err: 0.0018947701901197433
# DEBUG 4: forward cumulative err: 0.0018947701901197433
# DEBUG 3: backward cumulative err: 1.341104507446289e-06
# DEBUG 3: backward cumulative err: 3.406405448913574e-05
# DEBUG 3: backward cumulative err: 9.146332740783691e-05
# DEBUG 3: backward cumulative err: 9.146332740783691e-05
# DEBUG 4: forward cumulative err: 27.736343383789062
# DEBUG 4: forward cumulative err: 40.93864440917969
# DEBUG 4: forward cumulative err: 60.40238952636719
# DEBUG 4: forward cumulative err: 60.40238952636719
# DEBUG 3: backward cumulative err: 1.2666081190109253
# DEBUG 3: backward cumulative err: 5.283041477203369
# DEBUG 3: backward cumulative err: 18.874160766601562
# DEBUG 3: backward cumulative err: 18.874160766601562
# DEBUG 4: forward cumulative err: 4.0432305335998535
# DEBUG 4: forward cumulative err: 6.199853897094727
# DEBUG 4: forward cumulative err: 9.099577903747559
# DEBUG 4: forward cumulative err: 9.099577903747559
# DEBUG 3: backward cumulative err: 0.034158170223236084
# DEBUG 3: backward cumulative err: 0.1432134509086609
# DEBUG 3: backward cumulative err: 0.5137122869491577
# DEBUG 3: backward cumulative err: 0.5137122869491577
# DEBUG 4: forward cumulative err: 0.10096684843301773
# DEBUG 4: forward cumulative err: 0.253652423620224
# DEBUG 4: forward cumulative err: 0.561275839805603
# DEBUG 4: forward cumulative err: 0.561275839805603
# DEBUG 3: backward cumulative err: 0.000926971435546875
# DEBUG 3: backward cumulative err: 0.0038892030715942383
# DEBUG 3: backward cumulative err: 0.013882249593734741
# DEBUG 3: backward cumulative err: 0.013882249593734741
# DEBUG 4: forward cumulative err: 0.0027142008766531944
# DEBUG 4: forward cumulative err: 0.006294352933764458
# DEBUG 4: forward cumulative err: 0.018644794821739197
# DEBUG 4: forward cumulative err: 0.018644794821739197
# DEBUG 3: backward cumulative err: 2.5212764739990234e-05
# DEBUG 3: backward cumulative err: 0.0001506209373474121
# DEBUG 3: backward cumulative err: 0.0005372762680053711
# DEBUG 3: backward cumulative err: 0.0005372762680053711
# DEBUG 4: forward cumulative err: 0.00011291634291410446
# DEBUG 4: forward cumulative err: 0.00020091980695724487
# DEBUG 4: forward cumulative err: 0.00048813503235578537
# DEBUG 4: forward cumulative err: 0.00048813503235578537
# DEBUG 3: backward cumulative err: 2.682209014892578e-07
# DEBUG 3: backward cumulative err: 2.422928810119629e-05
# DEBUG 3: backward cumulative err: 8.687376976013184e-05
# DEBUG 3: backward cumulative err: 8.687376976013184e-05
# DEBUG 3: backward cumulative err: 0.04740375280380249
# DEBUG 3: backward cumulative err: 0.2000139355659485
# DEBUG 3: backward cumulative err: 0.7237963676452637
# DEBUG 3: backward cumulative err: 0.7237963676452637
# DEBUG 4: forward cumulative err: 0.14552032947540283
# DEBUG 4: forward cumulative err: 0.5248461961746216
# DEBUG 4: forward cumulative err: 0.9836390018463135
# DEBUG 4: forward cumulative err: 0.9836390018463135
# DEBUG 3: backward cumulative err: 0.001507401466369629
# DEBUG 3: backward cumulative err: 0.00638192892074585
# DEBUG 3: backward cumulative err: 0.023047983646392822
# DEBUG 3: backward cumulative err: 0.023047983646392822
# DEBUG 4: forward cumulative err: 0.004697511903941631
# DEBUG 4: forward cumulative err: 0.013396796770393848
# DEBUG 4: forward cumulative err: 0.053125713020563126
# DEBUG 4: forward cumulative err: 0.053125713020563126
# DEBUG 3: backward cumulative err: 5.042552947998047e-05
# DEBUG 3: backward cumulative err: 0.00021594762802124023
# DEBUG 3: backward cumulative err: 0.0007740259170532227
# DEBUG 3: backward cumulative err: 0.0007740259170532227
# DEBUG 4: forward cumulative err: 0.00017733685672283173
# DEBUG 4: forward cumulative err: 0.0004502388183027506
# DEBUG 4: forward cumulative err: 0.001350815175101161
# DEBUG 4: forward cumulative err: 0.001350815175101161
# DEBUG 3: backward cumulative err: 1.6093254089355469e-06
# DEBUG 3: backward cumulative err: 2.8192996978759766e-05
# DEBUG 3: backward cumulative err: 9.79304313659668e-05
# DEBUG 3: backward cumulative err: 9.79304313659668e-05
# DEBUG 4: forward cumulative err: 114.94129943847656
# DEBUG 4: forward cumulative err: 186.40538024902344
# DEBUG 4: forward cumulative err: 265.7981872558594
# DEBUG 4: forward cumulative err: 265.7981872558594
# DEBUG 3: backward cumulative err: 1.369139313697815
# DEBUG 3: backward cumulative err: 5.771234512329102
# DEBUG 3: backward cumulative err: 20.891664505004883
# DEBUG 3: backward cumulative err: 20.891664505004883
# DEBUG 4: forward cumulative err: 8.30952262878418
# DEBUG 4: forward cumulative err: 12.826772689819336
# DEBUG 4: forward cumulative err: 19.997116088867188
# DEBUG 4: forward cumulative err: 19.997116088867188
# DEBUG 3: backward cumulative err: 0.039971888065338135
# DEBUG 3: backward cumulative err: 0.1688365340232849
# DEBUG 3: backward cumulative err: 0.6115689873695374
# DEBUG 3: backward cumulative err: 0.6115689873695374
# DEBUG 4: forward cumulative err: 0.15831993520259857
# DEBUG 4: forward cumulative err: 0.7001327276229858
# DEBUG 4: forward cumulative err: 1.5502715110778809
# DEBUG 4: forward cumulative err: 1.5502715110778809
# DEBUG 3: backward cumulative err: 0.0011715888977050781
# DEBUG 3: backward cumulative err: 0.0049094557762146
# DEBUG 3: backward cumulative err: 0.01773861050605774
# DEBUG 3: backward cumulative err: 0.01773861050605774
# DEBUG 4: forward cumulative err: 0.0046407380141317844
# DEBUG 4: forward cumulative err: 0.012472892180085182
# DEBUG 4: forward cumulative err: 0.08200947940349579
# DEBUG 4: forward cumulative err: 0.08200947940349579
# DEBUG 3: backward cumulative err: 3.9696693420410156e-05
# DEBUG 3: backward cumulative err: 0.0001480579376220703
# DEBUG 3: backward cumulative err: 20.972381591796875
# DEBUG 3: backward cumulative err: 20.972381591796875
# DEBUG 4: forward cumulative err: 4.834185600280762
# DEBUG 4: forward cumulative err: 7.379298210144043
# DEBUG 4: forward cumulative err: 8.889888763427734
# DEBUG 4: forward cumulative err: 8.889888763427734
# DEBUG 3: backward cumulative err: 0.03998181223869324
# ...
# DEBUG 4: forward cumulative err: 0.047112949192523956
# DEBUG 4: forward cumulative err: 0.13971687853336334
# DEBUG 4: forward cumulative err: 0.3996487259864807
# DEBUG 4: forward cumulative err: 0.3996487259864807
# DEBUG 3: backward cumulative err: 0.0003559291362762451
# DEBUG 3: backward cumulative err: 0.0015791356563568115
# DEBUG 3: backward cumulative err: 0.005649656057357788
# DEBUG 3: backward cumulative err: 0.005649656057357788
# DEBUG 4: forward cumulative err: 0.001103665679693222
# DEBUG 4: forward cumulative err: 0.002653362462297082
# DEBUG 4: forward cumulative err: 0.012067180126905441
# DEBUG 4: forward cumulative err: 0.012067180126905441
# DEBUG 3: backward cumulative err: 7.510185241699219e-06
# DEBUG 3: backward cumulative err: 0.00012552738189697266
# DEBUG 3: backward cumulative err: 0.00043714046478271484
# DEBUG 3: backward cumulative err: 0.00043714046478271484
# DEBUG 4: forward cumulative err: 0.00011048559099435806
# DEBUG 4: forward cumulative err: 0.00016042962670326233
# DEBUG 4: forward cumulative err: 0.0003337475936859846
# DEBUG 4: forward cumulative err: 0.0003337475936859846
# DEBUG 3: backward cumulative err: 0.0
# DEBUG 3: backward cumulative err: 2.3484230041503906e-05
# DEBUG 3: backward cumulative err: 0.00014662742614746094
# DEBUG 3: backward cumulative err: 0.00014662742614746094
# DEBUG 4: forward cumulative err: 78.47618865966797
# DEBUG 4: forward cumulative err: 127.13429260253906
# DEBUG 4: forward cumulative err: 185.55606079101562
# DEBUG 4: forward cumulative err: 185.55606079101562
# DEBUG 3: backward cumulative err: 0.9753017425537109
# DEBUG 3: backward cumulative err: 4.147188186645508
# DEBUG 3: backward cumulative err: 15.170493125915527
# DEBUG 3: backward cumulative err: 15.170493125915527
# DEBUG 4: forward cumulative err: 5.1189775466918945
# DEBUG 4: forward cumulative err: 6.60424280166626
# DEBUG 4: forward cumulative err: 8.73086166381836
# DEBUG 4: forward cumulative err: 8.73086166381836
# DEBUG 3: backward cumulative err: 0.020178794860839844
# DEBUG 3: backward cumulative err: 0.08594858646392822
# DEBUG 3: backward cumulative err: 0.3147638738155365
# DEBUG 3: backward cumulative err: 0.3147638738155365
# DEBUG 4: forward cumulative err: 0.0771104246377945
# DEBUG 4: forward cumulative err: 0.18614841997623444
# DEBUG 4: forward cumulative err: 0.4134373664855957
# DEBUG 4: forward cumulative err: 0.4134373664855957
# DEBUG 3: backward cumulative err: 0.00042378902435302734
# DEBUG 3: backward cumulative err: 0.0018895864486694336
# DEBUG 3: backward cumulative err: 0.006929963827133179
# DEBUG 3: backward cumulative err: 0.006929963827133179
# DEBUG 4: forward cumulative err: 0.0018386325100436807
# DEBUG 4: forward cumulative err: 0.003216435667127371
# DEBUG 4: forward cumulative err: 0.011495785787701607
# DEBUG 4: forward cumulative err: 0.011495785787701607
# DEBUG 3: backward cumulative err: 6.705522537231445e-06
# DEBUG 3: backward cumulative err: 7.072091102600098e-05
# DEBUG 3: backward cumulative err: 0.00025337934494018555
# DEBUG 3: backward cumulative err: 0.00025337934494018555
# DEBUG 4: forward cumulative err: 7.660803385078907e-05
# DEBUG 4: forward cumulative err: 0.0001272681402042508
# DEBUG 4: forward cumulative err: 0.00020003248937427998
# DEBUG 4: forward cumulative err: 0.00020003248937427998
# DEBUG 3: backward cumulative err: 2.682209014892578e-07
# DEBUG 3: backward cumulative err: 2.2083520889282227e-05
# DEBUG 3: backward cumulative err: 8.079409599304199e-05
# DEBUG 3: backward cumulative err: 8.079409599304199e-05
# DEBUG 4: forward cumulative err: 35.89444351196289
# DEBUG 4: forward cumulative err: 58.23374938964844
# DEBUG 4: forward cumulative err: 89.7928466796875
# DEBUG 4: forward cumulative err: 89.7928466796875
# DEBUG 3: backward cumulative err: 0.9221959710121155
# DEBUG 3: backward cumulative err: 3.919774055480957
# DEBUG 3: backward cumulative err: 14.332403182983398
# DEBUG 3: backward cumulative err: 14.332403182983398
# DEBUG 4: forward cumulative err: 3.81406831741333
# DEBUG 4: forward cumulative err: 5.914796829223633
# DEBUG 4: forward cumulative err: 9.163573265075684
# DEBUG 4: forward cumulative err: 9.163573265075684
# DEBUG 3: backward cumulative err: 0.018030613660812378
# DEBUG 3: backward cumulative err: 0.07688537240028381
# DEBUG 3: backward cumulative err: 0.2814699113368988
# DEBUG 3: backward cumulative err: 0.2814699113368988
# DEBUG 4: forward cumulative err: 0.06630793958902359
# DEBUG 4: forward cumulative err: 0.21124044060707092
# DEBUG 4: forward cumulative err: 0.48614779114723206
# DEBUG 4: forward cumulative err: 0.48614779114723206
# DEBUG 3: backward cumulative err: 0.0003548860549926758
# DEBUG 3: backward cumulative err: 0.0015240907669067383
# DEBUG 3: backward cumulative err: 0.005545884370803833
# DEBUG 3: backward cumulative err: 0.005545884370803833
# DEBUG 4: forward cumulative err: 0.0012555918656289577
# DEBUG 4: forward cumulative err: 0.0035975626669824123
# DEBUG 4: forward cumulative err: 0.014584435150027275
# DEBUG 4: forward cumulative err: 0.014584435150027275
# DEBUG 3: backward cumulative err: 3.9637088775634766e-06
# DEBUG 3: backward cumulative err: 8.127093315124512e-05
# DEBUG 3: backward cumulative err: 0.0003434419631958008
# DEBUG 3: backward cumulative err: 0.0003434419631958008
# DEBUG 4: forward cumulative err: 0.00010714586824178696
# DEBUG 4: forward cumulative err: 0.00015543214976787567
# DEBUG 4: forward cumulative err: 0.0002986644394695759
# DEBUG 4: forward cumulative err: 0.0002986644394695759
# DEBUG 3: backward cumulative err: 0.0
# DEBUG 3: backward cumulative err: 1.9490718841552734e-05
# DEBUG 3: backward cumulative err: 8.100271224975586e-05
# DEBUG 3: backward cumulative err: 8.100271224975586e-05
# DEBUG 4: forward cumulative err: 28.72412109375
# DEBUG 4: forward cumulative err: 49.04393005371094
# DEBUG 4: forward cumulative err: 79.5036849975586
# DEBUG 4: forward cumulative err: 79.5036849975586
# DEBUG 3: backward cumulative err: 0.8745748400688171
# DEBUG 3: backward cumulative err: 3.715986490249634
# DEBUG 3: backward cumulative err: 13.580963134765625
# DEBUG 3: backward cumulative err: 13.580963134765625
# DEBUG 4: forward cumulative err: 3.3064024448394775
# DEBUG 4: forward cumulative err: 5.216146469116211
# DEBUG 4: forward cumulative err: 10.407938003540039
# DEBUG 4: forward cumulative err: 10.407938003540039
# DEBUG 3: backward cumulative err: 0.01620754599571228
# DEBUG 3: backward cumulative err: 0.06903591752052307
# DEBUG 3: backward cumulative err: 0.25288915634155273
# DEBUG 3: backward cumulative err: 0.25288915634155273
# DEBUG 4: forward cumulative err: 0.05960363149642944
# DEBUG 4: forward cumulative err: 0.2001200020313263
# DEBUG 4: forward cumulative err: 0.5881743431091309
# DEBUG 4: forward cumulative err: 0.5881743431091309
# DEBUG 3: backward cumulative err: 0.0002974271774291992
# DEBUG 3: backward cumulative err: 0.0013393163681030273
# DEBUG 3: backward cumulative err: 0.00471070408821106
# DEBUG 3: backward cumulative err: 0.00471070408821106
# DEBUG 4: forward cumulative err: 0.0010726992040872574
# DEBUG 4: forward cumulative err: 0.0036710482090711594
# DEBUG 4: forward cumulative err: 0.021321823820471764
# DEBUG 4: forward cumulative err: 0.021321823820471764
# DEBUG 3: backward cumulative err: 1.0192394256591797e-05
# DEBUG 3: backward cumulative err: 9.757280349731445e-05
# DEBUG 3: backward cumulative err: 0.00031751394271850586
# DEBUG 3: backward cumulative err: 0.00031751394271850586
# DEBUG 4: forward cumulative err: 8.453540795017034e-05
# DEBUG 4: forward cumulative err: 0.00011551305942703038
# DEBUG 4: forward cumulative err: 0.00044642173452302814
# DEBUG 4: forward cumulative err: 0.00044642173452302814
# DEBUG 3: backward cumulative err: 0.0
# DEBUG 3: backward cumulative err: 1.895427703857422e-05
# DEBUG 3: backward cumulative err: 8.147954940795898e-05
# DEBUG 3: backward cumulative err: 8.147954940795898e-05
# DEBUG 4: forward cumulative err: 26.873149871826172
# DEBUG 4: forward cumulative err: 47.743621826171875
# DEBUG 4: forward cumulative err: 69.8871078491211
# DEBUG 4: forward cumulative err: 69.8871078491211
# DEBUG 3: backward cumulative err: 1.1022961139678955
# DEBUG 3: backward cumulative err: 4.691773414611816
# DEBUG 3: backward cumulative err: 17.181556701660156
# DEBUG 3: backward cumulative err: 17.181556701660156
# DEBUG 4: forward cumulative err: 4.599595069885254
# DEBUG 4: forward cumulative err: 6.755717754364014
# DEBUG 4: forward cumulative err: 12.651771545410156
# DEBUG 4: forward cumulative err: 12.651771545410156
# DEBUG 3: backward cumulative err: 0.025834500789642334
# DEBUG 3: backward cumulative err: 0.11003386974334717
# DEBUG 3: backward cumulative err: 0.4029771089553833
# DEBUG 3: backward cumulative err: 0.4029771089553833
# DEBUG 4: forward cumulative err: 0.08456379175186157
# DEBUG 4: forward cumulative err: 0.23290963470935822
# DEBUG 4: forward cumulative err: 0.6012190580368042
# DEBUG 4: forward cumulative err: 0.6012190580368042
# DEBUG 3: backward cumulative err: 0.0006026923656463623
# DEBUG 3: backward cumulative err: 15.177755355834961
# DEBUG 4: forward cumulative err: 2.916337013244629
# DEBUG 4: forward cumulative err: 5.207067489624023
# DEBUG 4: forward cumulative err: 9.733481407165527
# DEBUG 4: forward cumulative err: 9.733481407165527
# DEBUG 3: backward cumulative err: 0.02018684148788452
# DEBUG 3: backward cumulative err: 0.08602875471115112
# DEBUG 3: backward cumulative err: 0.31480491161346436
# DEBUG 3: backward cumulative err: 0.31480491161346436
# DEBUG 4: forward cumulative err: 0.05558508634567261
# DEBUG 4: forward cumulative err: 0.19370850920677185
# DEBUG 4: forward cumulative err: 0.5546606779098511
# DEBUG 4: forward cumulative err: 0.5546606779098511
# DEBUG 3: backward cumulative err: 0.00041788816452026367
# DEBUG 3: backward cumulative err: 0.0018491148948669434
# DEBUG 3: backward cumulative err: 0.006753474473953247
# DEBUG 3: backward cumulative err: 0.006753474473953247
# DEBUG 4: forward cumulative err: 0.0011618752032518387
# DEBUG 4: forward cumulative err: 0.0033983890898525715
# DEBUG 4: forward cumulative err: 0.013755438849329948
# DEBUG 4: forward cumulative err: 0.013755438849329948
# DEBUG 3: backward cumulative err: 9.119510650634766e-06
# DEBUG 3: backward cumulative err: 0.00010198354721069336
# DEBUG 3: backward cumulative err: 0.00034552812576293945
# DEBUG 3: backward cumulative err: 0.00034552812576293945
# DEBUG 4: forward cumulative err: 0.00013545341789722443
# DEBUG 4: forward cumulative err: 0.00023379200138151646
# DEBUG 4: forward cumulative err: 0.0004361937753856182
# DEBUG 4: forward cumulative err: 0.0004361937753856182
# DEBUG 3: backward cumulative err: 0.0
# DEBUG 3: backward cumulative err: 2.205371856689453e-05
# DEBUG 3: backward cumulative err: 8.109211921691895e-05
# DEBUG 3: backward cumulative err: 8.109211921691895e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-da5cacace19a> in <module>
#     116     return hits/n
#     117
# --> 118 errs, stab, y_std, acc = run(train_loader, fit=True, max_iters=10000)
#
# <ipython-input-16-da5cacace19a> in run(data_iterable, fit, max_iters, model)
#      85         ## fit or predict
#      86         if fit:
# ---> 87             y_hat, stability = model(x, y)
#      88         else:
#      89             y_hat = model(x)
#
# <ipython-input-15-0416f58303bd> in __call__(self, x, y)
#     465             return y_hat
#     466         self.backward(y)
# --> 467         smd_pair_list = self.fit(x,y)
#     468         smallest_smd = self.__reduce_sherman_morrison_denominator_list(smd_pair_list)
#     469         self.fit_count += 1
#
# <ipython-input-15-0416f58303bd> in fit(self, x, y, eps)
#     421         sherman_morrison_denominator_list = []
#     422         for layer in self.layer_list:
# --> 423             forward_smd = layer.forward_fit()
#     424             backward_smd = layer.backward_fit()
#     425             sherman_morrison_denominator_list.append((forward_smd, backward_smd))
#
# <ipython-input-15-0416f58303bd> in forward_fit(self)
#     116             self.__validate_inputs(x=self.x_forward, y=self.y_backward, p=self.p, q=self.q)
#     117             x = torch.cat((torch.tensor([[1.]]), self.x_forward), dim=0)
# --> 118             self.xTx_inv, sm_denom = self.sherman_morrison(self.xTx_inv, x, x)
#     119             ##self.xTx_inv = self.reregularizer(self.xTx_inv, self.dlamdn) ## real online regularization too slow
#     120             self.xTy += torch.matmul(x, torch.transpose(self.y_backward, 0, 1))
#
# <ipython-input-15-0416f58303bd> in sherman_morrison(inv_mat, vec1, vec2)
#     267         denominator = 1. + torch.matmul(torch.matmul(v2t, inv_mat), vec1)
#     268         numerator = torch.matmul(torch.matmul(inv_mat, vec1), torch.matmul(v2t, inv_mat))
# --> 269         updated_inv_mat = inv_mat - numerator / denominator
#     270         return updated_inv_mat, float(denominator)
#     271     def __validate_inputs(self, p=None, q=None, lam=None, x=None, y=None, clip=None, dlamdn=None):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt 

print('acc')
plt.plot(acc[100:])
plt.show()
# Out:
# acc

# %%
print('errs')
plt.plot(errs)
plt.show()
# Out:
# errs

# %%
print('y_std')
plt.plot(y_std)
plt.show()
# Out:
# y_std

# %%
print('stab')
plt.plot(stab)
plt.show()
# Out:
# stab

# %%
## test dataset 
errs, stab, y_std, acc = run(test_loader, fit=False, max_iters=10000)
# Out:
# acc: 0.82253, err: 3.06964, y_std: 0.18998, stab: 1.00000: 100%|██████████| 10000/10000 [00:27<00:00, 360.17it/s]

# %% [markdown]
# # hypothesis test 1: does this solve catestrophic forgetting?
#
# Least squares' sufficient statistics have finite dimension and closed-form online update equations which guarantee perfect transfer learning.
# Our use of one least squares estimator per deep net layer enjoys a series of such sufficient statistics, but is only heuristically simlar to the mathematical guarantees of least squares.
# Nevertheless, we have proceeded hypothesizing some degree of a transfer learning benefit.
# In this section, we test this hypothesis.
#
# To test our hypothesis, we will subsample MNIST into two parts: initial and expanded.
# The initial portion will include digits 0 through 7, and expanded will only include digits 8 and 9.
# We will first fit our model to the initial dataset and then _transfer learn_ by fitting to the expanded dataset.
# If our hypothesis is true, transfer learning should be maintained and thus catastrophic forgetting avoided, so we'd expect the updated model to retain the ability to predict on digits 0 through 7.

# %%
## build data 
min_train_samples = 10000 
min_test_samples = 10000 

def hypothesis_1_sampler(data_loader, min_samples):
    '''
    randomly samples data for hypothesis test 1
    '''
    ## init empty datasets 
    initial = [] 
    expanded = [] 
    for pair in tqdm(data_loader): 
        if pair[1] > 7: 
            expanded.append(pair) 
        else: 
            initial.append(pair) 
            pass 
        if len(expanded) > min_samples and len(initial) > min_samples: 
            return initial, expanded 
    return initial, expanded 

train_initial, train_expanded = hypothesis_1_sampler(train_loader, min_train_samples) 
test_initial, test_expanded = hypothesis_1_sampler(test_loader, min_test_samples)
# Out:
#  85%|████████▍ | 50798/60000 [00:11<00:02, 4301.73it/s]
# 100%|██████████| 10000/10000 [00:02<00:00, 4441.27it/s]

# %% [markdown]
# #### Fitting on 0 through 7

# %%
## Get a fresh model 
hypothesis_1_model = OnlineNet( 
    layer_list = [ 
        OnlineDenseLayer(p=1*1*28*28, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=n_labels, activation=torch.sigmoid, activation_inverse=inv_sigmoid, lam=lam, clip=clip) 
    ], 
    reregularization_frequency = reregularization_frequency, 
    dlamdn = dlamdn 
) 

print('fit on 0-7') 
_, _, _, acc_train_initial = run(train_initial, fit=True, max_iters=10000, model=hypothesis_1_model)
# Out:
# acc: 0.85225, err: 4.09342, y_std: 0.08723, stab: 1.00033:  25%|██▍       | 10000/40798 [03:57<12:12, 42.04it/s]
# fit on 0-7

# %% [markdown]
# #### test on 0 through 7 before transfer learning

# %%
print('test on 0-7 before transfer learning') 
_, _, _, acc_test_initial_before = run(test_initial, fit=False, max_iters=10000, model=hypothesis_1_model)
# Out:
# acc: 0.85991, err: 3.10183, y_std: 0.18905, stab: 1.00000: 100%|██████████| 8017/8017 [00:21<00:00, 373.70it/s]
# test on 0-7 before transfer learning

# %% [markdown]
# #### fit on 8 and 9

# %%
## Things that haven't worked: 
## - matrix resizing 
## - iterating on temp matrices 

print('fit on 8-9') 
hypothesis_1_model_copy = hypothesis_1_model.copy() 
#hypothesis_1_model_copy.set_n_fits(0) 
#hypothesis_1_model_copy.reregularize(1.) 
_, _, _, acc_train_expanded = run(train_expanded, fit=True, max_iters=3000, model=hypothesis_1_model_copy) 
### hypothesis: copy broken, test: reassess test set 
#_, _, _, acc_test_initial_before = run(test_initial, fit=False, max_iters=10000, model=hypothesis_1_model_copy)
# Out:
# fit on 8-9
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
# DEBUG 1: err: 1879.08154296875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.08154296875
# DEBUG 1: err: 615.4923095703125
# DEBUG 2: err_forward: 0.0, err_backward: 615.4923095703125
# DEBUG 1: err: 1702.6961669921875
# DEBUG 2: err_forward: 0.0, err_backward: 1702.6961669921875
# DEBUG 1: err: 953.0318603515625
# DEBUG 2: err_forward: 0.0, err_backward: 953.0318603515625
# DEBUG 1: err: 1879.6748046875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.6748046875
# DEBUG 1: err: 1343.0159912109375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.0159912109375
# DEBUG 1: err: 1875.2518310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1875.2518310546875
# DEBUG 1: err: 790.6727294921875
# DEBUG 2: err_forward: 0.0, err_backward: 790.6727294921875
# DEBUG 1: err: 1701.51025390625
# DEBUG 2: err_forward: 0.0, err_backward: 1701.51025390625
# DEBUG 1: err: 955.7606201171875
# DEBUG 2: err_forward: 0.0, err_backward: 955.7606201171875
# DEBUG 1: err: 1874.9776611328125
# DEBUG 2: err_forward: 0.0, err_backward: 1874.9776611328125
# DEBUG 1: err: 1343.636474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.636474609375
# DEBUG 1: err: 1878.136474609375
# DEBUG 2: err_forward: 0.0, err_backward: 1878.136474609375
# DEBUG 1: err: 857.0662231445312
# DEBUG 2: err_forward: 0.0, err_backward: 857.0662231445312
# DEBUG 1: err: 1704.989013671875
# DEBUG 2: err_forward: 0.0, err_backward: 1704.989013671875
# DEBUG 1: err: 954.5746459960938
# DEBUG 2: err_forward: 0.0, err_backward: 954.5746459960938
# DEBUG 1: err: 1877.706298828125
# DEBUG 2: err_forward: 0.0, err_backward: 1877.706298828125
# DEBUG 1: err: 1338.9393310546875
# DEBUG 2: err_forward: 0.0, err_backward: 1338.9393310546875
# DEBUG 1: err: 1698.757080078125
# DEBUG 2: err_forward: 0.0, err_backward: 1698.757080078125
# DEBUG 1: err: 618.0260620117188
# DEBUG 2: err_forward: 0.0, err_backward: 618.0260620117188
# DEBUG 1: err: 2061.159423828125
# DEBUG 2: err_forward: 0.0, err_backward: 2061.159423828125
# DEBUG 1: err: 958.0534057617188
# DEBUG 2: err_forward: 0.0, err_backward: 958.0534057617188
# DEBUG 1: err: 1876.5203857421875
# DEBUG 2: err_forward: 0.0, err_backward: 1876.5203857421875
# DEBUG 1: err: 1341.6680908203125
# DEBUG 2: err_forward: 0.0, err_backward: 1341.6680908203125
# DEBUG 1: err: 1874.0599365234375
# DEBUG 2: err_forward: 0.0, err_backward: 1874.0599365234375
# DEBUG 1: err: 798.6466674804688
# DEBUG 2: err_forward: 0.0, err_backward: 798.6466674804688
# DEBUG 1: err: 1704.0440673828125
# DEBUG 2: err_forward: 0.0, err_backward: 1704.0440673828125
# DEBUG 1: err: 954.2236938476562
# DEBUG 2: err_forward: 0.0, err_backward: 954.2236938476562
# DEBUG 1: err: 1879.9991455078125
# DEBUG 2: err_forward: 0.0, err_backward: 1879.9991455078125
# DEBUG 1: err: 1340.482177734375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.482177734375
# DEBUG 1: err: 1876.7886962890625
# DEBUG 2: err_forward: 0.0, err_backward: 1876.7886962890625
# DEBUG 1: err: 773.9495239257812
# DEBUG 2: err_forward: 0.0, err_backward: 773.9495239257812
# DEBUG 1: err: 1704.6646728515625
# DEBUG 2: err_forward: 0.0, err_backward: 1704.6646728515625
# DEBUG 1: err: 957.1083984375
# DEBUG 2: err_forward: 0.0, err_backward: 957.1083984375
# DEBUG 1: err: 1876.16943359375
# DEBUG 2: err_forward: 0.0, err_backward: 1876.16943359375
# DEBUG 1: err: 1343.9609375
# DEBUG 2: err_forward: 0.0, err_backward: 1343.9609375
# DEBUG 1: err: 1875.602783203125
# DEBUG 2: err_forward: 0.0, err_backward: 1875.602783203125
# DEBUG 1: err: 596.67822265625
# DEBUG 2: err_forward: 0.0, err_backward: 596.67822265625
# DEBUG 1: err: 2059.967529296875
# DEBUG 2: err_forward: 0.0, err_backward: 2059.967529296875
# DEBUG 1: err: 957.72900390625
# DEBUG 2: err_forward: 0.0, err_backward: 957.72900390625
# DEBUG 1: err: 1879.05419921875
# DEBUG 2: err_forward: 0.0, err_backward: 1879.05419921875
# DEBUG 1: err: 1340.1312255859375
# DEBUG 2: err_forward: 0.0, err_backward: 1340.1312255859375
#   0%|          | 0/10001 [50:54<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4255f170a53a> in <module>
#       9 for layer in hypothesis_1_model_copy.layer_list:
#      10     layer.clip = 10.
# ---> 11 _, _, _, acc_train_expanded = run(train_expanded, fit=True, max_iters=3000, model=hypothesis_1_model_copy)
#      12 ### hypothesis: copy broken, test: reassess test set
#      13 #_, _, _, acc_test_initial_before = run(test_initial, fit=False, max_iters=10000, model=hypothesis_1_model_copy)
#
# <ipython-input-2-da5cacace19a> in run(data_iterable, fit, max_iters, model)
#      85         ## fit or predict
#      86         if fit:
# ---> 87             y_hat, stability = model(x, y)
#      88         else:
#      89             y_hat = model(x)
#
# <ipython-input-1-e5516c53c1b2> in __call__(self, x, y)
#     464             return y_hat
#     465         self.backward(y)
# --> 466         smd_pair_list = self.fit(x,y)
#     467         smallest_smd = self.__reduce_sherman_morrison_denominator_list(smd_pair_list)
#     468         self.fit_count += 1
#
# <ipython-input-1-e5516c53c1b2> in fit(self, x, y, eps)
#     408             self.set_ends(x,y)
#     409             for layer in self.layer_list:
# --> 410                 layer.forward_fit_temp()
#     411                 layer.backward_fit_temp()
#     412             self.set_ends(x,y)
#
# <ipython-input-1-e5516c53c1b2> in forward_fit_temp(self)
#     142             ##self.xTx_inv = self.reregularizer(self.xTx_inv, self.dlamdn) ## real online regularization too slow
#     143             self.xTy_temp = self.xTy + torch.matmul(x, torch.transpose(self.y_backward, 0, 1))
# --> 144             self.betaT_forward_temp = torch.matmul(self.xTx_inv_temp, self.xTy_temp)
#     145             self.betaT_forward_temp = torch.transpose(self.betaT_forward_temp, 0, 1)
#     146         return sm_denom
#
# KeyboardInterrupt:

# %% [markdown]
# #### test on 0 through 7 after transfer learning

# %%
print('test on 0-7 after transfer learning') 
_, _, _, acc_train_initial_after = run(test_initial, fit=False, max_iters=10000, model=hypothesis_1_model_copy)

# %% [markdown]
# #### test on 8 and 9 after transfer learning

# %%
print('test on 8-9 after transfer learning') 
_, _, _, acc_test_expanded = run(test_expanded, fit=False, max_iters=10000, model=hypothesis_1_model_copy)

# %% [markdown]
# # scratch space
#
# ideas
# - to improve accuracies:
#   - larger models, likely needs GPUs
#   - hyperparamter tuning: try different paths for $\frac{\partial \lambda}{\partial n}(n)$
# - to explore strength of transfer learning result
#   - compare against a good competing method
#   - ... $\leftarrow$ really need more here

# %%
## trying to improve accuracy: using a dense net architecture found online 
## this is turning-out to be difficult... 

lam = 100. 
dlamdn = 10. 
reregularization_frequency = 1000 
clip = 100. 

model_3 = OnlineNet( 
    layer_list = [ 
        OnlineDenseLayer(p=1*1*28*28, q=512, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=512, q=n_labels, activation=torch.sigmoid, activation_inverse=inv_sigmoid, lam=lam, clip=clip) 
    ], 
    reregularization_frequency = reregularization_frequency, 
    dlamdn = dlamdn 
) 

print('fit on train data') 
_, _, _, acc_3 = run(train_loader, fit=True, max_iters=10000, model=model_3)
# Out:
# acc: 0.76777, err: 4.23754, y_std: 0.09292, stab: 1.00047:  17%|█▋        | 10000/60000 [01:54<09:32, 87.30it/s]
# fit on train data

# %%
model_3_1 = model_3.copy() 
model_3_1.dlamdn = 100000 

_, _, _, acc_3_1 = run(train_loader, fit=True, max_iters=3000, model=model_3_1)
# Out:
# acc: 0.13335, err: 5.78938, y_std: 0.10098, stab: 1.00166:   5%|▌         | 3000/60000 [00:35<11:07, 85.40it/s]

# %%
## inspect 
p = train_initial[0]
x, y = build_data(p[0], p[1]) 
y_hat = model_3_1(x) 
torch.cat((y, y_hat), dim=1)
# Out:
# tensor([[0.0500, 0.7424],
#         [0.0500, 0.8904],
#         [0.0500, 0.8776],
#         [0.0500, 0.8693],
#         [0.0500, 0.7748],
#         [0.9500, 0.7470],
#         [0.0500, 0.8215],
#         [0.0500, 0.8227],
#         [0.0500, 0.7933],
#         [0.0500, 0.7836]])

# %%
## hypothesis 2: transfer learning is robust 
## fit on 8-9, then 0-7 

lam = 100. 
dlamdn = 10. 
reregularization_frequency = 1000 
clip = 100. 

model_4 = OnlineNet( 
    layer_list = [ 
        OnlineDenseLayer(p=1*1*28*28, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=n_labels, activation=torch.sigmoid, activation_inverse=inv_sigmoid, lam=lam, clip=clip) 
    ], 
    reregularization_frequency = reregularization_frequency, 
    dlamdn = dlamdn 
) 

print('fit on 8-9') 
_, _, _, _ = run(train_expanded, fit=True, max_iters=10000, model=model_4) 

print('test on 8-9') 
_, _, _, _ = run(test_expanded, fit=False, max_iters=10000, model=model_4) 

print('fit on 0-7') 
_, _, _, _ = run(train_initial, fit=True, max_iters=10000, model=model_4) 

print('test on 0-7') 
_, _, _, _ = run(test_initial, fit=False, max_iters=10000, model=model_4) 

print('test on 8-9') 
_, _, _, _ = run(test_expanded, fit=False, max_iters=10000, model=model_4)
# Out:
# acc: 0.80397, err: 4.42073, y_std: 0.06614, stab: 1.00017: 100%|█████████▉| 10000/10001 [01:10<00:00, 142.04it/s]
# acc: 0.76474, err: 4.31255, y_std: 0.07799, stab: 1.00000: 100%|██████████| 1983/1983 [00:05<00:00, 386.35it/s]
# acc: 0.00920, err: 4.74959, y_std: 0.01047, stab: 1.00009:  25%|██▍       | 10000/40798 [01:10<03:36, 142.38it/s]
# acc: 0.01686, err: 4.69201, y_std: 0.03374, stab: 1.00000: 100%|██████████| 8017/8017 [00:20<00:00, 385.09it/s]
# acc: 0.25299, err: 4.63899, y_std: 0.03366, stab: 1.00000: 100%|██████████| 1983/1983 [00:05<00:00, 392.06it/s]
# fit on 8-9
# test on 8-9
# fit on 0-7
# test on 0-7
# test on 8-9

# %%
## Does freezing lower layers help transfer learning? 

lam = 100. 
dlamdn = 10. 
reregularization_frequency = 1000 
clip = 100. 

model_5 = OnlineNet( 
    layer_list = [ 
        OnlineDenseLayer(p=1*1*28*28, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=n_labels, activation=torch.sigmoid, activation_inverse=inv_sigmoid, lam=lam, clip=clip) 
    ], 
    reregularization_frequency = reregularization_frequency, 
    dlamdn = dlamdn 
) 

#print('fit on 0-7') 
_, _, _, _ = run(train_initial, fit=True, max_iters=10000, model=model_5) 

#print('test on 0-7') 
_, _, _, _ = run(test_initial, fit=False, max_iters=10000, model=model_5) 

model_5.layer_list[0].trainable = False 
model_5.layer_list[1].trainable = False 
model_5.layer_list[2].trainable = False 

#print('fit on 8-9') 
_, _, _, _ = run(train_expanded, fit=True, max_iters=10000, model=model_5) 

#print('test on 8-9') 
_, _, _, _ = run(test_expanded, fit=False, max_iters=10000, model=model_5) 
#print('test on 0-7') 
_, _, _, _ = run(test_initial, fit=False, max_iters=10000, model=model_5)
# Out:
# acc: 0.66772, err: 4.67209, y_std: 0.02354, stab: 5.00000:  25%|██▍       | 10000/40798 [01:05<03:23, 151.59it/s]
# acc: 0.68942, err: 4.20784, y_std: 0.09580, stab: 1.00000: 100%|██████████| 8017/8017 [00:21<00:00, 381.67it/s]
# acc: 0.57032, err: 4.62903, y_std: 0.03707, stab: 5.00000: 100%|█████████▉| 10000/10001 [00:40<00:00, 245.54it/s]
# acc: 0.58905, err: 4.67013, y_std: 0.03525, stab: 1.00000: 100%|██████████| 1983/1983 [00:05<00:00, 371.48it/s]
# acc: 0.39470, err: 4.24401, y_std: 0.09614, stab: 1.00000: 100%|██████████| 8017/8017 [00:21<00:00, 380.89it/s]

# %%
## Does freezing lower layers help transfer learning? This time, without reregularization. 

lam = 100. 
dlamdn = 10. 
reregularization_frequency = 1000 
clip = 100. 

model_6 = OnlineNet( 
    layer_list = [ 
        OnlineDenseLayer(p=1*1*28*28, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=100, activation=leaky_relu, activation_inverse=inv_leaky_relu, lam=lam, clip=clip), 
        OnlineDenseLayer(p=100, q=n_labels, activation=torch.sigmoid, activation_inverse=inv_sigmoid, lam=lam, clip=clip) 
    ], 
    reregularization_frequency = reregularization_frequency, 
    dlamdn = dlamdn 
) 

#print('fit on 0-7') 
_, _, _, _ = run(train_initial, fit=True, max_iters=10000, model=model_6) 

#print('test on 0-7') 
_, _, _, _ = run(test_initial, fit=False, max_iters=10000, model=model_6) 

model_6.dlamdn = None 
model_6.layer_list[0].trainable = False 
model_6.layer_list[1].trainable = False 
model_6.layer_list[2].trainable = False 
model_6.layer_list[3].dlamdn = None 

#print('fit on 8-9') 
_, _, _, _ = run(train_expanded, fit=True, max_iters=10000, model=model_6) 

#print('test on 8-9') 
_, _, _, _ = run(test_expanded, fit=False, max_iters=10000, model=model_6) 
#print('test on 0-7') 
_, _, _, _ = run(test_initial, fit=False, max_iters=10000, model=model_6)
# Out:
# acc: 0.66772, err: 4.67209, y_std: 0.02354, stab: 5.00000:  25%|██▍       | 10000/40798 [01:08<03:30, 146.21it/s]
# acc: 0.68942, err: 4.20784, y_std: 0.09580, stab: 1.00000: 100%|██████████| 8017/8017 [00:21<00:00, 378.78it/s]
# acc: 0.57082, err: 4.62437, y_std: 0.03780, stab: 5.00000: 100%|█████████▉| 10000/10001 [00:36<00:00, 275.91it/s]
# acc: 0.59003, err: 4.65936, y_std: 0.03680, stab: 1.00000: 100%|██████████| 1983/1983 [00:05<00:00, 376.05it/s]
# acc: 0.39056, err: 4.23951, y_std: 0.09700, stab: 1.00000: 100%|██████████| 8017/8017 [00:21<00:00, 381.20it/s]

# %% [markdown]
# # Conclusion
#
# In theory, a least squares model should be capable of perfect transfer learning. That's not showing-up here. There's a little potential shown in

# %% [markdown]
# # scatch space
#
# $\hat \theta_{MLE} := \text{arg max}_\theta f_X(X; \theta) = \text{arg max}_\theta n^{-1} f_X(X; \theta) \to \text{arg max}_\theta \mathbb{E} f_X(X; \theta) \text{ as } {n \to \infty} $
#
# $\hat \beta := \text{arg min}_\beta \|y - x \beta \|^2 + \lambda(n) \| \beta \|^2 = \left( x^Tx + \lambda(n) \right)^{-1} x^Ty = \left(X_{n-1}^TX_{n-1} + x_n^T x_n + \lambda(n) \right)^{-1} \left(X_{n-1}^TY_{n-1} + x_n^T y_n \right) $
#
# $ = \frac{n}{n} \left( x^Tx + \lambda(n) \right)^{-1} x^Ty $
#
# $ = \left( \frac{x^Tx}{n} + \frac{\lambda(n)}{n} \right)^{-1} \frac{x^Ty}{n} $
#
# Apply the SLLN $\left( n^{-1}\sum_{i=1}^n X_i \to \mathbb{E}X_1 \text{ a.s. if } X_i \text{ iid} \right)$.
#
# $ = \left( \mathbb{E}X^TX + \frac{\lambda(n)}{n} \right)^{-1} \mathbb{E}X^TY $

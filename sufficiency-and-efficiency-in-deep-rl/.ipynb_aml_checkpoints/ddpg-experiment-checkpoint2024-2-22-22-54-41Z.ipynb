# %%
## Google's Generative AI search provided the initial draft of this code. 
## I have modified it since. 
## It provided these sources: 
## https://github.com/jk96491/RL_Algorithms?tab=readme-ov-file 
## https://github.com/abyaadrafid/Deep-Reinforcement-Learning 
## I couldn't find a draft of this code in the sources, 
## so Generative AI search may have generated the code. 
## Update: I expect the initial code was indeed AI-generated 
## because, while it looked correct, it was absolutely full 
## of mathematical failings. However, it looked good enough 
## to have me fooled at first glace - impressive! 

import random 
import numpy as np 
import gym
import torch
import torch.nn as nn
import torch.optim as optim 

torch.autograd.set_detect_anomaly(True) ## DEBUGGING 

class Object(object):
    pass

class ReplayBuffer(): 
    def __init__(self, capacity=10000): 
        self.n = 0 
        self.capacity = capacity 
        self.state_list = [] 
        self.action_list = [] 
        self.reward_list = [] 
        self.next_state_list = [] 
        self.done_list = [] 
        pass 
    def __len__(self):
         return self.n 
    def add(self, state, action, reward, next_state, done): 
        if self.n >= self.capacity: 
            ## discard earliest observation 
            self.state_list = self.state_list[1:] 
            self.action_list = self.action_list[1:] 
            self.reward_list = self.reward_list[1:] 
            self.next_state_list = self.next_state_list[1:] 
            self.done_list = self.done_list[1:] 
            self.n -= 1 
        pass 
        ## cast to torch  
        state = torch.tensor(state) 
        action = torch.tensor(action) 
        reward = torch.tensor(reward) 
        next_state = torch.tensor(next_state) 
        done = torch.tensor(done) 
        ## append to buffer 
        self.state_list.append(state) 
        self.action_list.append(action) 
        self.reward_list.append(reward) 
        self.next_state_list.append(next_state) 
        self.done_list.append(done) 
        self.n += 1 
        pass 
    def sample(self, batch_size=32): 
        ## sample lists 
        out = Object() ## transitions 
        out.state = [] 
        out.action = [] 
        out.reward = [] 
        out.next_state = [] 
        out.done = [] 
        for _ in range(batch_size): 
            idx = random.randint(0, self.n-1) 
            out.state.append(self.state_list[idx]) 
            out.action.append(self.action_list[idx]) 
            out.reward.append(self.reward_list[idx]) 
            out.next_state.append(self.next_state_list[idx]) 
            out.done.append(self.done_list[idx]) 
            pass 
        ## stack  
        out.state = torch.stack(out.state) 
        out.action = torch.stack(out.action) 
        out.reward = torch.stack(out.reward).reshape([-1,1]) 
        out.next_state = torch.stack(out.next_state) 
        out.done = torch.stack(out.done).reshape([-1,1]) 
        return out 
    pass 

# Define the actor and critic networks
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()

        self.fc1 = nn.Linear(state_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, state):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        action = torch.tanh(self.fc3(x))

        return action

class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        self.fc1 = nn.Linear(state_dim + action_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, state, action):
        x = torch.cat([state, action], dim=1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        value = self.fc3(x)

        return value

# Create the actor and critic networks
actor = Actor(state_dim=4, action_dim=1)
critic = Critic(state_dim=4, action_dim=1)
target_actor = Actor(state_dim=4, action_dim=1)
target_critic = Critic(state_dim=4, action_dim=1)
#actor = Actor(state_dim=2, action_dim=1)
#critic = Critic(state_dim=2, action_dim=1)

# Define the optimizers
actor_optimizer = optim.Adam(actor.parameters(), lr=1e-5)
critic_optimizer = optim.Adam(critic.parameters(), lr=1e-3)

# Create the replay buffer
replay_buffer = ReplayBuffer(capacity=100000) 

# Define the environment
env = gym.make('CartPole-v1')
#env = gym.make('MountainCarContinuous-v0') 

reward_list = [] 
p_list = [] # DEBUG 
TAU = -1 ## 0.05  
GAMMA = 0.99 

# Train the agent
for episode in range(1000):
    state = env.reset()
    target_actor.load_state_dict(actor.state_dict())
    target_critic.load_state_dict(critic.state_dict())

    for t in range(1000):
        action = actor(torch.tensor(state)) 
        if np.random.binomial(1, max(0,50-episode)/50) > 0: 
            ## random action
            action = torch.tensor(np.random.uniform(low=-1., high=1.)).reshape([1]) 
            pass 
        
        action_p = action.item() * .5 + .5 
        action_int = np.random.binomial(1, action_p) ## must be 0 or 1 
        #action_int = round(action_p) 
        next_state, reward, done, _ = env.step(action_int) 
        #next_state, reward, done, _ = env.step([action.item()]) 

        replay_buffer.add(state, action, reward, next_state, done) 

        if len(replay_buffer) > 1000: 
            # Sample a batch of transitions from the replay buffer 
            transitions = replay_buffer.sample(batch_size=256) 

            # Calculate the target Q-values
            target_Q = target_critic(transitions.next_state, target_actor(transitions.next_state))
            target_Q = (1 - transitions.done.int()) * target_Q.clone().detach() * GAMMA + transitions.reward 

            # Calculate the current Q-values
            current_Q = critic(transitions.state, transitions.action)

            # Calculate the critic loss
            critic_loss = torch.mean((target_Q - current_Q).pow(2)) 
            #critic_loss = nn.functional.smooth_l1_loss(target_Q, current_Q) 

            # Update the critic network 
            critic_optimizer.zero_grad() 
            critic_loss.backward() 
            critic_optimizer.step() 
            
            if len(replay_buffer) > 1000: 
                # Calculate the actor loss 
                actor_loss = -torch.mean(critic(transitions.state, actor(transitions.state))) 

                # Update the actor network 
                actor_optimizer.zero_grad() 
                actor_loss.backward() 
                actor_optimizer.step() 
            
            if TAU > 0: 
                ## smooth updates relative to target models 
                for param, target_param in zip(actor.parameters(), target_actor.parameters()): 
                    param.data = param.data * TAU + target_param.data * (1 - TAU) 
                for param, target_param in zip(critic.parameters(), target_critic.parameters()): 
                    param.data = param.data * TAU + target_param.data * (1 - TAU) 
                    pass 
                pass 

        state = next_state

        if done:
            break

    # Evaluate the agent
    episode_reward = 0 
    state = env.reset() 

    for t in range(1000): 
        action = actor(torch.tensor(state))

        action_p = action.item() * .5 + .5 
        action_int = np.random.binomial(1, action_p) ## must be 0 or 1
        #action_int = round(action_p) 
        next_state, reward, done, _ = env.step(action_int) 
        #next_state, reward, done, _ = env.step([action.item()])
        p_list.append(action.item()) # DEBUG 

        episode_reward += reward
        state = next_state 

        if done:
            break
    
    reward_list.append(episode_reward)
    print(f'Episode {episode}: {episode_reward}, len(replay_buffer): {len(replay_buffer)}')
# Out:
# /tmp/ipykernel_4192/215974007.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action = torch.tensor(action)
# Episode 0: 28.0, len(replay_buffer): 30
# Episode 1: 13.0, len(replay_buffer): 46
# Episode 2: 40.0, len(replay_buffer): 59
# Episode 3: 35.0, len(replay_buffer): 75
# Episode 4: 18.0, len(replay_buffer): 107
# Episode 5: 9.0, len(replay_buffer): 130
# Episode 6: 18.0, len(replay_buffer): 151
# Episode 7: 13.0, len(replay_buffer): 167
# Episode 8: 18.0, len(replay_buffer): 183
# Episode 9: 17.0, len(replay_buffer): 222
# Episode 10: 21.0, len(replay_buffer): 240
# Episode 11: 13.0, len(replay_buffer): 259
# Episode 12: 15.0, len(replay_buffer): 275
# Episode 13: 13.0, len(replay_buffer): 293
# Episode 14: 30.0, len(replay_buffer): 307
# Episode 15: 25.0, len(replay_buffer): 325
# Episode 16: 15.0, len(replay_buffer): 341
# Episode 17: 26.0, len(replay_buffer): 367
# Episode 18: 13.0, len(replay_buffer): 402
# Episode 19: 33.0, len(replay_buffer): 424
# Episode 20: 23.0, len(replay_buffer): 442
# Episode 21: 51.0, len(replay_buffer): 473
# Episode 22: 13.0, len(replay_buffer): 490
# Episode 23: 10.0, len(replay_buffer): 514
# Episode 24: 30.0, len(replay_buffer): 556
# Episode 25: 14.0, len(replay_buffer): 583
# Episode 26: 15.0, len(replay_buffer): 611
# Episode 27: 15.0, len(replay_buffer): 626
# Episode 28: 16.0, len(replay_buffer): 645
# Episode 29: 18.0, len(replay_buffer): 660
# Episode 30: 22.0, len(replay_buffer): 712
# Episode 31: 27.0, len(replay_buffer): 727
# Episode 32: 42.0, len(replay_buffer): 744
# Episode 33: 36.0, len(replay_buffer): 754
# Episode 34: 24.0, len(replay_buffer): 765
# Episode 35: 14.0, len(replay_buffer): 791
# Episode 36: 19.0, len(replay_buffer): 804
# Episode 37: 16.0, len(replay_buffer): 820
# Episode 38: 21.0, len(replay_buffer): 858
# Episode 39: 12.0, len(replay_buffer): 890
# Episode 40: 15.0, len(replay_buffer): 914
# Episode 41: 24.0, len(replay_buffer): 931
# Episode 42: 17.0, len(replay_buffer): 964
# Episode 43: 9.0, len(replay_buffer): 986
# Episode 44: 9.0, len(replay_buffer): 1014
# Episode 45: 31.0, len(replay_buffer): 1028
# Episode 46: 15.0, len(replay_buffer): 1049
# Episode 47: 25.0, len(replay_buffer): 1068
# Episode 48: 13.0, len(replay_buffer): 1079
# Episode 49: 29.0, len(replay_buffer): 1094
# Episode 50: 12.0, len(replay_buffer): 1107
# Episode 51: 15.0, len(replay_buffer): 1124
# Episode 52: 18.0, len(replay_buffer): 1138
# Episode 53: 10.0, len(replay_buffer): 1155
# Episode 54: 11.0, len(replay_buffer): 1173
# Episode 55: 11.0, len(replay_buffer): 1209
# Episode 56: 48.0, len(replay_buffer): 1233
# Episode 57: 18.0, len(replay_buffer): 1259
# Episode 58: 18.0, len(replay_buffer): 1269
# Episode 59: 20.0, len(replay_buffer): 1304
# Episode 60: 36.0, len(replay_buffer): 1323
# Episode 61: 30.0, len(replay_buffer): 1381
# Episode 62: 37.0, len(replay_buffer): 1399
# Episode 63: 12.0, len(replay_buffer): 1449
# Episode 64: 25.0, len(replay_buffer): 1495
# Episode 65: 46.0, len(replay_buffer): 1530
# Episode 66: 41.0, len(replay_buffer): 1603
# Episode 67: 75.0, len(replay_buffer): 1679
# Episode 68: 33.0, len(replay_buffer): 1742
# Episode 69: 28.0, len(replay_buffer): 1774
# Episode 70: 69.0, len(replay_buffer): 1793
# Episode 71: 49.0, len(replay_buffer): 1828
# Episode 72: 26.0, len(replay_buffer): 1914
# Episode 73: 25.0, len(replay_buffer): 1928
# Episode 74: 48.0, len(replay_buffer): 1976
# Episode 75: 49.0, len(replay_buffer): 2047
# Episode 76: 54.0, len(replay_buffer): 2086
# Episode 77: 21.0, len(replay_buffer): 2167
# Episode 78: 69.0, len(replay_buffer): 2267
# Episode 79: 70.0, len(replay_buffer): 2320
# Episode 80: 57.0, len(replay_buffer): 2419
# Episode 81: 84.0, len(replay_buffer): 2465
# Episode 82: 186.0, len(replay_buffer): 2532
# Episode 83: 70.0, len(replay_buffer): 2681
# Episode 84: 55.0, len(replay_buffer): 2741
# Episode 85: 35.0, len(replay_buffer): 2810
# Episode 86: 61.0, len(replay_buffer): 2842
# Episode 87: 51.0, len(replay_buffer): 2869
# Episode 88: 35.0, len(replay_buffer): 2907
# Episode 89: 49.0, len(replay_buffer): 2951
# Episode 90: 71.0, len(replay_buffer): 3019
# Episode 91: 102.0, len(replay_buffer): 3052
# Episode 92: 64.0, len(replay_buffer): 3126
# Episode 93: 149.0, len(replay_buffer): 3262
# Episode 94: 182.0, len(replay_buffer): 3418
# Episode 95: 144.0, len(replay_buffer): 3548
# Episode 96: 126.0, len(replay_buffer): 3651
# Episode 97: 102.0, len(replay_buffer): 3758
# Episode 98: 117.0, len(replay_buffer): 3847
# Episode 99: 140.0, len(replay_buffer): 3954
# Episode 100: 107.0, len(replay_buffer): 4055
# Episode 101: 122.0, len(replay_buffer): 4161
# Episode 102: 369.0, len(replay_buffer): 4262
# Episode 103: 230.0, len(replay_buffer): 4398
# Episode 104: 500.0, len(replay_buffer): 4597
# Episode 105: 167.0, len(replay_buffer): 4743
# Episode 106: 234.0, len(replay_buffer): 5064
# Episode 107: 179.0, len(replay_buffer): 5250
# Episode 108: 192.0, len(replay_buffer): 5425
# Episode 109: 238.0, len(replay_buffer): 5623
# Episode 110: 141.0, len(replay_buffer): 5835
# Episode 111: 152.0, len(replay_buffer): 5957
# Episode 112: 156.0, len(replay_buffer): 6131
# Episode 113: 127.0, len(replay_buffer): 6256
# Episode 114: 122.0, len(replay_buffer): 6375
# Episode 115: 125.0, len(replay_buffer): 6490
# Episode 116: 114.0, len(replay_buffer): 6587
# Episode 117: 178.0, len(replay_buffer): 6728
# Episode 118: 103.0, len(replay_buffer): 6884
# Episode 119: 112.0, len(replay_buffer): 7056
# Episode 120: 242.0, len(replay_buffer): 7165
# Episode 121: 146.0, len(replay_buffer): 7283
# Episode 122: 188.0, len(replay_buffer): 7401
# Episode 123: 138.0, len(replay_buffer): 7610
# Episode 124: 117.0, len(replay_buffer): 7717
# Episode 125: 139.0, len(replay_buffer): 7878
# Episode 126: 151.0, len(replay_buffer): 8080
# Episode 127: 127.0, len(replay_buffer): 8275
# Episode 128: 97.0, len(replay_buffer): 8456
# Episode 129: 179.0, len(replay_buffer): 8584
# Episode 130: 75.0, len(replay_buffer): 8692
# Episode 131: 92.0, len(replay_buffer): 8837
# Episode 132: 119.0, len(replay_buffer): 9034
# Episode 133: 126.0, len(replay_buffer): 9138
# Episode 134: 100.0, len(replay_buffer): 9231
# Episode 135: 130.0, len(replay_buffer): 9411
# Episode 136: 150.0, len(replay_buffer): 9619
# Episode 137: 162.0, len(replay_buffer): 9771
# Episode 138: 164.0, len(replay_buffer): 9946
# Episode 139: 155.0, len(replay_buffer): 10086
# Episode 140: 121.0, len(replay_buffer): 10247
# Episode 141: 134.0, len(replay_buffer): 10376
# Episode 142: 138.0, len(replay_buffer): 10490
# Episode 143: 116.0, len(replay_buffer): 10660
# Episode 144: 129.0, len(replay_buffer): 10760
# Episode 145: 113.0, len(replay_buffer): 10874
# Episode 146: 113.0, len(replay_buffer): 10984
# Episode 147: 167.0, len(replay_buffer): 11133
# Episode 148: 231.0, len(replay_buffer): 11281
# Episode 149: 114.0, len(replay_buffer): 11426
# Episode 150: 321.0, len(replay_buffer): 11578
# Episode 151: 139.0, len(replay_buffer): 11720
# Episode 152: 189.0, len(replay_buffer): 11853
# Episode 153: 136.0, len(replay_buffer): 11988
# Episode 154: 138.0, len(replay_buffer): 12125
# Episode 155: 111.0, len(replay_buffer): 12271
# Episode 156: 98.0, len(replay_buffer): 12410
# Episode 157: 108.0, len(replay_buffer): 12537
# Episode 158: 99.0, len(replay_buffer): 12623
# Episode 159: 95.0, len(replay_buffer): 12727
# Episode 160: 111.0, len(replay_buffer): 12825
# Episode 161: 106.0, len(replay_buffer): 12932
# Episode 162: 106.0, len(replay_buffer): 13041
# Episode 163: 103.0, len(replay_buffer): 13144
# Episode 164: 27.0, len(replay_buffer): 13249
# Episode 165: 139.0, len(replay_buffer): 13366
# Episode 166: 137.0, len(replay_buffer): 13496
# Episode 167: 111.0, len(replay_buffer): 13628
# Episode 168: 136.0, len(replay_buffer): 13762
# Episode 169: 115.0, len(replay_buffer): 13879
# Episode 170: 124.0, len(replay_buffer): 14006
# Episode 171: 105.0, len(replay_buffer): 14116
# Episode 172: 99.0, len(replay_buffer): 14226
# Episode 173: 108.0, len(replay_buffer): 14250
# Episode 174: 116.0, len(replay_buffer): 14277
# Episode 175: 108.0, len(replay_buffer): 14381
# Episode 176: 23.0, len(replay_buffer): 14512
# Episode 177: 102.0, len(replay_buffer): 14620
# Episode 178: 112.0, len(replay_buffer): 14730
# Episode 179: 135.0, len(replay_buffer): 14832
# Episode 180: 112.0, len(replay_buffer): 14947
# Episode 181: 111.0, len(replay_buffer): 15053
# Episode 182: 101.0, len(replay_buffer): 15170
# Episode 183: 109.0, len(replay_buffer): 15285
# Episode 184: 109.0, len(replay_buffer): 15402
# Episode 185: 112.0, len(replay_buffer): 15516
# Episode 186: 115.0, len(replay_buffer): 15558
# Episode 187: 120.0, len(replay_buffer): 15683
# Episode 188: 127.0, len(replay_buffer): 15808
# Episode 189: 111.0, len(replay_buffer): 15945
# Episode 190: 109.0, len(replay_buffer): 16053
# Episode 191: 103.0, len(replay_buffer): 16181
# Episode 192: 110.0, len(replay_buffer): 16281
# Episode 193: 118.0, len(replay_buffer): 16381
# Episode 194: 110.0, len(replay_buffer): 16498
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [20], line 185
#     181 critic_optimizer.step()
#     183 if len(replay_buffer) > 1000:
#     184     # Calculate the actor loss
# --> 185     actor_loss = -torch.mean(critic(transitions.state, actor(transitions.state)))
#     187     # Update the actor network
#     188     actor_optimizer.zero_grad()
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In [20], line 96, in Actor.forward(self, state)
#      95 def forward(self, state):
# ---> 96     x = torch.relu(self.fc1(state))
#      97     x = torch.relu(self.fc2(x))
#      98     action = torch.tanh(self.fc3(x))
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt


plt.plot(reward_list)
plt.show()

# %%
import matplotlib.pyplot as plt


plt.plot(p_list)
plt.show()

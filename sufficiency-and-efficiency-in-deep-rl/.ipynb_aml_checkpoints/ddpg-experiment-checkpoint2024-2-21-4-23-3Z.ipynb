# %%
## Google's Generative AI search provided the initial draft of this code. 
## I have modified it since. 
## It provided these sources: 
## https://github.com/jk96491/RL_Algorithms?tab=readme-ov-file 
## https://github.com/abyaadrafid/Deep-Reinforcement-Learning 
## I couldn't find a draft of this code in the sources, 
## so Generative AI search may have generated the code. 

import random 
import numpy as np 
import gym
import torch
import torch.nn as nn
import torch.optim as optim 

torch.autograd.set_detect_anomaly(True) ## DEBUGGING 

class Object(object):
    pass

class ReplayBuffer(): 
    def __init__(self, capacity=10000): 
        self.n = 0 
        self.capacity = capacity 
        self.state_list = [] 
        self.action_list = [] 
        self.reward_list = [] 
        self.next_state_list = [] 
        self.done_list = [] 
        pass 
    def __len__(self):
         return self.n 
    def add(self, state, action, reward, next_state, done): 
        if self.n >= self.capacity: 
            ## discard earliest observation 
            self.state_list = self.state_list[1:] 
            self.action_list = self.action_list[1:] 
            self.reward_list = self.reward_list[1:] 
            self.next_state_list = self.next_state_list[1:] 
            self.done_list = self.done_list[1:] 
            self.n -= 1 
        pass 
        ## cast to torch  
        state = torch.tensor(state) 
        action = torch.tensor(action) 
        reward = torch.tensor(reward) 
        next_state = torch.tensor(next_state) 
        done = torch.tensor(done) 
        ## append to buffer 
        self.state_list.append(state) 
        self.action_list.append(action) 
        self.reward_list.append(reward) 
        self.next_state_list.append(next_state) 
        self.done_list.append(done) 
        self.n += 1 
        pass 
    def sample(self, batch_size=32): 
        ## sample lists 
        out = Object() ## transitions 
        out.state = [] 
        out.action = [] 
        out.reward = [] 
        out.next_state = [] 
        out.done = [] 
        for _ in range(batch_size): 
            idx = random.randint(0, self.n-1) 
            out.state.append(self.state_list[idx]) 
            out.action.append(self.action_list[idx]) 
            out.reward.append(self.reward_list[idx]) 
            out.next_state.append(self.next_state_list[idx]) 
            out.done.append(self.done_list[idx]) 
            pass 
        ## stack  
        out.state = torch.stack(out.state) 
        out.action = torch.stack(out.action) 
        out.reward = torch.stack(out.reward) 
        out.next_state = torch.stack(out.next_state) 
        out.done = torch.stack(out.done) 
        return out 
    pass 

# Define the actor and critic networks
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()

        self.fc1 = nn.Linear(state_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, state):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        action = torch.tanh(self.fc3(x))

        return action

class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        self.fc1 = nn.Linear(state_dim + action_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, state, action):
        x = torch.cat([state, action], dim=1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        value = self.fc3(x)

        return value

# Create the actor and critic networks
actor = Actor(state_dim=4, action_dim=1)
critic = Critic(state_dim=4, action_dim=1)

# Define the optimizers
actor_optimizer = optim.Adam(actor.parameters(), lr=1e-5)
critic_optimizer = optim.Adam(critic.parameters(), lr=1e-3)

# Create the replay buffer
replay_buffer = ReplayBuffer(capacity=100000) 

# Define the environment
env = gym.make('CartPole-v1')

reward_list = [] 
p_list = [] # DEBUG 

# Train the agent
for episode in range(1000):
    state = env.reset()

    for t in range(1000):
        action = actor(torch.tensor(state)) 
        
        action_p = action.item() * .5 + .5 
        action_int = np.random.binomial(1, action_p) ## must be 0 or 1 
        #action_int = round(action_p)
        next_state, reward, done, _ = env.step(action_int) 

        replay_buffer.add(state, action, reward, next_state, done)

        if len(replay_buffer) > 1000:
            # Sample a batch of transitions from the replay buffer
            transitions = replay_buffer.sample(batch_size=128)

            # Calculate the target Q-values
            target_Q = critic(transitions.next_state, actor(transitions.next_state))
            target_Q = target_Q.clone().detach() * .99 + transitions.reward 

            # Calculate the current Q-values
            current_Q = critic(transitions.state, transitions.action)

            # Calculate the critic loss
            #critic_loss = torch.mean((target_Q - current_Q).pow(2)) 
            critic_loss = nn.functional.smooth_l1_loss(target_Q, current_Q)

            # Update the critic network
            critic_optimizer.zero_grad()
            critic_loss.backward()
            critic_optimizer.step()
            
            if len(replay_buffer) > 1000:
                # Calculate the actor loss
                actor_loss = -torch.mean(critic(transitions.state, actor(transitions.state)))

                # Update the actor network
                actor_optimizer.zero_grad()
                actor_loss.backward()
                actor_optimizer.step()

        state = next_state

        if done:
            break

    # Evaluate the agent
    episode_reward = 0 
    state = env.reset() 

    for t in range(1000): 
        action = actor(torch.tensor(state))

        action_p = action.item() * .5 + .5 
        action_int = np.random.binomial(1, action_p) ## must be 0 or 1
        #action_int = round(action_p) 
        next_state, reward, done, _ = env.step(action_int) 
        p_list.append(action_p) # DEBUG 

        episode_reward += reward

        if done:
            break
    
    reward_list.append(episode_reward)
    print(f'Episode {episode}: {episode_reward}, len(replay_buffer): {len(replay_buffer)}')
# Out:
# /tmp/ipykernel_4225/210018763.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action = torch.tensor(action)
# /tmp/ipykernel_4225/210018763.py:158: UserWarning: Using a target size (torch.Size([128, 1])) that is different to the input size (torch.Size([128, 128])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   critic_loss = nn.functional.smooth_l1_loss(target_Q, current_Q)
# Episode 0: 14.0, len(replay_buffer): 19
# Episode 1: 27.0, len(replay_buffer): 34
# Episode 2: 26.0, len(replay_buffer): 48
# Episode 3: 29.0, len(replay_buffer): 78
# Episode 4: 14.0, len(replay_buffer): 90
# Episode 5: 12.0, len(replay_buffer): 102
# Episode 6: 33.0, len(replay_buffer): 119
# Episode 7: 26.0, len(replay_buffer): 132
# Episode 8: 15.0, len(replay_buffer): 155
# Episode 9: 16.0, len(replay_buffer): 179
# Episode 10: 42.0, len(replay_buffer): 201
# Episode 11: 20.0, len(replay_buffer): 305
# Episode 12: 38.0, len(replay_buffer): 328
# Episode 13: 15.0, len(replay_buffer): 347
# Episode 14: 12.0, len(replay_buffer): 371
# Episode 15: 17.0, len(replay_buffer): 387
# Episode 16: 16.0, len(replay_buffer): 409
# Episode 17: 18.0, len(replay_buffer): 435
# Episode 18: 42.0, len(replay_buffer): 448
# Episode 19: 18.0, len(replay_buffer): 462
# Episode 20: 28.0, len(replay_buffer): 474
# Episode 21: 27.0, len(replay_buffer): 519
# Episode 22: 42.0, len(replay_buffer): 529
# Episode 23: 37.0, len(replay_buffer): 553
# Episode 24: 16.0, len(replay_buffer): 562
# Episode 25: 24.0, len(replay_buffer): 583
# Episode 26: 11.0, len(replay_buffer): 595
# Episode 27: 19.0, len(replay_buffer): 611
# Episode 28: 32.0, len(replay_buffer): 658
# Episode 29: 15.0, len(replay_buffer): 680
# Episode 30: 51.0, len(replay_buffer): 694
# Episode 31: 55.0, len(replay_buffer): 706
# Episode 32: 15.0, len(replay_buffer): 720
# Episode 33: 20.0, len(replay_buffer): 743
# Episode 34: 32.0, len(replay_buffer): 757
# Episode 35: 14.0, len(replay_buffer): 791
# Episode 36: 41.0, len(replay_buffer): 816
# Episode 37: 38.0, len(replay_buffer): 837
# Episode 38: 10.0, len(replay_buffer): 867
# Episode 39: 9.0, len(replay_buffer): 882
# Episode 40: 10.0, len(replay_buffer): 916
# Episode 41: 17.0, len(replay_buffer): 953
# Episode 42: 53.0, len(replay_buffer): 988
# Episode 43: 22.0, len(replay_buffer): 1004
# Episode 44: 109.0, len(replay_buffer): 1015
# Episode 45: 22.0, len(replay_buffer): 1027
# Episode 46: 16.0, len(replay_buffer): 1040
# Episode 47: 34.0, len(replay_buffer): 1062
# Episode 48: 10.0, len(replay_buffer): 1083
# Episode 49: 10.0, len(replay_buffer): 1147
# Episode 50: 43.0, len(replay_buffer): 1156
# Episode 51: 14.0, len(replay_buffer): 1167
# Episode 52: 10.0, len(replay_buffer): 1180
# Episode 53: 10.0, len(replay_buffer): 1202
# Episode 54: 10.0, len(replay_buffer): 1214
# Episode 55: 16.0, len(replay_buffer): 1223
# Episode 56: 11.0, len(replay_buffer): 1238
# Episode 57: 12.0, len(replay_buffer): 1251
# Episode 58: 15.0, len(replay_buffer): 1261
# Episode 59: 11.0, len(replay_buffer): 1271
# Episode 60: 11.0, len(replay_buffer): 1283
# Episode 61: 13.0, len(replay_buffer): 1295
# Episode 62: 10.0, len(replay_buffer): 1305
# Episode 63: 10.0, len(replay_buffer): 1315
# Episode 64: 11.0, len(replay_buffer): 1325
# Episode 65: 12.0, len(replay_buffer): 1336
# Episode 66: 8.0, len(replay_buffer): 1346
# Episode 67: 10.0, len(replay_buffer): 1354
# Episode 68: 10.0, len(replay_buffer): 1363
# Episode 69: 11.0, len(replay_buffer): 1372
# Episode 70: 13.0, len(replay_buffer): 1383
# Episode 71: 8.0, len(replay_buffer): 1393
# Episode 72: 10.0, len(replay_buffer): 1402
# Episode 73: 11.0, len(replay_buffer): 1412
# Episode 74: 9.0, len(replay_buffer): 1422
# Episode 75: 10.0, len(replay_buffer): 1432
# Episode 76: 10.0, len(replay_buffer): 1442
# Episode 77: 15.0, len(replay_buffer): 1452
# Episode 78: 9.0, len(replay_buffer): 1462
# Episode 79: 9.0, len(replay_buffer): 1470
# Episode 80: 9.0, len(replay_buffer): 1482
# Episode 81: 10.0, len(replay_buffer): 1492
# Episode 82: 10.0, len(replay_buffer): 1502
# Episode 83: 9.0, len(replay_buffer): 1511
# Episode 84: 10.0, len(replay_buffer): 1521
# Episode 85: 10.0, len(replay_buffer): 1530
# Episode 86: 11.0, len(replay_buffer): 1540
# Episode 87: 10.0, len(replay_buffer): 1549
# Episode 88: 11.0, len(replay_buffer): 1558
# Episode 89: 9.0, len(replay_buffer): 1566
# Episode 90: 9.0, len(replay_buffer): 1576
# Episode 91: 8.0, len(replay_buffer): 1584
# Episode 92: 10.0, len(replay_buffer): 1593
# Episode 93: 9.0, len(replay_buffer): 1603
# Episode 94: 11.0, len(replay_buffer): 1611
# Episode 95: 10.0, len(replay_buffer): 1619
# Episode 96: 9.0, len(replay_buffer): 1629
# Episode 97: 10.0, len(replay_buffer): 1639
# Episode 98: 8.0, len(replay_buffer): 1649
# Episode 99: 9.0, len(replay_buffer): 1658
# Episode 100: 9.0, len(replay_buffer): 1667
# Episode 101: 9.0, len(replay_buffer): 1680
# Episode 102: 9.0, len(replay_buffer): 1689
# Episode 103: 10.0, len(replay_buffer): 1698
# Episode 104: 13.0, len(replay_buffer): 1708
# Episode 105: 10.0, len(replay_buffer): 1716
# Episode 106: 9.0, len(replay_buffer): 1725
# Episode 107: 12.0, len(replay_buffer): 1733
# Episode 108: 10.0, len(replay_buffer): 1741
# Episode 109: 10.0, len(replay_buffer): 1750
# Episode 110: 8.0, len(replay_buffer): 1759
# Episode 111: 8.0, len(replay_buffer): 1768
# Episode 112: 9.0, len(replay_buffer): 1777
# Episode 113: 11.0, len(replay_buffer): 1785
# Episode 114: 11.0, len(replay_buffer): 1796
# Episode 115: 9.0, len(replay_buffer): 1805
# Episode 116: 9.0, len(replay_buffer): 1813
# Episode 117: 9.0, len(replay_buffer): 1822
# Episode 118: 9.0, len(replay_buffer): 1832
# Episode 119: 10.0, len(replay_buffer): 1841
# Episode 120: 10.0, len(replay_buffer): 1850
# Episode 121: 10.0, len(replay_buffer): 1859
# Episode 122: 9.0, len(replay_buffer): 1868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [81], line 162
#     160 # Update the critic network
#     161 critic_optimizer.zero_grad()
# --> 162 critic_loss.backward()
#     163 critic_optimizer.step()
#     165 if len(replay_buffer) > 1000:
#     166     # Calculate the actor loss
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt


plt.plot(reward_list)
plt.show()

# %%
import matplotlib.pyplot as plt


plt.plot(p_list)
plt.show()

# %% [markdown]
# # Optimized LLM Fine Tuning Experiment
#
# My sufficient statistic regularizer (SSR) framework and associated theory provides optimal statistical efficiency guarantees.
# The applied impact of improved statistical efficiency must be observed; it can't be derived.
# In this experiment, I try to see if something new is possible: LLM tuning with very small datasets.
# For example, could an agent learn from a single user?
# Can information be retained in model parameters so retrieval isn't limited by context windows?
# We have to try and see.

# %% [markdown]
# ### Learning `torch.distributed`

# %%
import subprocess
import sys
import os
import shutil 

def run_torch_script(script_path, nproc, *args): 
    """Finds the correct torchrun and runs the script."""
    python_executable = sys.executable
    torchrun_executable = shutil.which("torchrun", path=f"{os.path.dirname(python_executable)}") 

    command = [torchrun_executable, "--nnodes=1", f"--nproc_per_node={nproc}", script_path] + list(map(str, args)) 

    print("Running: " + " ".join(command))
    
    result = subprocess.run(command, text=True, capture_output=True)
    
    print("\n--- Script Output ---")
    if result.stdout:
        print(result.stdout)
    
    if result.stderr:
        print("\n--- Script Errors ---")
        print(result.stderr)

    return result.returncode

# %%
# Run it:
run_torch_script("torch_dist_example.py", nproc=4)
# Out:
# Running: /anaconda/envs/azureml_py310_sdkv2/bin/torchrun --nnodes=1 --nproc_per_node=4 torch_dist_example.py
#
# --- Script Output ---
# Rank 2 initialized and waiting at barrier.
# Rank 1 initialized and waiting at barrier.
# Rank 0 initialized and waiting at barrier.
# Rank 2 initialized and waiting at barrier.
# Rank 3 initialized and waiting at barrier.
# Rank 0 initialized and waiting at barrier.
# Rank 3 initialized and waiting at barrier.
# Rank 0 initialized and waiting at barrier.
# Rank 2 initialized and waiting at barrier.
#
#
# --- Script Errors ---
# W0301 17:09:40.884928 6711 site-packages/torch/distributed/run.py:792]
# W0301 17:09:40.884928 6711 site-packages/torch/distributed/run.py:792] *****************************************
# W0301 17:09:40.884928 6711 site-packages/torch/distributed/run.py:792] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0301 17:09:40.884928 6711 site-packages/torch/distributed/run.py:792] *****************************************
# [W301 17:09:40.658974730 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:09:40.663524048 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:04.492344693 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:04.499264220 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:04.723715386 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:04.730269211 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:04.752135696 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:04.756231812 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.879625988 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.884092905 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.950984050 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.956036367 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.073143758 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.080436983 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.131974955 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.135449167 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.151535120 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.156509937 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.190172750 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.193014059 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.196100969 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.200327384 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.276251337 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.280628452 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.295259701 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.299537915 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.325746803 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.327048907 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.328263811 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.330522119 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.337193941 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.341982257 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.398798447 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W301 17:10:05.403366762 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# W0301 17:10:06.034268 6718 site-packages/torch/multiprocessing/spawn.py:169] Terminating process 6723 via signal SIGTERM
# W0301 17:10:06.034943 6718 site-packages/torch/multiprocessing/spawn.py:169] Terminating process 6724 via signal SIGTERM
# W0301 17:10:06.035239 6718 site-packages/torch/multiprocessing/spawn.py:169] Terminating process 6725 via signal SIGTERM
# Traceback (most recent call last):
#   File "/mnt/batch/tasks/shared/LS_root/mounts/clusters/wdurno2/code/Users/wdurno/notebooks/sufficiency-and-efficiency-in-deep-rl/llm-sketches/llama3-8b/torch_dist_example.py", line 36, in <module>
#     torch.multiprocessing.spawn(all_reduce_example, args=(world_size,), nprocs=world_size, join=True)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 340, in spawn
#     return start_processes(fn, args, nprocs, join, daemon, start_method="spawn")
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 296, in start_processes
#     while not context.join():
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 215, in join
#     raise ProcessRaisedException(msg, error_index, failed_process.pid)
# torch.multiprocessing.spawn.ProcessRaisedException:
#
# -- Process 0 terminated with the following error:
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 90, in _wrap
#     fn(i, *args)
#   File "/mnt/batch/tasks/shared/LS_root/mounts/clusters/wdurno2/code/Users/wdurno/notebooks/sufficiency-and-efficiency-in-deep-rl/llm-sketches/llama3-8b/torch_dist_example.py", line 18, in all_reduce_example
#     dist.barrier()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
#     return func(*args, **kwargs)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py", line 4556, in barrier
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:534] Connection closed by peer [127.0.0.1]:5043
#
# W0301 17:10:07.032050 6717 site-packages/torch/multiprocessing/spawn.py:169] Terminating process 6728 via signal SIGTERM
# W0301 17:10:07.032628 6717 site-packages/torch/multiprocessing/spawn.py:169] Terminating process 6729 via signal SIGTERM
# W0301 17:10:07.032941 6717 site-packages/torch/multiprocessing/spawn.py:169] Terminating process 6731 via signal SIGTERM
# Traceback (most recent call last):
#   File "/mnt/batch/tasks/shared/LS_root/mounts/clusters/wdurno2/code/Users/wdurno/notebooks/sufficiency-and-efficiency-in-deep-rl/llm-sketches/llama3-8b/torch_dist_example.py", line 36, in <module>
#     torch.multiprocessing.spawn(all_reduce_example, args=(world_size,), nprocs=world_size, join=True)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 340, in spawn
#     return start_processes(fn, args, nprocs, join, daemon, start_method="spawn")
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 296, in start_processes
#     while not context.join():
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 215, in join
#     raise ProcessRaisedException(msg, error_index, failed_process.pid)
# torch.multiprocessing.spawn.ProcessRaisedException:
#
# -- Process 0 terminated with the following error:
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/multiprocessing/spawn.py", line 90, in _wrap
#     fn(i, *args)
#   File "/mnt/batch/tasks/shared/LS_root/mounts/clusters/wdurno2/code/Users/wdurno/notebooks/sufficiency-and-efficiency-in-deep-rl/llm-sketches/llama3-8b/torch_dist_example.py", line 18, in all_reduce_example
#     dist.barrier()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
#     return func(*args, **kwargs)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py", line 4556, in barrier
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:525] Read error [127.0.0.1]:5043: Connection reset by peer
#
# W0301 17:10:07.227044 6711 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 6716 closing signal SIGTERM
# W0301 17:10:07.227627 6711 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 6717 closing signal SIGTERM
# W0301 17:10:07.227939 6711 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 6719 closing signal SIGTERM
# E0301 17:10:07.328108 6711 site-packages/torch/distributed/elastic/multiprocessing/api.py:869] failed (exitcode: 1) local_rank: 2 (pid: 6718) of binary: /anaconda/envs/azureml_py310_sdkv2/bin/python
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py310_sdkv2/bin/torchrun", line 8, in <module>
#     sys.exit(main())
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/elastic/multiprocessing/errors/__init__.py", line 355, in wrapper
#     return f(*args, **kwargs)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/run.py", line 918, in main
#     run(args)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/run.py", line 909, in run
#     elastic_launch(
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/launcher/api.py", line 138, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/torch/distributed/launcher/api.py", line 269, in launch_agent
#     raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# torch_dist_example.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2025-03-01_17:10:07
#   host      : localhost
#   rank      : 2 (local_rank: 2)
#   exitcode  : 1 (pid: 6718)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================
# 1

# %% [markdown]
# # Optimized LLM Fine Tuning Experiment
#
# My sufficient statistic regularizer (SSR) framework and associated theory provides optimal statistical efficiency guarantees.
# The applied impact of improved statistical efficiency must be observed; it can't be derived.
# In this experiment, I try to see if something new is possible: LLM tuning with very small datasets.
# For example, could an agent learn from a single user?
# Can information be retained in model parameters so retrieval isn't limited by context windows?
# We have to try and see.

# %% [markdown]
# ### Learning `torch.distributed`

# %%
import subprocess
import sys
import os
import shutil 

def run_torch_script(script_path, nproc, *args): 
    """Finds the correct torchrun and runs the script."""
    python_executable = sys.executable
    torchrun_executable = shutil.which("torchrun", path=f"{os.path.dirname(python_executable)}") 

    command = [torchrun_executable, "--nnodes=1", f"--nproc_per_node={nproc}", script_path] + list(map(str, args)) 

    print("Running: " + " ".join(command))
    
    result = subprocess.run(command, text=True, capture_output=True)
    
    print("\n--- Script Output ---")
    if result.stdout:
        print(result.stdout)
    
    if result.stderr:
        print("\n--- Script Errors ---")
        print(result.stderr)

    return result.returncode

# %%
# Run it:
os.environ["TORCH_DISTRIBUTED_DEBUG"] = "DETAIL" ## Debugging 
run_torch_script("torch_dist_example.py", nproc=2)
# Out:
# Running: /anaconda/envs/azureml_py310_sdkv2/bin/torchrun --nnodes=1 --nproc_per_node=2 torch_dist_example.py
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 # Run it:
#       2 os.environ["TORCH_DISTRIBUTED_DEBUG"] = "DETAIL" ## Debugging
# ----> 3 run_torch_script("torch_dist_example.py", nproc=2)
#
# Input In [1], in run_torch_script(script_path, nproc, *args)
#      11 command = [torchrun_executable, "--nnodes=1", f"--nproc_per_node={nproc}", script_path] + list(map(str, args))
#      13 print("Running: " + " ".join(command))
# ---> 15 result = subprocess.run(command, text=True, capture_output=True)
#      17 print("\n--- Script Output ---")
#      18 if result.stdout:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
# --> 503         stdout, stderr = process.communicate(input, timeout=timeout)
#     504     except TimeoutExpired as exc:
#     505         process.kill()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/subprocess.py:1152, in Popen.communicate(self, input, timeout)
#    1149     endtime = None
#    1151 try:
# -> 1152     stdout, stderr = self._communicate(input, endtime, timeout)
#    1153 except KeyboardInterrupt:
#    1154     # https://bugs.python.org/issue25942
#    1155     # See the detailed comment in .wait().
#    1156     if timeout is not None:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/subprocess.py:2003, in Popen._communicate(self, input, endtime, orig_timeout)
#    1996     self._check_timeout(endtime, orig_timeout,
#    1997                         stdout, stderr,
#    1998                         skip_check_and_raise=True)
#    1999     raise RuntimeError(  # Impossible :)
#    2000         '_check_timeout(..., skip_check_and_raise=True) '
#    2001         'failed to raise TimeoutExpired.')
# -> 2003 ready = selector.select(timeout)
#    2004 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2006 # XXX Rewrite these to use non-blocking I/O on the file
#    2007 # objects; they are no longer using C stdio!
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

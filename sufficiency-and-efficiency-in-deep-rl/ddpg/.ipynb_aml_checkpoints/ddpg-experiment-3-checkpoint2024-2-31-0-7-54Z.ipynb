# %%
## try adding memory to these agents 

import random 
import numpy as np 
import gym 
import torch 
import torch.nn as nn 
import torch.optim as optim 
from lanczos import l_lanczos, combine_krylov_spaces 

GAMMA = .99 

class Object(object):
    pass

class ReplayBuffer(): 
    def __init__(self, capacity=10000): 
        self.n = 0 
        self.capacity = capacity 
        self.state_list = [] 
        self.action_list = [] 
        self.reward_list = [] 
        self.next_state_list = [] 
        self.done_list = [] 
        pass 
    def __len__(self):
         return self.n 
    def add(self, state, action, reward, next_state, done): 
        if self.n >= self.capacity: 
            ## discard earliest observation 
            self.state_list = self.state_list[1:] 
            self.action_list = self.action_list[1:] 
            self.reward_list = self.reward_list[1:] 
            self.next_state_list = self.next_state_list[1:] 
            self.done_list = self.done_list[1:] 
            self.n -= 1 
        pass 
        ## cast to torch  
        state = torch.tensor(state) 
        action = torch.tensor(action) 
        reward = torch.tensor(reward) 
        next_state = torch.tensor(next_state) 
        done = torch.tensor(done) 
        ## append to buffer 
        self.state_list.append(state) 
        self.action_list.append(action) 
        self.reward_list.append(reward) 
        self.next_state_list.append(next_state) 
        self.done_list.append(done) 
        self.n += 1 
        pass 
    def sample(self, batch_size=32, idx_list=None): 
        ## sample lists 
        out = Object() ## transitions 
        out.state = [] 
        out.action = [] 
        out.reward = [] 
        out.next_state = [] 
        out.done = [] 
        if idx_list is not None: 
            batch_size = len(idx_list) 
        for i in range(batch_size): 
            if idx_list is None: 
                idx = random.randint(0, self.n-1) 
            else: 
                idx = idx_list[i]
                pass 
            out.state.append(self.state_list[idx]) 
            out.action.append(self.action_list[idx]) 
            out.reward.append(self.reward_list[idx]) 
            out.next_state.append(self.next_state_list[idx]) 
            out.done.append(self.done_list[idx]) 
            pass 
        ## stack  
        out.state = torch.stack(out.state) 
        out.action = torch.stack(out.action) 
        out.reward = torch.stack(out.reward).reshape([-1,1]) 
        out.next_state = torch.stack(out.next_state) 
        out.done = torch.stack(out.done).reshape([-1,1]) 
        return out 
    def clear(self, n=None): 
        'clears first `n` transitions, or all if `n is None`'
        if n is None: 
            n = self.n 
            pass 
        self.state_list = self.state_list[n:] 
        self.action_list = self.action_list[n:] 
        self.reward_list = self.reward_list[n:] 
        self.next_state_list = self.next_state_list[n:] 
        self.done_list = self.done_list[n:] 
        self.n = len(self.state_list) 
        pass 
    pass 

# Define the actor and critic networks 
class SSRAgent(nn.Module): 
    def __init__(self, replay_buffer, ssr_rank=2): 
        super(SSRAgent, self).__init__() 
        self.ssr_rank = ssr_rank 
        self.ssr_low_rank_matrix = None ## =: A 
        self.ssr_residual_diagonal = None ## =: resid 
        self.ssr_center = None 
        self.ssr_prev_center = None 
        self.ssr_n = None 
        ## N * Fisher Information \approx AA^T + resid 
        self.ssr_model_dimension = None 
        self.replay_buffer = replay_buffer 
        pass 
    def loss(self, transitions): 
        raise NotImplementedError('ERROR: loss not implemented!') 
    def memorize(self, n=None): 
        'memorize oldest `n` transitions, or all if `n is None`' 
        self.ssr_prev_center = self.ssr_center 
        self.ssr_center = self.__get_param() ## elliptical centroid 
        if self.ssr_model_dimension is None: 
            self.ssr_model_dimension = self.ssr_center.shape[0] 
            pass 
        ssr_low_rank_matrix, ssr_residual_diagonal = l_lanczos(self.__get_get_grad_generator(n), self.ssr_rank, self.ssr_model_dimension, calc_diag=True) 
        if self.ssr_low_rank_matrix is None: 
            ## first memorization 
            self.ssr_low_rank_matrix = ssr_low_rank_matrix 
            self.ssr_residual_diagonal = ssr_residual_diagonal 
            self.ssr_n = n 
        else: 
            ## combine with previous memories 
            self.ssr_low_rank_matrix = combine_krylov_spaces(self.ssr_low_rank_matrix, ssr_low_rank_matrix) 
            self.ssr_residual_diagonal += ssr_residual_diagonal 
            self.ssr_n += n 
            pass 
        pass 
    def ssr(self, lmbda=None): 
        '''Get the ssr regularizer. If `lmbda is None`, `lmbda` will be set to 1 when `self.ssr_prev_center is None`, 
        otherwise `lmbda` will be the approximately optimal `n_A` value.'''
        if self.ssr_low_rank_matrix is None: 
            return 0. 
        if lmbda is None: 
            lmbda = 1. 
            pass 
        p = self.__get_param() 
        p0 = self.ssr_center 
        d = p - p0 
        A = self.ssr_low_rank_matrix 
        res = self.ssr_residual_diagonal 
        dTA = d.transpose(0,1).matmul(A) 
        ATd = dTA.transpose(0,1) 
        dTresd = (d.transpose(0,1) * res).matmul(d) 
        ssr_sum = dTA.matmul(ATd) + dTresd 
        if lmbda is None: 
            if self.ssr_prev_center is None: 
                lmbda = 1. 
            else: 
                ## approximately optimal lambda 
                dt = p0 - self.ssr_prev_center 
                dtTA = dt.transpose(0,1).matmul(A) 
                ATdt = dtTA.transpose(0,1) 
                dtTresdt = (dt.transpose(0,1) * res).matmul(dt) 
                lmbda = dtTA.matmul(ATdt) + dtTresdt 
                pass 
            pass 
        ## no average, because we're using the log lik  
        ## also, `ssr_n` becomes vague as we iteratively apply optimal lambda 
        return lmbda * .5 * ssr_sum 
    def __get_param(self): 
        return torch.cat([p.reshape([-1, 1]) for p in self.parameters()], dim=0) 
    def __get_get_grad_generator(self, n=None): 
        ## The double get hides `self` in a function context,  
        ## packaging `get_grad_generator` for calling without 
        ## the SSRAgent instance.  
        if n is None: 
            n = self.replay_buffer.n 
            pass 
        def get_grad_generator(): 
            'l-Lanczos alg uses grad at least `ssr_rank` times' 
            def grad_generator(): 
                self.eval() 
                for idx in range(n): 
                    transition = self.replay_buffer.sample(idx_list=[idx]) 
                    loss = self.loss(transition) 
                    loss.backward() 
                    grad_vec = torch.cat([p.grad.reshape([-1]) for p in self.parameters()]) 
                    yield grad_vec 
                    pass
                pass 
            return grad_generator 
        return get_grad_generator 
    pass 

class Actor(SSRAgent):
    def __init__(self, state_dim, action_dim, critic=None, replay_buffer=None, ssr_rank=2): 
        super(Actor, self).__init__(replay_buffer=replay_buffer, ssr_rank=ssr_rank) 
        self.fc1 = nn.Linear(state_dim, 256) 
        self.fc2 = nn.Linear(256, 128) 
        self.fc3 = nn.Linear(128, action_dim) 
        self.buffer = Object() 
        self.buffer.critic = critic ## buffer stops param sharing (ie. in `state_dict`)
        pass 
    def forward(self, state): 
        x = torch.relu(self.fc1(state)) 
        x = torch.relu(self.fc2(x)) 
        action = torch.tanh(self.fc3(x)) 
        return action
    def loss(self, transitions): 
        if self.buffer.critic is None: 
            raise ValueError('ERROR: this model has no associated critic!') 
        return -torch.sum(self.buffer.critic(transitions.state, self(transitions.state))) ## log lik, not average log lik 
    pass 

class Critic(SSRAgent):
    def __init__(self, state_dim, action_dim, target_actor=None, target_critic=None, replay_buffer=None, ssr_rank=2): 
        super(Critic, self).__init__(replay_buffer=replay_buffer, ssr_rank=ssr_rank) 
        self.fc1 = nn.Linear(state_dim + action_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)
        self.buffer = Object() 
        self.buffer.target_actor = target_actor 
        self.buffer.target_critic = target_critic 
        pass 
    def forward(self, state, action):
        x = torch.cat([state, action], dim=1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        value = self.fc3(x)
        return value
    def loss(self, transitions): 
        if self.buffer.target_actor is None or self.buffer.target_critic is None: 
            raise ValueError('ERROR: target model missing!') 
        # Calculate the target Q-values
        target_Q = self.buffer.target_critic(transitions.next_state, self.buffer.target_actor(transitions.next_state))
        target_Q = (1 - transitions.done.int()) * target_Q.clone().detach() * GAMMA + transitions.reward 
        # Calculate the current Q-values
        current_Q = self(transitions.state, transitions.action) 
        # Calculate the critic loss
        return torch.sum((target_Q - current_Q).pow(2)) ## log lik, not average log lik 
    pass 

# Create the replay buffer 
replay_buffer = ReplayBuffer(capacity=100000) 

# Create the actor and critic networks
target_critic = Critic(state_dim=4, action_dim=1) 
target_actor = Actor(state_dim=4, action_dim=1) 
critic = Critic(state_dim=4, action_dim=1, target_critic=target_critic, target_actor=target_actor, replay_buffer=replay_buffer) 
actor = Actor(state_dim=4, action_dim=1, critic=critic, replay_buffer=replay_buffer) 

# Define the optimizers
actor_optimizer = optim.Adam(actor.parameters(), lr=1e-5)
critic_optimizer = optim.Adam(critic.parameters(), lr=1e-3)

# Define the environment 
env = gym.make('CartPole-v1') 

reward_list = [] 
p_list = [] # DEBUG 
LAMBDA = None 

# Train the agent
for episode in range(1000):
    state = env.reset()
    target_actor.load_state_dict(actor.state_dict()) 
    target_critic.load_state_dict(critic.state_dict()) 

    for t in range(1000): 
        action = actor(torch.tensor(state)) 
        if np.random.binomial(1, max(0,50-episode)/50) > 0: 
            ## random action 
            action = torch.tensor(np.random.uniform(low=-1., high=1.)).reshape([1]) 
            pass 
        
        action_p = action.item() * .5 + .5 
        action_int = np.random.binomial(1, action_p) ## must be 0 or 1 
        next_state, reward, done, _ = env.step(action_int) 

        replay_buffer.add(state, action, reward, next_state, done) 

        if len(replay_buffer) > 1000: 
            # Sample a batch of transitions from the replay buffer 
            transitions = replay_buffer.sample(batch_size=256) 

            # Calculate the critic loss 
            critic_loss = critic.loss(transitions) + critic.ssr(LAMBDA) 

            # Update the critic network 
            critic_optimizer.zero_grad() 
            critic_loss.backward() 
            critic_optimizer.step() 
            
            # Calculate the actor loss 
            actor_loss = actor.loss(transitions) + actor.ssr(LAMBDA) 

            # Update the actor network 
            actor_optimizer.zero_grad() 
            actor_loss.backward() 
            actor_optimizer.step() 

            if len(replay_buffer) > 2000: 
                ## memorize every 1000 transitions 
                actor.memorize(1000) 
                critic.memorize(1000) 
                replay_buffer.clear(1000) 
                pass 
            pass 

        state = next_state 

        if done:
            break

    # Evaluate the agent
    episode_reward = 0 
    state = env.reset() 

    for t in range(1000): 
        action = actor(torch.tensor(state))

        action_p = action.item() * .5 + .5 
        action_int = np.random.binomial(1, action_p) 
        next_state, reward, done, _ = env.step(action_int) 
        p_list.append(action.item()) # DEBUG 

        episode_reward += reward
        state = next_state 

        if done:
            break
    
    reward_list.append(episode_reward)
    print(f'Episode {episode}: {episode_reward}, len(replay_buffer): {len(replay_buffer)}')
# Out:
# /tmp/ipykernel_4305/2985502513.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   action = torch.tensor(action)
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/torch/autograd/__init__.py:266: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Episode 0: 15.0, len(replay_buffer): 14
# Episode 1: 14.0, len(replay_buffer): 35
# Episode 2: 12.0, len(replay_buffer): 55
# Episode 3: 13.0, len(replay_buffer): 66
# Episode 4: 15.0, len(replay_buffer): 83
# Episode 5: 14.0, len(replay_buffer): 101
# Episode 6: 16.0, len(replay_buffer): 187
# Episode 7: 15.0, len(replay_buffer): 207
# Episode 8: 13.0, len(replay_buffer): 236
# Episode 9: 16.0, len(replay_buffer): 297
# Episode 10: 28.0, len(replay_buffer): 314
# Episode 11: 14.0, len(replay_buffer): 331
# Episode 12: 15.0, len(replay_buffer): 348
# Episode 13: 17.0, len(replay_buffer): 369
# Episode 14: 26.0, len(replay_buffer): 388
# Episode 15: 31.0, len(replay_buffer): 408
# Episode 16: 11.0, len(replay_buffer): 447
# Episode 17: 14.0, len(replay_buffer): 459
# Episode 18: 15.0, len(replay_buffer): 473
# Episode 19: 12.0, len(replay_buffer): 508
# Episode 20: 11.0, len(replay_buffer): 522
# Episode 21: 8.0, len(replay_buffer): 541
# Episode 22: 10.0, len(replay_buffer): 557
# Episode 23: 15.0, len(replay_buffer): 576
# Episode 24: 14.0, len(replay_buffer): 591
# Episode 25: 14.0, len(replay_buffer): 602
# Episode 26: 11.0, len(replay_buffer): 616
# Episode 27: 25.0, len(replay_buffer): 630
# Episode 28: 17.0, len(replay_buffer): 669
# Episode 29: 16.0, len(replay_buffer): 682
# Episode 30: 18.0, len(replay_buffer): 700
# Episode 31: 12.0, len(replay_buffer): 722
# Episode 32: 11.0, len(replay_buffer): 734
# Episode 33: 26.0, len(replay_buffer): 760
# Episode 34: 35.0, len(replay_buffer): 769
# Episode 35: 47.0, len(replay_buffer): 792
# Episode 36: 14.0, len(replay_buffer): 806
# Episode 37: 19.0, len(replay_buffer): 837
# Episode 38: 17.0, len(replay_buffer): 848
# Episode 39: 17.0, len(replay_buffer): 862
# Episode 40: 13.0, len(replay_buffer): 888
# Episode 41: 13.0, len(replay_buffer): 900
# Episode 42: 22.0, len(replay_buffer): 929
# Episode 43: 15.0, len(replay_buffer): 941
# Episode 44: 10.0, len(replay_buffer): 962
# Episode 45: 10.0, len(replay_buffer): 981
# Episode 46: 12.0, len(replay_buffer): 1009
# Episode 47: 13.0, len(replay_buffer): 1031
# Episode 48: 26.0, len(replay_buffer): 1049
# Episode 49: 13.0, len(replay_buffer): 1086
# Episode 50: 10.0, len(replay_buffer): 1107
# Episode 51: 21.0, len(replay_buffer): 1128
# Episode 52: 9.0, len(replay_buffer): 1145
# Episode 53: 15.0, len(replay_buffer): 1158
# Episode 54: 10.0, len(replay_buffer): 1171
# Episode 55: 24.0, len(replay_buffer): 1192
# Episode 56: 26.0, len(replay_buffer): 1206
# Episode 57: 15.0, len(replay_buffer): 1220
# Episode 58: 23.0, len(replay_buffer): 1232
# Episode 59: 9.0, len(replay_buffer): 1276
# Episode 60: 26.0, len(replay_buffer): 1305
# Episode 61: 17.0, len(replay_buffer): 1339
# Episode 62: 17.0, len(replay_buffer): 1352
# Episode 63: 36.0, len(replay_buffer): 1366
# Episode 64: 16.0, len(replay_buffer): 1388
# Episode 65: 18.0, len(replay_buffer): 1432
# Episode 66: 44.0, len(replay_buffer): 1466
# Episode 67: 28.0, len(replay_buffer): 1502
# Episode 68: 17.0, len(replay_buffer): 1537
# Episode 69: 45.0, len(replay_buffer): 1588
# Episode 70: 71.0, len(replay_buffer): 1624
# Episode 71: 46.0, len(replay_buffer): 1659
# Episode 72: 37.0, len(replay_buffer): 1763
# Episode 73: 53.0, len(replay_buffer): 1889
# Episode 74: 74.0, len(replay_buffer): 1963
# Episode 75: 41.0, len(replay_buffer): 1014
# Episode 76: 39.0, len(replay_buffer): 1074
# Episode 77: 103.0, len(replay_buffer): 1128
# Episode 78: 63.0, len(replay_buffer): 1178
# Episode 79: 46.0, len(replay_buffer): 1223
# Episode 80: 43.0, len(replay_buffer): 1287
# Episode 81: 40.0, len(replay_buffer): 1370
# Episode 82: 80.0, len(replay_buffer): 1417
# Episode 83: 24.0, len(replay_buffer): 1443
# Episode 84: 41.0, len(replay_buffer): 1465
# Episode 85: 34.0, len(replay_buffer): 1494
# Episode 86: 25.0, len(replay_buffer): 1522
# Episode 87: 18.0, len(replay_buffer): 1544
# Episode 88: 15.0, len(replay_buffer): 1560
# Episode 89: 13.0, len(replay_buffer): 1576
# Episode 90: 29.0, len(replay_buffer): 1585
# Episode 91: 15.0, len(replay_buffer): 1603
# Episode 92: 15.0, len(replay_buffer): 1621
# Episode 93: 26.0, len(replay_buffer): 1635
# Episode 94: 22.0, len(replay_buffer): 1661
# Episode 95: 17.0, len(replay_buffer): 1677
# Episode 96: 27.0, len(replay_buffer): 1701
# Episode 97: 24.0, len(replay_buffer): 1721
# Episode 98: 32.0, len(replay_buffer): 1740
# Episode 99: 83.0, len(replay_buffer): 1774
# Episode 100: 62.0, len(replay_buffer): 1834
# Episode 101: 86.0, len(replay_buffer): 1945
# Episode 102: 31.0, len(replay_buffer): 1070
# Episode 103: 40.0, len(replay_buffer): 1180
# Episode 104: 172.0, len(replay_buffer): 1267
# Episode 105: 22.0, len(replay_buffer): 1413
# Episode 106: 128.0, len(replay_buffer): 1577
# Episode 107: 120.0, len(replay_buffer): 1698
# Episode 108: 136.0, len(replay_buffer): 1831
# Episode 109: 113.0, len(replay_buffer): 1958
# Episode 110: 16.0, len(replay_buffer): 1978
# Episode 111: 21.0, len(replay_buffer): 2000
# Episode 112: 11.0, len(replay_buffer): 1087
# Episode 113: 42.0, len(replay_buffer): 1100
# Episode 114: 12.0, len(replay_buffer): 1131
# Episode 115: 19.0, len(replay_buffer): 1153
# Episode 116: 15.0, len(replay_buffer): 1176
# Episode 117: 18.0, len(replay_buffer): 1190
# Episode 118: 16.0, len(replay_buffer): 1205
# Episode 119: 28.0, len(replay_buffer): 1217
# Episode 120: 23.0, len(replay_buffer): 1243
# Episode 121: 14.0, len(replay_buffer): 1265
# Episode 122: 25.0, len(replay_buffer): 1299
# Episode 123: 13.0, len(replay_buffer): 1362
# Episode 124: 18.0, len(replay_buffer): 1378
# Episode 125: 27.0, len(replay_buffer): 1391
# Episode 126: 18.0, len(replay_buffer): 1430
# Episode 127: 13.0, len(replay_buffer): 1519
# Episode 128: 15.0, len(replay_buffer): 1598
# Episode 129: 19.0, len(replay_buffer): 1621
# Episode 130: 79.0, len(replay_buffer): 1631
# Episode 131: 82.0, len(replay_buffer): 1647
# Episode 132: 72.0, len(replay_buffer): 1664
# Episode 133: 14.0, len(replay_buffer): 1734
# Episode 134: 16.0, len(replay_buffer): 1751
# Episode 135: 17.0, len(replay_buffer): 1829
# Episode 136: 84.0, len(replay_buffer): 1847
# Episode 137: 110.0, len(replay_buffer): 1939
# Episode 138: 115.0, len(replay_buffer): 1039
# Episode 139: 168.0, len(replay_buffer): 1213
# Episode 140: 239.0, len(replay_buffer): 1306
# Episode 141: 160.0, len(replay_buffer): 1509
# Episode 142: 160.0, len(replay_buffer): 1674
# Episode 143: 158.0, len(replay_buffer): 1834
# Episode 144: 20.0, len(replay_buffer): 1032
# Episode 145: 16.0, len(replay_buffer): 1050
# Episode 146: 16.0, len(replay_buffer): 1066
# Episode 147: 12.0, len(replay_buffer): 1080
# Episode 148: 24.0, len(replay_buffer): 1098
# Episode 149: 14.0, len(replay_buffer): 1116
# Episode 150: 19.0, len(replay_buffer): 1137
# Episode 151: 106.0, len(replay_buffer): 1243
# Episode 152: 106.0, len(replay_buffer): 1353
# Episode 153: 116.0, len(replay_buffer): 1447
# Episode 154: 95.0, len(replay_buffer): 1550
# Episode 155: 119.0, len(replay_buffer): 1661
# Episode 156: 116.0, len(replay_buffer): 1767
# Episode 157: 134.0, len(replay_buffer): 1872
# Episode 158: 111.0, len(replay_buffer): 1984
# Episode 159: 76.0, len(replay_buffer): 1082
# Episode 160: 25.0, len(replay_buffer): 1123
# Episode 161: 25.0, len(replay_buffer): 1186
# Episode 162: 33.0, len(replay_buffer): 1210
# Episode 163: 19.0, len(replay_buffer): 1251
# Episode 164: 72.0, len(replay_buffer): 1263
# Episode 165: 27.0, len(replay_buffer): 1326
# Episode 166: 53.0, len(replay_buffer): 1343
# Episode 167: 63.0, len(replay_buffer): 1366
# Episode 168: 49.0, len(replay_buffer): 1403
# Episode 169: 25.0, len(replay_buffer): 1432
# Episode 170: 30.0, len(replay_buffer): 1456
# Episode 171: 64.0, len(replay_buffer): 1513
# Episode 172: 33.0, len(replay_buffer): 1569
# Episode 173: 53.0, len(replay_buffer): 1657
# Episode 174: 33.0, len(replay_buffer): 1682
# Episode 175: 80.0, len(replay_buffer): 1704
# Episode 176: 35.0, len(replay_buffer): 1730
# Episode 177: 30.0, len(replay_buffer): 1773
# Episode 178: 32.0, len(replay_buffer): 1833
# Episode 179: 60.0, len(replay_buffer): 1898
# Episode 180: 65.0, len(replay_buffer): 1920
# Episode 181: 42.0, len(replay_buffer): 1991
# Episode 182: 21.0, len(replay_buffer): 1016
# Episode 183: 94.0, len(replay_buffer): 1100
# Episode 184: 118.0, len(replay_buffer): 1221
# Episode 185: 99.0, len(replay_buffer): 1325
# Episode 186: 176.0, len(replay_buffer): 1507
# Episode 187: 67.0, len(replay_buffer): 1632
# Episode 188: 144.0, len(replay_buffer): 1713
# Episode 189: 97.0, len(replay_buffer): 1767
# Episode 190: 49.0, len(replay_buffer): 1846
# Episode 191: 64.0, len(replay_buffer): 1903
# Episode 192: 41.0, len(replay_buffer): 1954
# Episode 193: 75.0, len(replay_buffer): 1993
# Episode 194: 49.0, len(replay_buffer): 1039
# Episode 195: 176.0, len(replay_buffer): 1094
# Episode 196: 204.0, len(replay_buffer): 1233
# Episode 197: 124.0, len(replay_buffer): 1356
# Episode 198: 198.0, len(replay_buffer): 1448
# Episode 199: 86.0, len(replay_buffer): 1543
# Episode 200: 85.0, len(replay_buffer): 1647
# Episode 201: 90.0, len(replay_buffer): 1740
# Episode 202: 209.0, len(replay_buffer): 1847
# Episode 203: 155.0, len(replay_buffer): 1955
# Episode 204: 113.0, len(replay_buffer): 1066
# Episode 205: 105.0, len(replay_buffer): 1168
# Episode 206: 116.0, len(replay_buffer): 1263
# Episode 207: 99.0, len(replay_buffer): 1419
# Episode 208: 65.0, len(replay_buffer): 1481
# Episode 209: 88.0, len(replay_buffer): 1541
# Episode 210: 87.0, len(replay_buffer): 1597
# Episode 211: 99.0, len(replay_buffer): 1664
# Episode 212: 53.0, len(replay_buffer): 1728
# Episode 213: 44.0, len(replay_buffer): 1777
# Episode 214: 64.0, len(replay_buffer): 1823
# Episode 215: 37.0, len(replay_buffer): 1853
# Episode 216: 29.0, len(replay_buffer): 1899
# Episode 217: 27.0, len(replay_buffer): 1937
# Episode 218: 26.0, len(replay_buffer): 1968
# Episode 219: 52.0, len(replay_buffer): 1997
# Episode 220: 37.0, len(replay_buffer): 1022
# Episode 221: 73.0, len(replay_buffer): 1080
# Episode 222: 87.0, len(replay_buffer): 1151
# Episode 223: 199.0, len(replay_buffer): 1253
# Episode 224: 105.0, len(replay_buffer): 1343
# Episode 225: 112.0, len(replay_buffer): 1407
# Episode 226: 61.0, len(replay_buffer): 1477
# Episode 227: 102.0, len(replay_buffer): 1581
# Episode 228: 88.0, len(replay_buffer): 1699
# Episode 229: 117.0, len(replay_buffer): 1816
# Episode 230: 100.0, len(replay_buffer): 1910
# Episode 231: 95.0, len(replay_buffer): 1007
# Episode 232: 180.0, len(replay_buffer): 1158
# Episode 233: 158.0, len(replay_buffer): 1356
# Episode 234: 238.0, len(replay_buffer): 1507
# Episode 235: 249.0, len(replay_buffer): 1689
# Episode 236: 233.0, len(replay_buffer): 1887
# Episode 237: 162.0, len(replay_buffer): 1040
# Episode 238: 25.0, len(replay_buffer): 1143
# Episode 239: 106.0, len(replay_buffer): 1164
# Episode 240: 84.0, len(replay_buffer): 1269
# Episode 241: 91.0, len(replay_buffer): 1371
# Episode 242: 33.0, len(replay_buffer): 1461
# Episode 243: 83.0, len(replay_buffer): 1536
# Episode 244: 77.0, len(replay_buffer): 1613
# Episode 245: 18.0, len(replay_buffer): 1681
# Episode 246: 22.0, len(replay_buffer): 1759
# Episode 247: 70.0, len(replay_buffer): 1844
# Episode 248: 47.0, len(replay_buffer): 1887
# Episode 249: 66.0, len(replay_buffer): 1963
# Episode 250: 69.0, len(replay_buffer): 1020
# Episode 251: 99.0, len(replay_buffer): 1146
# Episode 252: 79.0, len(replay_buffer): 1256
# Episode 253: 77.0, len(replay_buffer): 1337
# Episode 254: 66.0, len(replay_buffer): 1376
# Episode 255: 63.0, len(replay_buffer): 1431
# Episode 256: 43.0, len(replay_buffer): 1485
# Episode 257: 64.0, len(replay_buffer): 1521
# Episode 258: 47.0, len(replay_buffer): 1550
# Episode 259: 36.0, len(replay_buffer): 1590
# Episode 260: 32.0, len(replay_buffer): 1614
# Episode 261: 49.0, len(replay_buffer): 1644
# Episode 262: 23.0, len(replay_buffer): 1683
# Episode 263: 22.0, len(replay_buffer): 1713
# Episode 264: 11.0, len(replay_buffer): 1732
# Episode 265: 16.0, len(replay_buffer): 1753
# Episode 266: 12.0, len(replay_buffer): 1773
# Episode 267: 27.0, len(replay_buffer): 1785
# Episode 268: 10.0, len(replay_buffer): 1797
# Episode 269: 30.0, len(replay_buffer): 1809
# Episode 270: 13.0, len(replay_buffer): 1822
# Episode 271: 20.0, len(replay_buffer): 1832
# Episode 272: 15.0, len(replay_buffer): 1850
# Episode 273: 15.0, len(replay_buffer): 1862
# Episode 274: 13.0, len(replay_buffer): 1876
# Episode 275: 14.0, len(replay_buffer): 1886
# Episode 276: 11.0, len(replay_buffer): 1896
# Episode 277: 10.0, len(replay_buffer): 1905
# Episode 278: 9.0, len(replay_buffer): 1915
# Episode 279: 9.0, len(replay_buffer): 1933
# Episode 280: 10.0, len(replay_buffer): 1946
# Episode 281: 9.0, len(replay_buffer): 1957
# Episode 282: 9.0, len(replay_buffer): 1967
# Episode 283: 10.0, len(replay_buffer): 1975
# Episode 284: 11.0, len(replay_buffer): 1984
# Episode 285: 10.0, len(replay_buffer): 1998
# Episode 286: 10.0, len(replay_buffer): 1007
# Episode 287: 10.0, len(replay_buffer): 1016
# Episode 288: 10.0, len(replay_buffer): 1027
# Episode 289: 10.0, len(replay_buffer): 1037
# Episode 290: 13.0, len(replay_buffer): 1046
# Episode 291: 9.0, len(replay_buffer): 1055
# Episode 292: 9.0, len(replay_buffer): 1064
# Episode 293: 10.0, len(replay_buffer): 1074
# Episode 294: 9.0, len(replay_buffer): 1085
# Episode 295: 9.0, len(replay_buffer): 1093
# Episode 296: 10.0, len(replay_buffer): 1102
# Episode 297: 12.0, len(replay_buffer): 1111
# Episode 298: 10.0, len(replay_buffer): 1121
# Episode 299: 11.0, len(replay_buffer): 1133
# Episode 300: 8.0, len(replay_buffer): 1142
# Episode 301: 13.0, len(replay_buffer): 1152
# Episode 302: 10.0, len(replay_buffer): 1162
# Episode 303: 13.0, len(replay_buffer): 1171
# Episode 304: 8.0, len(replay_buffer): 1183
# Episode 305: 11.0, len(replay_buffer): 1196
# Episode 306: 11.0, len(replay_buffer): 1207
# Episode 307: 9.0, len(replay_buffer): 1217
# Episode 308: 13.0, len(replay_buffer): 1227
# Episode 309: 13.0, len(replay_buffer): 1238
# Episode 310: 11.0, len(replay_buffer): 1248
# Episode 311: 9.0, len(replay_buffer): 1260
# Episode 312: 9.0, len(replay_buffer): 1269
# Episode 313: 18.0, len(replay_buffer): 1283
# Episode 314: 14.0, len(replay_buffer): 1305
# Episode 315: 29.0, len(replay_buffer): 1318
# Episode 316: 27.0, len(replay_buffer): 1337
# Episode 317: 26.0, len(replay_buffer): 1353
# Episode 318: 45.0, len(replay_buffer): 1377
# Episode 319: 24.0, len(replay_buffer): 1401
# Episode 320: 65.0, len(replay_buffer): 1439
# Episode 321: 60.0, len(replay_buffer): 1470
# Episode 322: 68.0, len(replay_buffer): 1532
# Episode 323: 96.0, len(replay_buffer): 1598
# Episode 324: 116.0, len(replay_buffer): 1673
# Episode 325: 140.0, len(replay_buffer): 1847
# Episode 326: 172.0, len(replay_buffer): 1985
# Episode 327: 138.0, len(replay_buffer): 1100
# Episode 328: 143.0, len(replay_buffer): 1220
# Episode 329: 146.0, len(replay_buffer): 1341
# Episode 330: 91.0, len(replay_buffer): 1443
# Episode 331: 126.0, len(replay_buffer): 1567
# Episode 332: 121.0, len(replay_buffer): 1700
# Episode 333: 107.0, len(replay_buffer): 1828
# Episode 334: 118.0, len(replay_buffer): 1949
# Episode 335: 100.0, len(replay_buffer): 1087
# Episode 336: 117.0, len(replay_buffer): 1162
# Episode 337: 78.0, len(replay_buffer): 1262
# Episode 338: 118.0, len(replay_buffer): 1391
# Episode 339: 108.0, len(replay_buffer): 1497
# Episode 340: 106.0, len(replay_buffer): 1612
# Episode 341: 79.0, len(replay_buffer): 1712
# Episode 342: 131.0, len(replay_buffer): 1823
# Episode 343: 80.0, len(replay_buffer): 1933
# Episode 344: 132.0, len(replay_buffer): 1020
# Episode 345: 315.0, len(replay_buffer): 1167
# Episode 346: 223.0, len(replay_buffer): 1389
# Episode 347: 179.0, len(replay_buffer): 1600
# Episode 348: 212.0, len(replay_buffer): 1802
# Episode 349: 223.0, len(replay_buffer): 1972
# Episode 350: 180.0, len(replay_buffer): 1204
# Episode 351: 182.0, len(replay_buffer): 1388
# Episode 352: 209.0, len(replay_buffer): 1584
# Episode 353: 194.0, len(replay_buffer): 1772
# Episode 354: 177.0, len(replay_buffer): 1962
# Episode 355: 184.0, len(replay_buffer): 1133
# Episode 356: 172.0, len(replay_buffer): 1301
# Episode 357: 150.0, len(replay_buffer): 1474
# Episode 358: 208.0, len(replay_buffer): 1638
# Episode 359: 189.0, len(replay_buffer): 1831
# Episode 360: 175.0, len(replay_buffer): 1012
# Episode 361: 249.0, len(replay_buffer): 1243
# Episode 362: 236.0, len(replay_buffer): 1446
# Episode 363: 204.0, len(replay_buffer): 1654
# Episode 364: 194.0, len(replay_buffer): 1843
# Episode 365: 144.0, len(replay_buffer): 1041
# Episode 366: 123.0, len(replay_buffer): 1174
# Episode 367: 158.0, len(replay_buffer): 1320
# Episode 368: 168.0, len(replay_buffer): 1491
# Episode 369: 160.0, len(replay_buffer): 1671
# Episode 370: 149.0, len(replay_buffer): 1854
# Episode 371: 208.0, len(replay_buffer): 1025
# Episode 372: 149.0, len(replay_buffer): 1337
# Episode 373: 129.0, len(replay_buffer): 1477
# Episode 374: 133.0, len(replay_buffer): 1600
# Episode 375: 109.0, len(replay_buffer): 1697
# Episode 376: 89.0, len(replay_buffer): 1788
# Episode 377: 72.0, len(replay_buffer): 1871
# Episode 378: 95.0, len(replay_buffer): 1940
# Episode 379: 70.0, len(replay_buffer): 1008
# Episode 380: 346.0, len(replay_buffer): 1138
# Episode 381: 195.0, len(replay_buffer): 1364
# Episode 382: 163.0, len(replay_buffer): 1521
# Episode 383: 157.0, len(replay_buffer): 1683
# Episode 384: 159.0, len(replay_buffer): 1836
# Episode 385: 159.0, len(replay_buffer): 1980
# Episode 386: 216.0, len(replay_buffer): 1157
# Episode 387: 230.0, len(replay_buffer): 1406
# Episode 388: 238.0, len(replay_buffer): 1666
# Episode 389: 253.0, len(replay_buffer): 1935
# Episode 390: 187.0, len(replay_buffer): 1154
# Episode 391: 165.0, len(replay_buffer): 1335
# Episode 392: 176.0, len(replay_buffer): 1524
# Episode 393: 195.0, len(replay_buffer): 1713
# Episode 394: 193.0, len(replay_buffer): 1886
# Episode 395: 194.0, len(replay_buffer): 1077
# Episode 396: 198.0, len(replay_buffer): 1264
# Episode 397: 197.0, len(replay_buffer): 1500
# Episode 398: 217.0, len(replay_buffer): 1728
# Episode 399: 231.0, len(replay_buffer): 1963
# Episode 400: 469.0, len(replay_buffer): 1228
# Episode 401: 235.0, len(replay_buffer): 1460
# Episode 402: 173.0, len(replay_buffer): 1710
# Episode 403: 118.0, len(replay_buffer): 1837
# Episode 404: 126.0, len(replay_buffer): 1994
# Episode 405: 171.0, len(replay_buffer): 1258
# Episode 406: 141.0, len(replay_buffer): 1418
# Episode 407: 146.0, len(replay_buffer): 1557
# Episode 408: 118.0, len(replay_buffer): 1693
# Episode 409: 133.0, len(replay_buffer): 1709
# Episode 410: 136.0, len(replay_buffer): 1840
# Episode 411: 127.0, len(replay_buffer): 1966
# Episode 412: 178.0, len(replay_buffer): 1082
# Episode 413: 246.0, len(replay_buffer): 1297
# Episode 414: 500.0, len(replay_buffer): 1620
# Episode 415: 313.0, len(replay_buffer): 1120
# Episode 416: 171.0, len(replay_buffer): 1351
# Episode 417: 154.0, len(replay_buffer): 1531
# Episode 418: 147.0, len(replay_buffer): 1689
# Episode 419: 136.0, len(replay_buffer): 1840
# Episode 420: 151.0, len(replay_buffer): 1994
# Episode 421: 239.0, len(replay_buffer): 1168
# Episode 422: 227.0, len(replay_buffer): 1439
# Episode 423: 479.0, len(replay_buffer): 1832
# Episode 424: 237.0, len(replay_buffer): 1233
# Episode 425: 206.0, len(replay_buffer): 1469
# Episode 426: 197.0, len(replay_buffer): 1685
# Episode 427: 195.0, len(replay_buffer): 1889
# Episode 428: 264.0, len(replay_buffer): 1080
# Episode 429: 500.0, len(replay_buffer): 1420
# Episode 430: 500.0, len(replay_buffer): 1920
# Episode 431: 264.0, len(replay_buffer): 1325
# Episode 432: 256.0, len(replay_buffer): 1586
# Episode 433: 245.0, len(replay_buffer): 1823
# Episode 434: 362.0, len(replay_buffer): 1044
# Episode 435: 169.0, len(replay_buffer): 1391
# Episode 436: 11.0, len(replay_buffer): 1511
# Episode 437: 9.0, len(replay_buffer): 1602
# Episode 438: 10.0, len(replay_buffer): 1612
# Episode 439: 13.0, len(replay_buffer): 1623
# Episode 440: 9.0, len(replay_buffer): 1632
# Episode 441: 22.0, len(replay_buffer): 1642
# Episode 442: 76.0, len(replay_buffer): 1653
# Episode 443: 10.0, len(replay_buffer): 1665
# Episode 444: 10.0, len(replay_buffer): 1675
# Episode 445: 10.0, len(replay_buffer): 1685
# Episode 446: 10.0, len(replay_buffer): 1695
# Episode 447: 9.0, len(replay_buffer): 1703
# Episode 448: 9.0, len(replay_buffer): 1714
# Episode 449: 10.0, len(replay_buffer): 1723
# Episode 450: 10.0, len(replay_buffer): 1780
# Episode 451: 10.0, len(replay_buffer): 1789
# Episode 452: 58.0, len(replay_buffer): 1799
# Episode 453: 8.0, len(replay_buffer): 1808
# Episode 454: 9.0, len(replay_buffer): 1817
# Episode 455: 10.0, len(replay_buffer): 1827
# Episode 456: 10.0, len(replay_buffer): 1837
# Episode 457: 8.0, len(replay_buffer): 1847
# Episode 458: 11.0, len(replay_buffer): 1857
# Episode 459: 10.0, len(replay_buffer): 1868
# Episode 460: 10.0, len(replay_buffer): 1878
# Episode 461: 10.0, len(replay_buffer): 1888
# Episode 462: 9.0, len(replay_buffer): 1896
# Episode 463: 9.0, len(replay_buffer): 1906
# Episode 464: 8.0, len(replay_buffer): 1916
# Episode 465: 9.0, len(replay_buffer): 1926
# Episode 466: 8.0, len(replay_buffer): 1936
# Episode 467: 10.0, len(replay_buffer): 1946
# Episode 468: 9.0, len(replay_buffer): 1956
# Episode 469: 11.0, len(replay_buffer): 1966
# Episode 470: 10.0, len(replay_buffer): 1976
# Episode 471: 10.0, len(replay_buffer): 1986
# Episode 472: 10.0, len(replay_buffer): 1997
# Episode 473: 8.0, len(replay_buffer): 1005
# Episode 474: 11.0, len(replay_buffer): 1016
# Episode 475: 10.0, len(replay_buffer): 1026
# Episode 476: 9.0, len(replay_buffer): 1035
# Episode 477: 9.0, len(replay_buffer): 1045
# Episode 478: 9.0, len(replay_buffer): 1054
# Episode 479: 11.0, len(replay_buffer): 1064
# Episode 480: 10.0, len(replay_buffer): 1073
# Episode 481: 9.0, len(replay_buffer): 1081
# Episode 482: 10.0, len(replay_buffer): 1090
# Episode 483: 11.0, len(replay_buffer): 1100
# Episode 484: 8.0, len(replay_buffer): 1109
# Episode 485: 11.0, len(replay_buffer): 1118
# Episode 486: 9.0, len(replay_buffer): 1127
# Episode 487: 9.0, len(replay_buffer): 1135
# Episode 488: 11.0, len(replay_buffer): 1145
# Episode 489: 8.0, len(replay_buffer): 1154
# Episode 490: 11.0, len(replay_buffer): 1163
# Episode 491: 9.0, len(replay_buffer): 1172
# Episode 492: 9.0, len(replay_buffer): 1183
# Episode 493: 10.0, len(replay_buffer): 1193
# Episode 494: 11.0, len(replay_buffer): 1212
# Episode 495: 10.0, len(replay_buffer): 1232
# Episode 496: 12.0, len(replay_buffer): 1242
# Episode 497: 172.0, len(replay_buffer): 1364
# Episode 498: 452.0, len(replay_buffer): 1581
# Episode 499: 262.0, len(replay_buffer): 1976
# Episode 500: 199.0, len(replay_buffer): 1216
# Episode 501: 183.0, len(replay_buffer): 1419
# Episode 502: 178.0, len(replay_buffer): 1603
# Episode 503: 184.0, len(replay_buffer): 1801
# Episode 504: 172.0, len(replay_buffer): 1974
# Episode 505: 137.0, len(replay_buffer): 1125
# Episode 506: 142.0, len(replay_buffer): 1137
# Episode 507: 10.0, len(replay_buffer): 1243
# Episode 508: 10.0, len(replay_buffer): 1255
# Episode 509: 9.0, len(replay_buffer): 1265
# Episode 510: 12.0, len(replay_buffer): 1276
# Episode 511: 11.0, len(replay_buffer): 1287
# Episode 512: 10.0, len(replay_buffer): 1308
# Episode 513: 11.0, len(replay_buffer): 1319
# Episode 514: 11.0, len(replay_buffer): 1331
# Episode 515: 10.0, len(replay_buffer): 1341
# Episode 516: 117.0, len(replay_buffer): 1350
# Episode 517: 11.0, len(replay_buffer): 1361
# Episode 518: 10.0, len(replay_buffer): 1371
# Episode 519: 9.0, len(replay_buffer): 1380
# Episode 520: 11.0, len(replay_buffer): 1389
# Episode 521: 11.0, len(replay_buffer): 1400
# Episode 522: 10.0, len(replay_buffer): 1411
# Episode 523: 11.0, len(replay_buffer): 1420
# Episode 524: 11.0, len(replay_buffer): 1430
# Episode 525: 11.0, len(replay_buffer): 1440
# Episode 526: 11.0, len(replay_buffer): 1450
# Episode 527: 11.0, len(replay_buffer): 1461
# Episode 528: 11.0, len(replay_buffer): 1471
# Episode 529: 11.0, len(replay_buffer): 1481
# Episode 530: 11.0, len(replay_buffer): 1492
# Episode 531: 11.0, len(replay_buffer): 1502
# Episode 532: 11.0, len(replay_buffer): 1513
# Episode 533: 9.0, len(replay_buffer): 1523
# Episode 534: 10.0, len(replay_buffer): 1532
# Episode 535: 11.0, len(replay_buffer): 1544
# Episode 536: 11.0, len(replay_buffer): 1554
# Episode 537: 9.0, len(replay_buffer): 1566
# Episode 538: 10.0, len(replay_buffer): 1575
# Episode 539: 10.0, len(replay_buffer): 1587
# Episode 540: 12.0, len(replay_buffer): 1596
# Episode 541: 9.0, len(replay_buffer): 1606
# Episode 542: 11.0, len(replay_buffer): 1617
# Episode 543: 13.0, len(replay_buffer): 1627
# Episode 544: 12.0, len(replay_buffer): 1639
# Episode 545: 11.0, len(replay_buffer): 1648
# Episode 546: 15.0, len(replay_buffer): 1656
# Episode 547: 11.0, len(replay_buffer): 1666
# Episode 548: 10.0, len(replay_buffer): 1677
# Episode 549: 11.0, len(replay_buffer): 1686
# Episode 550: 10.0, len(replay_buffer): 1697
# Episode 551: 13.0, len(replay_buffer): 1707
# Episode 552: 11.0, len(replay_buffer): 1717
# Episode 553: 9.0, len(replay_buffer): 1728
# Episode 554: 11.0, len(replay_buffer): 1739
# Episode 555: 11.0, len(replay_buffer): 1751
# Episode 556: 8.0, len(replay_buffer): 1763
# Episode 557: 11.0, len(replay_buffer): 1774
# Episode 558: 10.0, len(replay_buffer): 1787
# Episode 559: 10.0, len(replay_buffer): 1798
# Episode 560: 10.0, len(replay_buffer): 1811
# Episode 561: 11.0, len(replay_buffer): 1820
# Episode 562: 12.0, len(replay_buffer): 1830
# Episode 563: 10.0, len(replay_buffer): 1839
# Episode 564: 10.0, len(replay_buffer): 1851
# Episode 565: 9.0, len(replay_buffer): 1866
# Episode 566: 14.0, len(replay_buffer): 1878
# Episode 567: 13.0, len(replay_buffer): 1893
# Episode 568: 14.0, len(replay_buffer): 1905
# Episode 569: 11.0, len(replay_buffer): 1917
# Episode 570: 12.0, len(replay_buffer): 1929
# Episode 571: 11.0, len(replay_buffer): 1946
# Episode 572: 14.0, len(replay_buffer): 1956
# Episode 573: 16.0, len(replay_buffer): 1970
# Episode 574: 10.0, len(replay_buffer): 1984
# Episode 575: 12.0, len(replay_buffer): 1996
# Episode 576: 8.0, len(replay_buffer): 1009
# Episode 577: 9.0, len(replay_buffer): 1023
# Episode 578: 9.0, len(replay_buffer): 1039
# Episode 579: 11.0, len(replay_buffer): 1049
# Episode 580: 12.0, len(replay_buffer): 1058
# Episode 581: 10.0, len(replay_buffer): 1070
# Episode 582: 9.0, len(replay_buffer): 1080
# Episode 583: 10.0, len(replay_buffer): 1090
# Episode 584: 9.0, len(replay_buffer): 1099
# Episode 585: 9.0, len(replay_buffer): 1108
# Episode 586: 9.0, len(replay_buffer): 1118
# Episode 587: 10.0, len(replay_buffer): 1127
# Episode 588: 10.0, len(replay_buffer): 1137
# Episode 589: 9.0, len(replay_buffer): 1146
# Episode 590: 9.0, len(replay_buffer): 1155
# Episode 591: 9.0, len(replay_buffer): 1164
# Episode 592: 9.0, len(replay_buffer): 1174
# Episode 593: 10.0, len(replay_buffer): 1183
# Episode 594: 10.0, len(replay_buffer): 1193
# Episode 595: 10.0, len(replay_buffer): 1203
# Episode 596: 10.0, len(replay_buffer): 1212
# Episode 597: 9.0, len(replay_buffer): 1223
# Episode 598: 10.0, len(replay_buffer): 1232
# Episode 599: 10.0, len(replay_buffer): 1242
# Episode 600: 10.0, len(replay_buffer): 1253
# Episode 601: 10.0, len(replay_buffer): 1262
# Episode 602: 9.0, len(replay_buffer): 1272
# Episode 603: 8.0, len(replay_buffer): 1281
# Episode 604: 10.0, len(replay_buffer): 1291
# Episode 605: 9.0, len(replay_buffer): 1301
# Episode 606: 8.0, len(replay_buffer): 1309
# Episode 607: 10.0, len(replay_buffer): 1318
# Episode 608: 9.0, len(replay_buffer): 1328
# Episode 609: 8.0, len(replay_buffer): 1337
# Episode 610: 9.0, len(replay_buffer): 1347
# Episode 611: 10.0, len(replay_buffer): 1356
# Episode 612: 9.0, len(replay_buffer): 1366
# Episode 613: 10.0, len(replay_buffer): 1376
# Episode 614: 8.0, len(replay_buffer): 1386
# Episode 615: 8.0, len(replay_buffer): 1395
# Episode 616: 9.0, len(replay_buffer): 1403
# Episode 617: 10.0, len(replay_buffer): 1411
# Episode 618: 10.0, len(replay_buffer): 1420
# Episode 619: 9.0, len(replay_buffer): 1429
# Episode 620: 10.0, len(replay_buffer): 1438
# Episode 621: 9.0, len(replay_buffer): 1448
# Episode 622: 10.0, len(replay_buffer): 1457
# Episode 623: 10.0, len(replay_buffer): 1466
# Episode 624: 9.0, len(replay_buffer): 1475
# Episode 625: 10.0, len(replay_buffer): 1485
# Episode 626: 10.0, len(replay_buffer): 1493
# Episode 627: 9.0, len(replay_buffer): 1503
# Episode 628: 8.0, len(replay_buffer): 1512
# Episode 629: 9.0, len(replay_buffer): 1521
# Episode 630: 9.0, len(replay_buffer): 1530
# Episode 631: 10.0, len(replay_buffer): 1539
# Episode 632: 8.0, len(replay_buffer): 1549
# Episode 633: 8.0, len(replay_buffer): 1557
# Episode 634: 9.0, len(replay_buffer): 1567
# Episode 635: 8.0, len(replay_buffer): 1576
# Episode 636: 9.0, len(replay_buffer): 1586
# Episode 637: 10.0, len(replay_buffer): 1595
# Episode 638: 9.0, len(replay_buffer): 1605
# Episode 639: 10.0, len(replay_buffer): 1615
# Episode 640: 9.0, len(replay_buffer): 1625
# Episode 641: 9.0, len(replay_buffer): 1634
# Episode 642: 9.0, len(replay_buffer): 1644
# Episode 643: 10.0, len(replay_buffer): 1653
# Episode 644: 9.0, len(replay_buffer): 1662
# Episode 645: 10.0, len(replay_buffer): 1672
# Episode 646: 8.0, len(replay_buffer): 1682
# Episode 647: 8.0, len(replay_buffer): 1691
# Episode 648: 9.0, len(replay_buffer): 1699
# Episode 649: 8.0, len(replay_buffer): 1708
# Episode 650: 9.0, len(replay_buffer): 1717
# Episode 651: 8.0, len(replay_buffer): 1727
# Episode 652: 10.0, len(replay_buffer): 1735
# Episode 653: 9.0, len(replay_buffer): 1744
# Episode 654: 10.0, len(replay_buffer): 1754
# Episode 655: 8.0, len(replay_buffer): 1763
# Episode 656: 9.0, len(replay_buffer): 1772
# Episode 657: 10.0, len(replay_buffer): 1781
# Episode 658: 10.0, len(replay_buffer): 1789
# Episode 659: 10.0, len(replay_buffer): 1799
# Episode 660: 10.0, len(replay_buffer): 1808
# Episode 661: 9.0, len(replay_buffer): 1817
# Episode 662: 9.0, len(replay_buffer): 1826
# Episode 663: 10.0, len(replay_buffer): 1835
# Episode 664: 10.0, len(replay_buffer): 1844
# Episode 665: 9.0, len(replay_buffer): 1853
# Episode 666: 9.0, len(replay_buffer): 1861
# Episode 667: 10.0, len(replay_buffer): 1869
# Episode 668: 8.0, len(replay_buffer): 1879
# Episode 669: 10.0, len(replay_buffer): 1889
# Episode 670: 9.0, len(replay_buffer): 1899
# Episode 671: 9.0, len(replay_buffer): 1909
# Episode 672: 9.0, len(replay_buffer): 1920
# Episode 673: 10.0, len(replay_buffer): 1928
# Episode 674: 8.0, len(replay_buffer): 1937
# Episode 675: 10.0, len(replay_buffer): 1947
# Episode 676: 9.0, len(replay_buffer): 1956
# Episode 677: 9.0, len(replay_buffer): 1965
# Episode 678: 9.0, len(replay_buffer): 1975
# Episode 679: 10.0, len(replay_buffer): 1984
# Episode 680: 9.0, len(replay_buffer): 1993
# Episode 681: 10.0, len(replay_buffer): 1003
# Episode 682: 9.0, len(replay_buffer): 1012
# Episode 683: 10.0, len(replay_buffer): 1021
# Episode 684: 9.0, len(replay_buffer): 1030
# Episode 685: 9.0, len(replay_buffer): 1039
# Episode 686: 9.0, len(replay_buffer): 1049
# Episode 687: 9.0, len(replay_buffer): 1059
# Episode 688: 10.0, len(replay_buffer): 1068
# Episode 689: 9.0, len(replay_buffer): 1077
# Episode 690: 9.0, len(replay_buffer): 1086
# Episode 691: 9.0, len(replay_buffer): 1096
# Episode 692: 9.0, len(replay_buffer): 1104
# Episode 693: 10.0, len(replay_buffer): 1114
# Episode 694: 9.0, len(replay_buffer): 1123
# Episode 695: 10.0, len(replay_buffer): 1132
# Episode 696: 8.0, len(replay_buffer): 1141
# Episode 697: 9.0, len(replay_buffer): 1150
# Episode 698: 10.0, len(replay_buffer): 1160
# Episode 699: 10.0, len(replay_buffer): 1168
# Episode 700: 10.0, len(replay_buffer): 1178
# Episode 701: 10.0, len(replay_buffer): 1187
# Episode 702: 8.0, len(replay_buffer): 1197
# Episode 703: 10.0, len(replay_buffer): 1207
# Episode 704: 9.0, len(replay_buffer): 1216
# Episode 705: 10.0, len(replay_buffer): 1224
# Episode 706: 9.0, len(replay_buffer): 1233
# Episode 707: 8.0, len(replay_buffer): 1242
# Episode 708: 10.0, len(replay_buffer): 1252
# Episode 709: 9.0, len(replay_buffer): 1262
# Episode 710: 10.0, len(replay_buffer): 1271
# Episode 711: 9.0, len(replay_buffer): 1280
# Episode 712: 10.0, len(replay_buffer): 1290
# Episode 713: 9.0, len(replay_buffer): 1300
# Episode 714: 8.0, len(replay_buffer): 1309
# Episode 715: 10.0, len(replay_buffer): 1318
# Episode 716: 9.0, len(replay_buffer): 1328
# Episode 717: 10.0, len(replay_buffer): 1337
# Episode 718: 8.0, len(replay_buffer): 1345
# Episode 719: 10.0, len(replay_buffer): 1354
# Episode 720: 9.0, len(replay_buffer): 1363
# Episode 721: 10.0, len(replay_buffer): 1373
# Episode 722: 10.0, len(replay_buffer): 1383
# Episode 723: 10.0, len(replay_buffer): 1392
# Episode 724: 9.0, len(replay_buffer): 1402
# Episode 725: 8.0, len(replay_buffer): 1410
# Episode 726: 9.0, len(replay_buffer): 1419
# Episode 727: 9.0, len(replay_buffer): 1428
# Episode 728: 10.0, len(replay_buffer): 1437
# Episode 729: 10.0, len(replay_buffer): 1446
# Episode 730: 9.0, len(replay_buffer): 1456
# Episode 731: 11.0, len(replay_buffer): 1465
# Episode 732: 8.0, len(replay_buffer): 1473
# Episode 733: 10.0, len(replay_buffer): 1483
# Episode 734: 9.0, len(replay_buffer): 1492
# Episode 735: 9.0, len(replay_buffer): 1500
# Episode 736: 9.0, len(replay_buffer): 1510
# Episode 737: 9.0, len(replay_buffer): 1519
# Episode 738: 10.0, len(replay_buffer): 1528
# Episode 739: 9.0, len(replay_buffer): 1536
# Episode 740: 9.0, len(replay_buffer): 1546
# Episode 741: 9.0, len(replay_buffer): 1556
# Episode 742: 10.0, len(replay_buffer): 1565
# Episode 743: 10.0, len(replay_buffer): 1575
# Episode 744: 9.0, len(replay_buffer): 1585
# Episode 745: 9.0, len(replay_buffer): 1595
# Episode 746: 9.0, len(replay_buffer): 1604
# Episode 747: 9.0, len(replay_buffer): 1613
# Episode 748: 9.0, len(replay_buffer): 1623
# Episode 749: 10.0, len(replay_buffer): 1633
# Episode 750: 9.0, len(replay_buffer): 1643
# Episode 751: 9.0, len(replay_buffer): 1651
# Episode 752: 10.0, len(replay_buffer): 1660
# Episode 753: 9.0, len(replay_buffer): 1668
# Episode 754: 9.0, len(replay_buffer): 1677
# Episode 755: 10.0, len(replay_buffer): 1686
# Episode 756: 10.0, len(replay_buffer): 1694
# Episode 757: 9.0, len(replay_buffer): 1705
# Episode 758: 10.0, len(replay_buffer): 1715
# Episode 759: 10.0, len(replay_buffer): 1725
# Episode 760: 9.0, len(replay_buffer): 1734
# Episode 761: 9.0, len(replay_buffer): 1744
# Episode 762: 9.0, len(replay_buffer): 1754
# Episode 763: 9.0, len(replay_buffer): 1764
# Episode 764: 10.0, len(replay_buffer): 1772
# Episode 765: 9.0, len(replay_buffer): 1783
# Episode 766: 9.0, len(replay_buffer): 1792
# Episode 767: 9.0, len(replay_buffer): 1803
# Episode 768: 10.0, len(replay_buffer): 1811
# Episode 769: 10.0, len(replay_buffer): 1821
# Episode 770: 10.0, len(replay_buffer): 1829
# Episode 771: 10.0, len(replay_buffer): 1838
# Episode 772: 9.0, len(replay_buffer): 1848
# Episode 773: 10.0, len(replay_buffer): 1858
# Episode 774: 10.0, len(replay_buffer): 1867
# Episode 775: 10.0, len(replay_buffer): 1875
# Episode 776: 9.0, len(replay_buffer): 1884
# Episode 777: 10.0, len(replay_buffer): 1894
# Episode 778: 9.0, len(replay_buffer): 1903
# Episode 779: 9.0, len(replay_buffer): 1914
# Episode 780: 8.0, len(replay_buffer): 1924
# Episode 781: 9.0, len(replay_buffer): 1933
# Episode 782: 10.0, len(replay_buffer): 1942
# Episode 783: 8.0, len(replay_buffer): 1952
# Episode 784: 9.0, len(replay_buffer): 1961
# Episode 785: 9.0, len(replay_buffer): 1970
# Episode 786: 9.0, len(replay_buffer): 1979
# Episode 787: 8.0, len(replay_buffer): 1988
# Episode 788: 10.0, len(replay_buffer): 1998
# Episode 789: 10.0, len(replay_buffer): 1008
# Episode 790: 9.0, len(replay_buffer): 1017
# Episode 791: 10.0, len(replay_buffer): 1027
# Episode 792: 9.0, len(replay_buffer): 1037
# Episode 793: 9.0, len(replay_buffer): 1046
# Episode 794: 10.0, len(replay_buffer): 1055
# Episode 795: 11.0, len(replay_buffer): 1063
# Episode 796: 9.0, len(replay_buffer): 1072
# Episode 797: 8.0, len(replay_buffer): 1081
# Episode 798: 9.0, len(replay_buffer): 1092
# Episode 799: 9.0, len(replay_buffer): 1102
# Episode 800: 10.0, len(replay_buffer): 1113
# Episode 801: 11.0, len(replay_buffer): 1123
# Episode 802: 16.0, len(replay_buffer): 1135
# Episode 803: 13.0, len(replay_buffer): 1146
# Episode 804: 14.0, len(replay_buffer): 1157
# Episode 805: 16.0, len(replay_buffer): 1173
# Episode 806: 137.0, len(replay_buffer): 1286
# Episode 807: 166.0, len(replay_buffer): 1426
# Episode 808: 223.0, len(replay_buffer): 1614
# Episode 809: 170.0, len(replay_buffer): 1863
# Episode 810: 131.0, len(replay_buffer): 1005
# Episode 811: 113.0, len(replay_buffer): 1124
# Episode 812: 99.0, len(replay_buffer): 1234
# Episode 813: 87.0, len(replay_buffer): 1337
# Episode 814: 75.0, len(replay_buffer): 1404
# Episode 815: 10.0, len(replay_buffer): 1480
# Episode 816: 79.0, len(replay_buffer): 1492
# Episode 817: 10.0, len(replay_buffer): 1561
# Episode 818: 13.0, len(replay_buffer): 1632
# Episode 819: 30.0, len(replay_buffer): 1691
# Episode 820: 10.0, len(replay_buffer): 1756
# Episode 821: 10.0, len(replay_buffer): 1765
# Episode 822: 16.0, len(replay_buffer): 1775
# Episode 823: 11.0, len(replay_buffer): 1831
# Episode 824: 15.0, len(replay_buffer): 1842
# Episode 825: 14.0, len(replay_buffer): 1853
# Episode 826: 30.0, len(replay_buffer): 1898
# Episode 827: 11.0, len(replay_buffer): 1912
# Episode 828: 12.0, len(replay_buffer): 1967
# Episode 829: 53.0, len(replay_buffer): 1982
# Episode 830: 9.0, len(replay_buffer): 1993
# Episode 831: 47.0, len(replay_buffer): 1003
# Episode 832: 21.0, len(replay_buffer): 1026
# Episode 833: 12.0, len(replay_buffer): 1034
# Episode 834: 12.0, len(replay_buffer): 1044
# Episode 835: 8.0, len(replay_buffer): 1055
# Episode 836: 35.0, len(replay_buffer): 1064
# Episode 837: 10.0, len(replay_buffer): 1072
# Episode 838: 9.0, len(replay_buffer): 1082
# Episode 839: 10.0, len(replay_buffer): 1092
# Episode 840: 10.0, len(replay_buffer): 1100
# Episode 841: 10.0, len(replay_buffer): 1111
# Episode 842: 10.0, len(replay_buffer): 1122
# Episode 843: 10.0, len(replay_buffer): 1133
# Episode 844: 9.0, len(replay_buffer): 1142
# Episode 845: 11.0, len(replay_buffer): 1152
# Episode 846: 10.0, len(replay_buffer): 1161
# Episode 847: 10.0, len(replay_buffer): 1170
# Episode 848: 10.0, len(replay_buffer): 1179
# Episode 849: 10.0, len(replay_buffer): 1189
# Episode 850: 9.0, len(replay_buffer): 1199
# Episode 851: 9.0, len(replay_buffer): 1208
# Episode 852: 10.0, len(replay_buffer): 1218
# Episode 853: 9.0, len(replay_buffer): 1227
# Episode 854: 10.0, len(replay_buffer): 1236
# Episode 855: 10.0, len(replay_buffer): 1246
# Episode 856: 11.0, len(replay_buffer): 1255
# Episode 857: 10.0, len(replay_buffer): 1265
# Episode 858: 9.0, len(replay_buffer): 1275
# Episode 859: 10.0, len(replay_buffer): 1284
# Episode 860: 11.0, len(replay_buffer): 1294
# Episode 861: 10.0, len(replay_buffer): 1303
# Episode 862: 10.0, len(replay_buffer): 1312
# Episode 863: 8.0, len(replay_buffer): 1321
# Episode 864: 8.0, len(replay_buffer): 1330
# Episode 865: 11.0, len(replay_buffer): 1340
# Episode 866: 9.0, len(replay_buffer): 1350
# Episode 867: 10.0, len(replay_buffer): 1359
# Episode 868: 11.0, len(replay_buffer): 1367
# Episode 869: 10.0, len(replay_buffer): 1377
# Episode 870: 10.0, len(replay_buffer): 1387
# Episode 871: 10.0, len(replay_buffer): 1396
# Episode 872: 9.0, len(replay_buffer): 1404
# Episode 873: 9.0, len(replay_buffer): 1413
# Episode 874: 9.0, len(replay_buffer): 1422
# Episode 875: 9.0, len(replay_buffer): 1432
# Episode 876: 10.0, len(replay_buffer): 1441
# Episode 877: 9.0, len(replay_buffer): 1450
# Episode 878: 10.0, len(replay_buffer): 1459
# Episode 879: 10.0, len(replay_buffer): 1469
# Episode 880: 11.0, len(replay_buffer): 1479
# Episode 881: 9.0, len(replay_buffer): 1489
# Episode 882: 9.0, len(replay_buffer): 1500
# Episode 883: 9.0, len(replay_buffer): 1510
# Episode 884: 9.0, len(replay_buffer): 1520
# Episode 885: 10.0, len(replay_buffer): 1528
# Episode 886: 10.0, len(replay_buffer): 1538
# Episode 887: 8.0, len(replay_buffer): 1548
# Episode 888: 10.0, len(replay_buffer): 1558
# Episode 889: 8.0, len(replay_buffer): 1567
# Episode 890: 10.0, len(replay_buffer): 1577
# Episode 891: 10.0, len(replay_buffer): 1586
# Episode 892: 9.0, len(replay_buffer): 1597
# Episode 893: 9.0, len(replay_buffer): 1605
# Episode 894: 9.0, len(replay_buffer): 1615
# Episode 895: 8.0, len(replay_buffer): 1625
# Episode 896: 9.0, len(replay_buffer): 1635
# Episode 897: 9.0, len(replay_buffer): 1645
# Episode 898: 10.0, len(replay_buffer): 1655
# Episode 899: 10.0, len(replay_buffer): 1665
# Episode 900: 9.0, len(replay_buffer): 1675
# Episode 901: 8.0, len(replay_buffer): 1684
# Episode 902: 9.0, len(replay_buffer): 1694
# Episode 903: 8.0, len(replay_buffer): 1704
# Episode 904: 10.0, len(replay_buffer): 1714
# Episode 905: 9.0, len(replay_buffer): 1724
# Episode 906: 10.0, len(replay_buffer): 1734
# Episode 907: 8.0, len(replay_buffer): 1743
# Episode 908: 9.0, len(replay_buffer): 1752
# Episode 909: 8.0, len(replay_buffer): 1762
# Episode 910: 8.0, len(replay_buffer): 1771
# Episode 911: 9.0, len(replay_buffer): 1780
# Episode 912: 10.0, len(replay_buffer): 1789
# Episode 913: 10.0, len(replay_buffer): 1798
# Episode 914: 10.0, len(replay_buffer): 1807
# Episode 915: 8.0, len(replay_buffer): 1815
# Episode 916: 9.0, len(replay_buffer): 1825
# Episode 917: 10.0, len(replay_buffer): 1835
# Episode 918: 10.0, len(replay_buffer): 1846
# Episode 919: 9.0, len(replay_buffer): 1855
# Episode 920: 8.0, len(replay_buffer): 1863
# Episode 921: 10.0, len(replay_buffer): 1871
# Episode 922: 10.0, len(replay_buffer): 1880
# Episode 923: 10.0, len(replay_buffer): 1889
# Episode 924: 9.0, len(replay_buffer): 1899
# Episode 925: 8.0, len(replay_buffer): 1909
# Episode 926: 10.0, len(replay_buffer): 1918
# Episode 927: 9.0, len(replay_buffer): 1928
# Episode 928: 10.0, len(replay_buffer): 1938
# Episode 929: 10.0, len(replay_buffer): 1947
# Episode 930: 8.0, len(replay_buffer): 1956
# Episode 931: 9.0, len(replay_buffer): 1966
# Episode 932: 8.0, len(replay_buffer): 1976
# Episode 933: 9.0, len(replay_buffer): 1985
# Episode 934: 10.0, len(replay_buffer): 1994
# Episode 935: 11.0, len(replay_buffer): 1003
# Episode 936: 9.0, len(replay_buffer): 1012
# Episode 937: 9.0, len(replay_buffer): 1022
# Episode 938: 9.0, len(replay_buffer): 1032
# Episode 939: 10.0, len(replay_buffer): 1042
# Episode 940: 10.0, len(replay_buffer): 1052
# Episode 941: 10.0, len(replay_buffer): 1061
# Episode 942: 9.0, len(replay_buffer): 1069
# Episode 943: 9.0, len(replay_buffer): 1079
# Episode 944: 10.0, len(replay_buffer): 1090
# Episode 945: 9.0, len(replay_buffer): 1099
# Episode 946: 10.0, len(replay_buffer): 1109
# Episode 947: 10.0, len(replay_buffer): 1117
# Episode 948: 10.0, len(replay_buffer): 1127
# Episode 949: 10.0, len(replay_buffer): 1137
# Episode 950: 8.0, len(replay_buffer): 1146
# Episode 951: 10.0, len(replay_buffer): 1156
# Episode 952: 9.0, len(replay_buffer): 1166
# Episode 953: 10.0, len(replay_buffer): 1175
# Episode 954: 10.0, len(replay_buffer): 1185
# Episode 955: 10.0, len(replay_buffer): 1194
# Episode 956: 10.0, len(replay_buffer): 1203
# Episode 957: 10.0, len(replay_buffer): 1211
# Episode 958: 9.0, len(replay_buffer): 1220
# Episode 959: 9.0, len(replay_buffer): 1229
# Episode 960: 10.0, len(replay_buffer): 1238
# Episode 961: 9.0, len(replay_buffer): 1248
# Episode 962: 9.0, len(replay_buffer): 1258
# Episode 963: 8.0, len(replay_buffer): 1268
# Episode 964: 10.0, len(replay_buffer): 1277
# Episode 965: 11.0, len(replay_buffer): 1286
# Episode 966: 9.0, len(replay_buffer): 1295
# Episode 967: 10.0, len(replay_buffer): 1305
# Episode 968: 9.0, len(replay_buffer): 1315
# Episode 969: 9.0, len(replay_buffer): 1325
# Episode 970: 10.0, len(replay_buffer): 1333
# Episode 971: 10.0, len(replay_buffer): 1342
# Episode 972: 9.0, len(replay_buffer): 1351
# Episode 973: 10.0, len(replay_buffer): 1359
# Episode 974: 9.0, len(replay_buffer): 1367
# Episode 975: 10.0, len(replay_buffer): 1377
# Episode 976: 9.0, len(replay_buffer): 1387
# Episode 977: 10.0, len(replay_buffer): 1397
# Episode 978: 10.0, len(replay_buffer): 1407
# Episode 979: 9.0, len(replay_buffer): 1417
# Episode 980: 8.0, len(replay_buffer): 1427
# Episode 981: 10.0, len(replay_buffer): 1436
# Episode 982: 10.0, len(replay_buffer): 1444
# Episode 983: 10.0, len(replay_buffer): 1453
# Episode 984: 10.0, len(replay_buffer): 1463
# Episode 985: 8.0, len(replay_buffer): 1472
# Episode 986: 9.0, len(replay_buffer): 1482
# Episode 987: 9.0, len(replay_buffer): 1491
# Episode 988: 9.0, len(replay_buffer): 1501
# Episode 989: 10.0, len(replay_buffer): 1509
# Episode 990: 10.0, len(replay_buffer): 1518
# Episode 991: 9.0, len(replay_buffer): 1527
# Episode 992: 9.0, len(replay_buffer): 1536
# Episode 993: 9.0, len(replay_buffer): 1545
# Episode 994: 8.0, len(replay_buffer): 1554
# Episode 995: 9.0, len(replay_buffer): 1563
# Episode 996: 11.0, len(replay_buffer): 1572
# Episode 997: 10.0, len(replay_buffer): 1582
# Episode 998: 8.0, len(replay_buffer): 1592
# Episode 999: 10.0, len(replay_buffer): 1600

# %%
import matplotlib.pyplot as plt


plt.plot(reward_list)
plt.show()

# %%
import matplotlib.pyplot as plt


plt.plot(p_list)
plt.show()
